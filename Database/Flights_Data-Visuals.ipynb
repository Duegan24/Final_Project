# %%
# Importing dependencies
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Setting file directory
file_dir = 'Data'

# %%
# Extracting data
jan_19_data = pd.read_csv(f'{file_dir}/Jan_2019_ontime.csv')
jan_20_data = pd.read_csv(f'{file_dir}/Jan_2020_ontime.csv')
airline_codes = pd.read_csv(f'{file_dir}/airline_codes.csv')
airport_codes = pd.read_csv(f'{file_dir}/airport_codes.csv')

# %%
jan_19 = jan_19_data
jan_19.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                1195302    GNV  ...              1039707   ATL    601.0
# ...

# %%
jan_20 = jan_20_data
jan_20.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            3                EV                  20366
# 1             1            3                EV                  20366
# 2             1            3                EV                  20366
# 3             1            3                EV                  20366
# 4             1            3                EV                  20366
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         EV   N48901               4397              13930
# 1         EV   N16976               4401              15370
# 2         EV   N12167               4404              11618
# 3         EV   N14902               4405              10781
# 4         EV   N606UX               4407              14524
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                1393007    ORD  ...              1197705   GRB   1003.0
# ...

# %%
jan_19 = jan_19.dropna()
jan_19
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
jan_20 = jan_20.dropna()
jan_20
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            3                EV                  20366
# 1                  1            3                EV                  20366
# 2                  1            3                EV                  20366
# 3                  1            3                EV                  20366
# 4                  1            3                EV                  20366
# ...              ...          ...               ...                    ...
# 607341            31            5                9E                  20363
# 607342            31            5                9E                  20363
# 607343            31            5                9E                  20363
# 607344            31            5                9E                  20363
# 607345            31            5                9E                  20363
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
jan_19.count()
# Out:
# DAY_OF_MONTH             565963
# DAY_OF_WEEK              565963
# OP_UNIQUE_CARRIER        565963
# OP_CARRIER_AIRLINE_ID    565963
# OP_CARRIER               565963
# TAIL_NUM                 565963
# OP_CARRIER_FL_NUM        565963
# ORIGIN_AIRPORT_ID        565963
# ORIGIN_AIRPORT_SEQ_ID    565963
# ORIGIN                   565963
# DEST_AIRPORT_ID          565963
# DEST_AIRPORT_SEQ_ID      565963
# DEST                     565963
# DEP_TIME                 565963
# DEP_DEL15                565963
# DEP_TIME_BLK             565963
# ARR_TIME                 565963
# ARR_DEL15                565963
# CANCELLED                565963
# DIVERTED                 565963
# DISTANCE                 565963
# dtype: int64

# %%
jan_20.count()
# Out:
# DAY_OF_MONTH             599268
# DAY_OF_WEEK              599268
# OP_UNIQUE_CARRIER        599268
# OP_CARRIER_AIRLINE_ID    599268
# OP_CARRIER               599268
# TAIL_NUM                 599268
# OP_CARRIER_FL_NUM        599268
# ORIGIN_AIRPORT_ID        599268
# ORIGIN_AIRPORT_SEQ_ID    599268
# ORIGIN                   599268
# DEST_AIRPORT_ID          599268
# DEST_AIRPORT_SEQ_ID      599268
# DEST                     599268
# DEP_TIME                 599268
# DEP_DEL15                599268
# DEP_TIME_BLK             599268
# ARR_TIME                 599268
# ARR_DEL15                599268
# CANCELLED                599268
# DIVERTED                 599268
# DISTANCE                 599268
# dtype: int64

# %%
jan_19.dtypes
# Out:
# DAY_OF_MONTH               int64
# DAY_OF_WEEK                int64
# OP_UNIQUE_CARRIER         object
# OP_CARRIER_AIRLINE_ID      int64
# OP_CARRIER                object
# TAIL_NUM                  object
# OP_CARRIER_FL_NUM          int64
# ORIGIN_AIRPORT_ID          int64
# ORIGIN_AIRPORT_SEQ_ID      int64
# ORIGIN                    object
# DEST_AIRPORT_ID            int64
# DEST_AIRPORT_SEQ_ID        int64
# DEST                      object
# DEP_TIME                 float64
# DEP_DEL15                float64
# DEP_TIME_BLK              object
# ARR_TIME                 float64
# ARR_DEL15                float64
# CANCELLED                  int64
# DIVERTED                   int64
# DISTANCE                   int64
# dtype: object

# %%
jan_20.dtypes
# Out:
# DAY_OF_MONTH               int64
# DAY_OF_WEEK                int64
# OP_UNIQUE_CARRIER         object
# OP_CARRIER_AIRLINE_ID      int64
# OP_CARRIER                object
# TAIL_NUM                  object
# OP_CARRIER_FL_NUM          int64
# ORIGIN_AIRPORT_ID          int64
# ORIGIN_AIRPORT_SEQ_ID      int64
# ORIGIN                    object
# DEST_AIRPORT_ID            int64
# DEST_AIRPORT_SEQ_ID        int64
# DEST                      object
# DEP_TIME                 float64
# DEP_DEL15                float64
# DEP_TIME_BLK              object
# ARR_TIME                 float64
# ARR_DEL15                float64
# CANCELLED                  int64
# DIVERTED                   int64
# DISTANCE                   int64
# dtype: object

# %%
jan_19[jan_19.OP_UNIQUE_CARRIER==jan_19.OP_CARRIER].shape
# Out:
# (565963, 21)

# %%
jan_20[jan_20.OP_UNIQUE_CARRIER==jan_20.OP_CARRIER].shape
# Out:
# (599268, 21)

# %%
jan_19_clean = jan_19.drop(['OP_UNIQUE_CARRIER'], axis=1)
jan_19_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0             1            2                  20363         9E   N8688C
# 1             1            2                  20363         9E   N348PQ
# 2             1            2                  20363         9E   N8896A
# 3             1            2                  20363         9E   N8886A
# 4             1            2                  20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# ...

# %%
jan_20_clean = jan_20.drop('OP_UNIQUE_CARRIER', axis=1)
jan_20_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0             1            3                  20366         EV   N48901
# 1             1            3                  20366         EV   N16976
# 2             1            3                  20366         EV   N12167
# 3             1            3                  20366         EV   N14902
# 4             1            3                  20366         EV   N606UX
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               4397              13930                1393007    ORD
# 1               4401              15370                1537002    TUL
# 2               4404              11618                1161802    EWR
# 3               4405              10781                1078105    BTR
# 4               4407              14524                1452401    RIC
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# ...

# %%
jan_19_clean.OP_CARRIER.unique()
# Out:
# array(['9E', 'AA', 'MQ', 'G4', 'OH', 'B6', 'YV', 'EV', 'F9', 'YX', 'HA',
#        'NK', 'OO', 'WN', 'AS', 'UA', 'DL'], dtype=object)

# %%
airline_codes_df = airline_codes
airline_codes_df.head()
# Out:
#    OP_CARRIER_AIRLINE_ID OP_CARRIER    OP_CARRIER_NAME
# 0                  20363         9E       Endeavor Air
# 1                  19805         AA  American Airlines
# 2                  19930         AS    Alaska Airlines
# 3                  20409         B6           Jet Blue
# 4                  19790         DL    Delta Air Lines

# %%
jan_19_join = jan_19_clean.merge(airline_codes_df, on ="OP_CARRIER", how="left")
jan_19_join.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEP_TIME DEP_DEL15  DEP_TIME_BLK  ARR_TIME ARR_DEL15  \
# ...

# %%
jan_19_clean = jan_19_join.drop("OP_CARRIER_AIRLINE_ID_y", axis=1)
jan_19_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEST DEP_TIME  DEP_DEL15  DEP_TIME_BLK ARR_TIME  \
# ...

# %%
airport_codes_df = airport_codes
airport_codes_df.head()
# Out:
#   ORIGIN          CITY STATE
# 0    ABR      Aberdeen    SD
# 1    ABI       Abilene    TX
# 2    ADK   Adak Island    AK
# 3    CAK  Akron/Canton    OH
# 4    ALB        Albany    NY

# %%
jan_19_join = jan_19_clean.merge(airport_codes_df, on ="ORIGIN", how="left")
jan_19_join.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  \
# ...

# %%
jan_19_clean = jan_19_join
jan_19_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  \
# ...

# %% [markdown]
# # January 2019 Flights Visuals

# %%
# Airlines and the percentage of delayed flight vs total flights.
df_carrier=pd.DataFrame(jan_19_clean.groupby(["OP_CARRIER_NAME","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Carrier","Not_Delayed","Delayed"])
df_carrier["Percent_of_delayed"]=df_carrier.Delayed /( df_carrier.Delayed+ df_carrier.Not_Delayed)
df_carrier.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_carrier.head(18)
# Out:
#                         Carrier Not_Delayed Delayed Percent_of_delayed
# 14           Southwest Airlines       88769   18466           0.172201
# 5               Delta Air Lines       63990    9413           0.128237
# 2             American Airlines       63361   11993           0.159155
# 13             SkyWest Airlines       49190   12580           0.203659
# 16              United Airlines       37768    8358           0.181199
# 12             Midwest Airlines       19779    4790           0.194961
# 4                        Comair       19068    3301            0.14757
# 7                     Envoy Air       19016    4694           0.197976
# 0               Alaska Airlines       17472    2732           0.135221
# 10                     Jet Blue       17074    6321           0.270186
# 6                  Endeavor Air       16092    3729           0.188134
# 11                Mesa Airlines       14927    2902           0.162769
# ...

# %%
df_carrier.set_index("Carrier", inplace=True)
df_carrier
# Out:
#                             Not_Delayed Delayed Percent_of_delayed
# Carrier
# Southwest Airlines                88769   18466           0.172201
# Delta Air Lines                   63990    9413           0.128237
# American Airlines                 63361   11993           0.159155
# SkyWest Airlines                  49190   12580           0.203659
# United Airlines                   37768    8358           0.181199
# Midwest Airlines                  19779    4790           0.194961
# Comair                            19068    3301            0.14757
# Envoy Air                         19016    4694           0.197976
# Alaska Airlines                   17472    2732           0.135221
# Jet Blue                          17074    6321           0.270186
# Endeavor Air                      16092    3729           0.188134
# Mesa Airlines                     14927    2902           0.162769
# Spirit Airlines                   12842    2167            0.14438
# ...

# %%
# df_carrier[[ 'Not_Delayed', 'Delayed']].plot(kind='bar',stacked=True)
# # df_carrier[['Carrier', 'Percent Of Delayed']].set_index("Carrier").plot.line()
# df_carrier[ 'Percent_of_delayed'].plot(secondary_y=True)
# # ax = plt.gca()
# plt.show()

# %%
# df_carrier[[ 'Not_Delayed', 'Delayed']].plot(kind='bar',stacked=True)
# # df_carrier[['Carrier', 'Percent Of Delayed']].set_index("Carrier").plot.line()
df_carrier[[ 'Not_Delayed', 'Delayed']].plot(kind='bar',stacked=True)
plt.xlabel("Airline") 
plt.ylabel("Flights")
plt.show()

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# fig, ax1 = plt.subplots()
# ax2 = ax1.twinx()  # set up the 2nd axis
# ax1.plot(df_carrier.index, df_carrier.Percent_of_delayed) #plot the Revenue on axis #1
# # the next few lines plot the fiscal year data as bar plots and changes the color for each.
# ax2.bar(df_carrier.index, df_carrier[[ 'Not_Delayed', 'Delayed']])
# ax2.grid(b=False) # turn off grid #2

# %%
# Top 10 origin airports and the percentage of delayed flight vs total flights.
df_org=pd.DataFrame(jan_19_clean.groupby(["CITY","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Origin","Not_Delayed","Delayed"])
df_org["Percent Of Delayed"]=df_org.Delayed /( df_org.Delayed+ df_org.Not_Delayed)
df_org.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_org.head(50)
# Out:
#                                      Origin Not_Delayed Delayed  \
# 15                                  Atlanta       26665    4118
# 71                        Dallas/Fort Worth       18677    4028
# 58                         Chicago - O'Hare       16776    6560
# 53                                Charlotte       16101    2671
# 74                                   Denver       14805    3415
# 171                             Los Angeles       14643    3017
# 224                                 Phoenix       12417    2123
# 128  Houston - George Bush Intercontinental       12381    2082
# 159                               Las Vegas       10844    2201
# 255                           San Francisco       10111    2967
# 186                             Minneapolis       10071    1849
# 214                                 Orlando        9690    2147
# 201                   New York - La Guardia        9575    3775
# 76                                  Detroit        9551    2200
# ...

# %%
df_org[['Origin', 'Not_Delayed', 'Delayed']].head(10).set_index("Origin").plot(kind='bar',stacked=True)
plt.xlabel("Airport Departure") 
plt.ylabel("Flights") 
# plt.tick_params(axis='x', colors='red', rotation=45, length=13, width=3)

plt.show()
# df_org.set_index("Origin", inplace=True)
# df_org[[ 'Not_Delayed', 'Delayed']].head(10).plot(kind='bar',stacked=True)
# df_org[ 'Percent Of Delayed'].plot(secondary_y=True)
# plt.show()

# %%
# top 10 departure time blocks and the percentage of delayed flight vs total flights.
df_dep_time=pd.DataFrame(jan_19_clean.groupby(["DEP_TIME_BLK","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["DEP_TIME_BLK","Not_Delayed","Delayed"])
df_dep_time["PercentOfDelayed"]=df_dep_time.Delayed /( df_dep_time.Delayed+ df_dep_time.Not_Delayed)
df_dep_time.sort_values(by="PercentOfDelayed",ascending=False,inplace=True)
df_dep_time.head(18)
# Out:
#    DEP_TIME_BLK Not_Delayed Delayed PercentOfDelayed
# 14    1900-1959       23195    7566         0.245961
# 13    1800-1859       25482    7894         0.236517
# 15    2000-2059       19431    5750         0.228347
# 16    2100-2159       13244    3889         0.226989
# 12    1700-1759       27955    8143          0.22558
# 11    1600-1659       26913    7342         0.214334
# 9     1400-1459       27507    7279         0.209251
# 10    1500-1559       27704    7240         0.207189
# 8     1300-1359       26108    6402         0.196924
# 17    2200-2259       10260    2336         0.185456
# 7     1200-1259       29357    6497         0.181207
# 18    2300-2359        2913     609         0.172913
# 6     1100-1159       29788    5983         0.167258
# 5     1000-1059       29165    5465         0.157811
# 4     0900-0959       29121    4371         0.130509
# 3     0800-0859       33814    4054         0.107056
# 2     0700-0759       33903    3366        0.0903163
# ...

# %%
#It seems most of the flights are in the morning. But higher percentage of delay occurs after 1700
df_dep_time.sort_values(by="DEP_TIME_BLK",inplace=True)
df_dep_time.head(20)
# Out:
#    DEP_TIME_BLK Not_Delayed Delayed PercentOfDelayed
# 0     0001-0559       14007    1294        0.0845696
# 1     0600-0659       37791    2825        0.0695539
# 2     0700-0759       33903    3366        0.0903163
# 3     0800-0859       33814    4054         0.107056
# 4     0900-0959       29121    4371         0.130509
# 5     1000-1059       29165    5465         0.157811
# 6     1100-1159       29788    5983         0.167258
# 7     1200-1259       29357    6497         0.181207
# 8     1300-1359       26108    6402         0.196924
# 9     1400-1459       27507    7279         0.209251
# 10    1500-1559       27704    7240         0.207189
# 11    1600-1659       26913    7342         0.214334
# 12    1700-1759       27955    8143          0.22558
# 13    1800-1859       25482    7894         0.236517
# 14    1900-1959       23195    7566         0.245961
# 15    2000-2059       19431    5750         0.228347
# 16    2100-2159       13244    3889         0.226989
# ...

# %%
df_dep_time[['DEP_TIME_BLK', 'Not_Delayed', 'Delayed']].set_index("DEP_TIME_BLK").plot(kind='bar',stacked=True)
# df_carrier[['Carrier', 'Percent Of Delayed']].set_index("Carrier").plot.line()
plt.title("Flights Delay per Departure Time Block January 2019")
plt.xlabel('Departure Time Block')
plt.ylabel('Flights')
plt.show()

# %%
# Its clearly seen that most of the flights are on the 4th day. Nearly %20 of flights are delayed of 6th day.
df_weekday=pd.DataFrame(jan_19_clean.groupby(["DAY_OF_WEEK","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Weekday","Not_Delayed","Delayed"])
df_weekday["PercentOfDelayed"]=df_weekday.Delayed /( df_weekday.Delayed+ df_weekday.Not_Delayed)
df_weekday.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_weekday.head(10)
# Out:
#    Weekday  Not_Delayed  Delayed  PercentOfDelayed
# 3        4        77444    19029          0.197247
# 2        3        76585    16758          0.179531
# 1        2        75431    14251          0.158906
# 4        5        65131    13523          0.171930
# 0        1        63320    13485          0.175575
# 6        7        58367    12493          0.176305
# 5        6        51380     8766          0.145745

# %%
df_weekday.sort_values(by="Weekday",inplace=True)
df_weekday.head(7)
# Out:
#    Weekday  Not_Delayed  Delayed  PercentOfDelayed
# 0        1        63320    13485          0.175575
# 1        2        75431    14251          0.158906
# 2        3        76585    16758          0.179531
# 3        4        77444    19029          0.197247
# 4        5        65131    13523          0.171930
# 5        6        51380     8766          0.145745
# 6        7        58367    12493          0.176305

# %%
df_weekday[['Weekday', 'Not_Delayed', 'Delayed']].set_index("Weekday").plot(kind='bar', stacked=True)

plt.show()

# %%
# Cut the per distance into the distance ranges.
distance = jan_19_clean["DISTANCE"]
# distance_bins = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
# distance_bins = [0, 1000,2000,3000, 4000, 5000]
distance_bins = [0, 250, 500, 750, 1000, 1500, 2000, 2500, 5000]
distance.groupby(pd.cut(distance, distance_bins)).count()
# Out:
# DISTANCE
# (0, 250]         73959
# (250, 500]      141246
# (500, 750]      108819
# (750, 1000]      85846
# (1000, 1500]     87713
# (1500, 2000]     35223
# (2000, 2500]     22389
# (2500, 5000]     10768
# Name: DISTANCE, dtype: int64

# %%
# Establish the distance bins and group names.
# distance_bins = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
# group_names = ["<100", "100-500", "500-1000", "1000-1500", "1500-2000", "2000-2500", "2500-3000", "3000-3500", "3500-4000", "4000-4500", "4500-5000"]
# distance_bins = [0, 1000,2000,3000, 4000, 5000]
distance_bins = [0, 250, 500, 750, 1000, 1500, 2000, 2500, 5000]
# group_names = ["<1000", "1000-2000", "2000-3000", "3000-4000", "4000-5000"]
group_names = ["<250", "250-500", "500-750", "750-1000", "1000-1500", "1500-2000", "2000-2500", "2500-5000"]

# %%
# Categorize distance based on the bins.
jan_19_clean["Distance Range (in Miles)"] = pd.cut(distance, distance_bins, labels=group_names)

jan_19_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED DIVERTED  \
# ...

# %%
# Establishing percentage of delay per distance range
df_distance=pd.DataFrame(jan_19_clean.groupby(["Distance Range (in Miles)","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Distance","Not_Delayed","Delayed"])
df_distance["PercentOfDelayed"]=df_distance.Delayed /(df_distance.Delayed+ df_distance.Not_Delayed)
df_distance.sort_values(by="PercentOfDelayed",ascending=False,inplace=True)
df_distance.head()
# Out:
#     Distance Not_Delayed Delayed PercentOfDelayed
# 5  1500-2000       28648    6575         0.186668
# 4  1000-1500       71356   16357         0.186483
# 7  2500-5000        8812    1956         0.181649
# 2    500-750       89461   19358         0.177892
# 3   750-1000       70904   14942         0.174056

# %%
x_axis = df_distance["Distance"]
y_axis = df_distance["PercentOfDelayed"]
explode_values = (0.2, 0, 0, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27a04631e48>,
# ...
#  [Text(1.186771096979416, 0.5306358104899, '1500-2000'),
#   Text(0.3353853707913275, 1.0476242900291899, '1000-1500'),
#   Text(-0.5459698615671256, 0.9549434068364333, '2500-5000'),
#   Text(-1.068059302498132, 0.2631526673761903, '500-750'),
#   Text(-0.9371012348166513, -0.5760566601516794, '750-1000'),
#   Text(-0.2710125733175673, -1.0660920153081488, '250-500'),
#   Text(0.5192119811202615, -0.9697519882223359, '2000-2500'),
#   Text(1.0299994481705919, -0.38613616350748137, '<250')],
#  [Text(0.7303206750642561, 0.32654511414763077, '13.4%'),
#   Text(0.1829374749770877, 0.5714314309250126, '13.4%'),
#   Text(-0.29780174267297754, 0.5208782219107818, '13.0%'),
#   Text(-0.5825778013626174, 0.14353781856883105, '12.8%'),
#   Text(-0.5111461280818098, -0.3142127237190978, '12.5%'),
#   Text(-0.14782503999140031, -0.5815047356226266, '12.1%'),
#   Text(0.28320653515650623, -0.5289556299394559, '11.5%'),
# ...

# %% [markdown]
# # January 2020 Flights Visuals

# %%
jan_20_join = jan_20_clean.merge(airline_codes_df, on ="OP_CARRIER", how="left")
jan_20_join.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            3                    20366         EV   N48901
# 1             1            3                    20366         EV   N16976
# 2             1            3                    20366         EV   N12167
# 3             1            3                    20366         EV   N14902
# 4             1            3                    20366         EV   N606UX
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               4397              13930                1393007    ORD
# 1               4401              15370                1537002    TUL
# 2               4404              11618                1161802    EWR
# 3               4405              10781                1078105    BTR
# 4               4407              14524                1452401    RIC
#
#    DEST_AIRPORT_ID  ...  DEP_TIME DEP_DEL15  DEP_TIME_BLK  ARR_TIME ARR_DEL15  \
# ...

# %%
jan_20_clean = jan_20_join.drop("OP_CARRIER_AIRLINE_ID_y", axis=1)
jan_20_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            3                    20366         EV   N48901
# 1             1            3                    20366         EV   N16976
# 2             1            3                    20366         EV   N12167
# 3             1            3                    20366         EV   N14902
# 4             1            3                    20366         EV   N606UX
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               4397              13930                1393007    ORD
# 1               4401              15370                1537002    TUL
# 2               4404              11618                1161802    EWR
# 3               4405              10781                1078105    BTR
# 4               4407              14524                1452401    RIC
#
#    DEST_AIRPORT_ID  ...  DEST DEP_TIME  DEP_DEL15  DEP_TIME_BLK ARR_TIME  \
# ...

# %%
jan_20_join = jan_20_clean.merge(airport_codes_df, on ="ORIGIN", how="left")
jan_20_join.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            3                    20366         EV   N48901
# 1             1            3                    20366         EV   N16976
# 2             1            3                    20366         EV   N12167
# 3             1            3                    20366         EV   N14902
# 4             1            3                    20366         EV   N606UX
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               4397              13930                1393007    ORD
# 1               4401              15370                1537002    TUL
# 2               4404              11618                1161802    EWR
# 3               4405              10781                1078105    BTR
# 4               4407              14524                1452401    RIC
#
#    DEST_AIRPORT_ID  ...  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  \
# ...

# %%
jan_20_clean = jan_20_join
jan_20_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            3                    20366         EV   N48901
# 1             1            3                    20366         EV   N16976
# 2             1            3                    20366         EV   N12167
# 3             1            3                    20366         EV   N14902
# 4             1            3                    20366         EV   N606UX
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               4397              13930                1393007    ORD
# 1               4401              15370                1537002    TUL
# 2               4404              11618                1161802    EWR
# 3               4405              10781                1078105    BTR
# 4               4407              14524                1452401    RIC
#
#    DEST_AIRPORT_ID  ...  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  \
# ...

# %%
# Airlines and the percentage of delayed flight vs total flights.
df_carrier=pd.DataFrame(jan_20_clean.groupby(["OP_CARRIER_NAME","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Carrier","Not_Delayed","Delayed"])
df_carrier["Percent Of Delayed"]=df_carrier.Delayed /( df_carrier.Delayed+ df_carrier.Not_Delayed)
df_carrier.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_carrier.head(18)
# Out:
#                         Carrier Not_Delayed Delayed Percent Of Delayed
# 14           Southwest Airlines       94378   13330           0.123761
# 5               Delta Air Lines       71858    8070           0.100966
# 2             American Airlines       64516   10956           0.145166
# 13             SkyWest Airlines       58751   10750           0.154674
# 16              United Airlines       41885    6134           0.127741
# 12             Midwest Airlines       25870    2956           0.102546
# 7                     Envoy Air       21031    4253           0.168209
# 10                     Jet Blue       20907    3714           0.150847
# 6                  Endeavor Air       20390    2565            0.11174
# 4                        Comair       19362    4637           0.193216
# 0               Alaska Airlines       16950    3833            0.18443
# 15              Spirit Airlines       14942    2391           0.137945
# ...

# %%
# df_carrier.set_index("Carrier", inplace=True)
# df_carrier[[ 'Not_Delayed', 'Delayed']].plot(kind='bar',stacked=True)
# df_carrier[ 'Percent Of Delayed'].plot(secondary_y=True)
# plt.show()

# %%
df_carrier.set_index("Carrier", inplace=True)
df_carrier[['Not_Delayed', 'Delayed']].plot(kind='bar',stacked=True)
plt.xlabel("Airline") 
plt.ylabel("Flights")
plt.show()

# %%
# Top 10 origin airports and the percentage of delayed flight vs total flights.
df_org=pd.DataFrame(jan_20_clean.groupby(["CITY","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Origin","Not_Delayed","Delayed"])
df_org["Percent Of Delayed"]=df_org.Delayed /( df_org.Delayed+ df_org.Not_Delayed)
df_org.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_org.head(10)
# Out:
#                                      Origin Not_Delayed Delayed  \
# 15                                  Atlanta       28405    3619
# 58                         Chicago - O'Hare       20687    4079
# 71                        Dallas/Fort Worth       19287    4531
# 74                                   Denver       17414    2739
# 53                                Charlotte       16823    3046
# 171                             Los Angeles       15270    2377
# 224                                 Phoenix       13352    1839
# 128  Houston - George Bush Intercontinental       12871    1806
# 159                               Las Vegas       12348    1739
# 201                   New York - La Guardia       11896    1820
#
#     Percent Of Delayed
# 15            0.113009
# 58            0.164702
# 71            0.190234
# 74             0.13591
# 53            0.153304
# 171           0.134697
# 224           0.121059
# 128            0.12305
# 159           0.123447
# ...

# %%
df_org[['Origin', 'Not_Delayed', 'Delayed']].head(10).set_index("Origin").plot(kind='bar',stacked=True)
plt.xlabel("Airport Departure") 
plt.ylabel("Flights") 
plt.show()

# %%
# top 10 departure time blocks and the percentage of delayed flight vs total flights.
df_dep_time=pd.DataFrame(jan_20_clean.groupby(["DEP_TIME_BLK","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["DEP_TIME_BLK","Not_Delayed","Delayed"])
df_dep_time["PercentOfDelayed"]=df_dep_time.Delayed /( df_dep_time.Delayed+ df_dep_time.Not_Delayed)
df_dep_time.sort_values(by="PercentOfDelayed",ascending=False,inplace=True)
df_dep_time.head(18)
# Out:
#    DEP_TIME_BLK Not_Delayed Delayed PercentOfDelayed
# 14    1900-1959       26632    5925         0.181989
# 13    1800-1859       28336    6194          0.17938
# 15    2000-2059       23810    5043         0.174783
# 12    1700-1759       32502    6690         0.170698
# 16    2100-2159       15545    3149          0.16845
# 11    1600-1659       29608    5962         0.167613
# 10    1500-1559       29866    5764         0.161774
# 9     1400-1459       29643    5641         0.159874
# 17    2200-2259       11945    2112         0.150245
# 8     1300-1359       29081    5064         0.148309
# 18    2300-2359        3637     629         0.147445
# 7     1200-1259       32301    5321         0.141433
# 5     1000-1059       30968    4705         0.131892
# 6     1100-1159       32770    4930         0.130769
# 4     0900-0959       32405    3931         0.108185
# 3     0800-0859       35405    3616        0.0926681
# 0     0001-0559       14921    1191        0.0739201
# ...

# %%
df_dep_time[['DEP_TIME_BLK', 'Not_Delayed', 'Delayed']].set_index("DEP_TIME_BLK").plot(kind='bar',stacked=True)
# df_carrier[['Carrier', 'Percent Of Delayed']].set_index("Carrier").plot.line()
plt.title("Flights Delay per Departure Time Block January 2020")
plt.xlabel('Departure Time Block')
plt.ylabel('Flights')
plt.show()

# %%
# Its clearly seen that most of the flights are on the 4th day. Nearly %20 of flights are delayed of 6th day.
df_weekday=pd.DataFrame(jan_20_clean.groupby(["DAY_OF_WEEK","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Weekday","Not_Delayed","Delayed"])
df_weekday["PercentOfDelayed"]=df_weekday.Delayed /( df_weekday.Delayed+ df_weekday.Not_Delayed)
df_weekday.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_weekday.head(10)
# Out:
#    Weekday  Not_Delayed  Delayed  PercentOfDelayed
# 3        4        89124    13879          0.134744
# 2        3        86768     9519          0.098861
# 4        5        85021    15703          0.155901
# 0        1        70547    11125          0.136216
# 1        2        68512     7526          0.098977
# 6        7        66718    11292          0.144751
# 5        6        51131    12403          0.195218

# %%
df_weekday[['Weekday', 'Not_Delayed', 'Delayed']].set_index("Weekday").plot(kind='bar', stacked=True)

plt.show()

# %%
# Cut the per distance into the distance ranges.
distance = jan_20_clean["DISTANCE"]
# distance_bins = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
# distance_bins = [0, 1000,2000,3000, 4000, 5000]
distance_bins = [0, 250, 500, 750, 1000, 1500, 2000, 2500, 5000]
distance.groupby(pd.cut(distance, distance_bins)).count()
# Out:
# DISTANCE
# (0, 250]         77423
# (250, 500]      148258
# (500, 750]      117320
# (750, 1000]      92209
# (1000, 1500]     93501
# (1500, 2000]     36446
# (2000, 2500]     23121
# (2500, 5000]     10947
# Name: DISTANCE, dtype: int64

# %%
# Establish the distance bins and group names.
# distance_bins = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
# group_names = ["<100", "100-500", "500-1000", "1000-1500", "1500-2000", "2000-2500", "2500-3000", "3000-3500", "3500-4000", "4000-4500", "4500-5000"]
# distance_bins = [0, 1000,2000,3000, 4000, 5000]
distance_bins = [0, 250, 500, 750, 1000, 1500, 2000, 2500, 5000]
# group_names = ["<1000", "1000-2000", "2000-3000", "3000-4000", "4000-5000"]
group_names = ["<250", "250-500", "500-750", "750-1000", "1000-1500", "1500-2000", "2000-2500", "2500-5000"]

# %%
# Categorize distance based on the bins.
jan_20_clean["Distance Range (in Miles)"] = pd.cut(distance, distance_bins, labels=group_names)

jan_20_clean.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            3                    20366         EV   N48901
# 1             1            3                    20366         EV   N16976
# 2             1            3                    20366         EV   N12167
# 3             1            3                    20366         EV   N14902
# 4             1            3                    20366         EV   N606UX
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               4397              13930                1393007    ORD
# 1               4401              15370                1537002    TUL
# 2               4404              11618                1161802    EWR
# 3               4405              10781                1078105    BTR
# 4               4407              14524                1452401    RIC
#
#    DEST_AIRPORT_ID  ...  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED DIVERTED  \
# ...

# %%
# Establishing percentage of delay per distance range
df_distance=pd.DataFrame(jan_20_clean.groupby(["Distance Range (in Miles)","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Distance","Not_Delayed","Delayed"])
df_distance["PercentOfDelayed"]=df_distance.Delayed /(df_distance.Delayed+ df_distance.Not_Delayed)
df_distance.sort_values(by="PercentOfDelayed",ascending=False,inplace=True)
df_distance.head(8)
# Out:
#     Distance Not_Delayed Delayed PercentOfDelayed
# 7  2500-5000        9286    1661         0.151731
# 5  1500-2000       31081    5365         0.147204
# 4  1000-1500       79902   13599         0.145442
# 3   750-1000       79614   12595         0.136592
# 0       <250       66885   10538         0.136109
# 2    500-750      101596   15724         0.134027
# 6  2000-2500       20052    3069         0.132736
# 1    250-500      129370   18888           0.1274

# %%
labels = df_distance["Distance"]
sizes = df_distance["PercentOfDelayed"]
explode_values = (0.2, 0, 0, 0, 0, 0, 0, 0)
plt.pie(sizes, explode=explode_values, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27a0527f408>,
# ...
#  [Text(1.1822188628946546, 0.5407019143817323, '2500-5000'),
#   Text(0.32162037981851754, 1.0519317141741629, '1500-2000'),
#   Text(-0.5566790465310888, 0.9487404487810341, '1000-1500'),
#   Text(-1.067726806655141, 0.26449851861591817, '750-1000'),
#   Text(-0.9501306323069717, -0.5543029690989886, '<250'),
#   Text(-0.30290495352023183, -1.0574727368272463, '500-750'),
#   Text(0.5032618205899557, -0.9781245012453595, '2000-2500'),
#   Text(1.02942002226501, -0.3876782399876299, '250-500')],
#  [Text(0.7275193002428643, 0.33273963961952757, '13.7%'),
#   Text(0.17542929808282773, 0.5737809350040888, '13.2%'),
#   Text(-0.30364311628968477, 0.5174947902442004, '13.1%'),
#   Text(-0.5823964399937133, 0.14427191924504626, '12.3%'),
#   Text(-0.518253072167439, -0.3023470740539937, '12.2%'),
#   Text(-0.16522088373830826, -0.5768033109966797, '12.1%'),
#   Text(0.27450644759452125, -0.5335224552247415, '11.9%'),
# ...

# %%
flights = pd.concat([jan_19_clean, jan_20_clean])
flights.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED DIVERTED  \
# ...

# %%
# Airlines and the percentage of delayed flight vs total flights.
df_carrier=pd.DataFrame(flights.groupby(["OP_CARRIER_NAME","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Carrier","Not_Delayed","Delayed"])
df_carrier["Percent Of Delayed"]=df_carrier.Delayed /( df_carrier.Delayed+ df_carrier.Not_Delayed)
df_carrier.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_carrier
# Out:
#                         Carrier Not_Delayed Delayed Percent Of Delayed
# 14           Southwest Airlines      183147   31796           0.147928
# 5               Delta Air Lines      135848   17483           0.114021
# 2             American Airlines      127877   22949           0.152155
# 13             SkyWest Airlines      107941   23330           0.177724
# 16              United Airlines       79653   14492           0.153933
# 12             Midwest Airlines       45649    7746            0.14507
# 7                     Envoy Air       40047    8947           0.182614
# 4                        Comair       38430    7938           0.171196
# 10                     Jet Blue       37981   10035           0.208993
# 6                  Endeavor Air       36482    6294           0.147139
# 0               Alaska Airlines       34422    6565           0.160173
# 11                Mesa Airlines       29623    5679           0.160869
# ...

# %%
df_carrier.set_index("Carrier", inplace=True)
df_carrier[[ 'Not_Delayed', 'Delayed']].plot(kind='bar',stacked=True)
plt.xlabel("Airline") 
plt.ylabel("Flights")
plt.show()

# %%
# Its clearly seen that most of the flights are on the 4th day. Nearly %20 of flights are delayed of 6th day.
df_weekday=pd.DataFrame(flights.groupby(["DAY_OF_WEEK","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Weekday","Not_Delayed","Delayed"])
df_weekday["PercentOfDelayed"]=df_weekday.Delayed /( df_weekday.Delayed+ df_weekday.Not_Delayed)
df_weekday.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_weekday.head(10)
# Out:
#    Weekday  Not_Delayed  Delayed  PercentOfDelayed
# 3        4       166568    32908          0.164972
# 2        3       163353    26277          0.138570
# 4        5       150152    29226          0.162930
# 1        2       143943    21777          0.131408
# 0        1       133867    24610          0.155291
# 6        7       125085    23785          0.159770
# 5        6       102511    21169          0.171159

# %%
df_weekday[['Weekday', 'Not_Delayed', 'Delayed']].set_index("Weekday").plot(kind='bar', stacked=True)

plt.show()

# %%
# top 10 departure time blocks and the percentage of delayed flight vs total flights.
df_dep_time=pd.DataFrame(flights.groupby(["DEP_TIME_BLK","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["DEP_TIME_BLK","Not_Delayed","Delayed"])
df_dep_time['Percent_Of_Delayed']=df_dep_time.Delayed /( df_dep_time.Delayed+ df_dep_time.Not_Delayed)
df_dep_time.sort_values(by='Percent_Of_Delayed',ascending=False,inplace=True)
df_dep_time.head(18)
# Out:
#    DEP_TIME_BLK Not_Delayed Delayed Percent_Of_Delayed
# 14    1900-1959       49827   13491           0.213067
# 13    1800-1859       53818   14088           0.207463
# 15    2000-2059       43241   10793           0.199745
# 12    1700-1759       60457   14833           0.197012
# 16    2100-2159       28789    7038           0.196444
# 11    1600-1659       56521   13304           0.190533
# 9     1400-1459       57150   12920           0.184387
# 10    1500-1559       57570   13004            0.18426
# 8     1300-1359       55189   11466            0.17202
# 17    2200-2259       22205    4448           0.166886
# 7     1200-1259       61658   11818           0.160842
# 18    2300-2359        6550    1238           0.158963
# 6     1100-1159       62558   10913           0.148535
# 5     1000-1059       60133   10170            0.14466
# 4     0900-0959       61526    8302           0.118892
# 3     0800-0859       69219    7670          0.0997542
# ...

# %%
df_dep_time[['DEP_TIME_BLK',"Percent_Of_Delayed"]].set_index("DEP_TIME_BLK").plot(kind='bar',stacked=True)
# df_carrier[['Carrier', 'Percent Of Delayed']].set_index("Carrier").plot.line()
plt.title("Flights Delay per Departure Time Block January 2019 and 2020")
plt.xlabel('Departure Time Block')
plt.ylabel('Percentage of Delay')
plt.show()

# %%
# Cut the per distance into the distance ranges.
distance = flights["DISTANCE"]
distance_bins = [0, 250, 500, 750, 1000, 1500, 2000, 2500, 5000]
distance.groupby(pd.cut(distance, distance_bins)).count()
# Out:
# DISTANCE
# (0, 250]        151382
# (250, 500]      289504
# (500, 750]      226139
# (750, 1000]     178055
# (1000, 1500]    181214
# (1500, 2000]     71669
# (2000, 2500]     45510
# (2500, 5000]     21715
# Name: DISTANCE, dtype: int64

# %%
# Establish the distance bins and group names.
distance_bins = [0, 250, 500, 750, 1000, 1500, 2000, 2500, 5000]
group_names = ["<250", "250-500", "500-750", "750-1000", "1000-1500", "1500-2000", "2000-2500", "2500-5000"]

# %%
# Categorize distance based on the bins.
flights["Distance Range (in Miles)"] = pd.cut(distance, distance_bins, labels=group_names)

flights.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID_x OP_CARRIER TAIL_NUM  \
# 0             1            2                    20363         9E   N8688C
# 1             1            2                    20363         9E   N348PQ
# 2             1            2                    20363         9E   N8896A
# 3             1            2                    20363         9E   N8886A
# 4             1            2                    20363         9E   N8974C
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0               3280              11953                1195302    GNV
# 1               3281              13487                1348702    MSP
# 2               3282              11433                1143302    DTW
# 3               3283              15249                1524906    TLH
# 4               3284              10397                1039707    ATL
#
#    DEST_AIRPORT_ID  ...  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED DIVERTED  \
# ...

# %%
# Establishing percentage of delay per distance range
df_distance=pd.DataFrame(flights.groupby(["Distance Range (in Miles)","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Distance","Not_Delayed","Delayed"])
df_distance["PercentOfDelayed"]=df_distance.Delayed /(df_distance.Delayed+ df_distance.Not_Delayed)
df_distance.sort_values(by="PercentOfDelayed",ascending=False,inplace=True)
df_distance.head(8)
# Out:
#     Distance Not_Delayed Delayed PercentOfDelayed
# 5  1500-2000       59729   11940         0.166599
# 7  2500-5000       18098    3617         0.166567
# 4  1000-1500      151258   29956         0.165307
# 2    500-750      191057   35082         0.155135
# 3   750-1000      150518   27537         0.154654
# 0       <250      129067   22315         0.147409
# 1    250-500      246873   42631         0.147255
# 6  2000-2500       38844    6666         0.146473

# %%
x_axis = df_distance["Distance"]
y_axis = df_distance["PercentOfDelayed"]
explode_values = (0.2, 0, 0, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27a389128c8>,
# ...
#  [Text(1.1875923250522256, 0.5287953001654321, '1500-2000'),
#   Text(0.33990422674644133, 1.046166868448769, '2500-5000'),
#   Text(-0.5468985995358262, 0.9544118198271395, '1000-1500'),
#   Text(-1.0672298269007916, 0.26649671024856314, '500-750'),
#   Text(-0.9467133116623748, -0.5601195457411385, '750-1000'),
#   Text(-0.3008288473472025, -1.0580652175569112, '<250'),
#   Text(0.49219993691514996, -0.9837373745572151, '250-500'),
#   Text(1.0262331704629386, -0.39603722027302596, '2000-2500')],
#  [Text(0.7308260461859848, 0.32541249240949666, '13.3%'),
#   Text(0.1854023054980589, 0.5706364736993285, '13.3%'),
#   Text(-0.2983083270195415, 0.5205882653602579, '13.2%'),
#   Text(-0.5821253601277044, 0.1453618419537617, '12.4%'),
#   Text(-0.516389079088568, -0.30551975222243916, '12.4%'),
#   Text(-0.16408846218938317, -0.5771264823037696, '11.8%'),
#   Text(0.26847269286280906, -0.5365840224857537, '11.8%'),
# ...

# %%
# Top 10 origin airports and the percentage of delayed flight vs total flights.
df_org=pd.DataFrame(flights.groupby(["CITY","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Origin","Not_Delayed","Delayed"])
df_org["Percent Of Delayed"]=df_org.Delayed /( df_org.Delayed+ df_org.Not_Delayed)
df_org.sort_values(by="In the data",ascending=False,inplace=True)
df_org.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-3b60e4e7f3e8> in <module>
#       2 df_org=pd.DataFrame(flights.groupby(["CITY","DEP_DEL15"])["ORIGIN_AIRPORT_ID"].count().unstack("DEP_DEL15").reset_index().values,columns=["Origin","Not_Delayed","Delayed"])
#       3 df_org["Percent Of Delayed"]=df_org.Delayed /( df_org.Delayed+ df_org.Not_Delayed)
# ----> 4 df_org.sort_values(by="In the data",ascending=False,inplace=True)
#       5 df_org.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ...

# %%
df_org[['Origin', 'Not_Delayed', 'Delayed']].head(10).set_index("Origin").plot(kind='bar',stacked=True)
plt.xlabel("Airport Departure") 
plt.ylabel("Flights") 
plt.show()
