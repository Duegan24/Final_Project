# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("postgres://postgres:faB17&rigeme@flightsdata.cxtoxxxge4vx.us-east-2.rds.amazonaws.com/flightsdata")

# %%
full_flight_df = pd.read_sql_query("SELECT * FROM full_flight_2019", engine)

# %%
full_flight_df
# Out:
#        origin                               origin_city day_of_month  \
# 0         BOS  boston,ma                                  2019-01-31
# 1         BOS  boston,ma                                  2019-01-31
# 2         BOS  boston,ma                                  2019-01-31
# 3         BOS  boston,ma                                  2019-01-31
# 4         BOS  boston,ma                                  2019-01-31
# ...       ...                                       ...          ...
# 545335    BOS  boston,ma                                  2019-01-31
# 545336    BOS  boston,ma                                  2019-01-31
# 545337    BOS  boston,ma                                  2019-01-31
# 545338    BOS  boston,ma                                  2019-01-31
# 545339    BOS  boston,ma                                  2019-01-31
#
#        op_carrier_airline_id op_carrier tail_num op_carrier_fl_num  \
# 0                      20409   Jet Blue   N203JB              1189
# ...

# %%
full_flight_df.to_csv("full_flight.csv", index=False)
