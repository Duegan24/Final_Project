# %%
#Import requests library and API key
import requests
from config import weather_api_key

# Import Dependencies
import pandas as pd

# Import Historical API Package
from wwo_hist import retrieve_hist_data

# Import glob dependncies
import os, glob

# %%
# Import CSV
city_code_api_df = pd.read_csv('../../../../Flight_data_files/city_code_api.csv',index_col='Unnamed: 0')
city_code_api_df
# Out:
#     Airport Code           City
# 0            ABR    aberdeen,sd
# 1            ABI     abilene,tx
# 2            ADK  adakisland,ak
# 3            CAK       akron,oh
# 4            ALB      albany,ny
# ..           ...            ...
# 342          OGD       ogden,ut
# 343          LYH   lynchburg,va
# 344          XWA   williston,nd
# 345          PAE     everett,wa
# 346          BFM      mobile,al
#
# [347 rows x 2 columns]

# %%
cities_unique = []
for city in city_code_api_df['City']:
    if city not in cities_unique:
        cities_unique.append(city)
print(cities_unique)
# Out:
# ['aberdeen,sd', 'abilene,tx', 'adakisland,ak', 'akron,oh', 'albany,ny', 'albuquerque,nm', 'alexandria,la', 'easton,pa', 'alpena,mi', 'amarillo,tx', 'anchorage,ak', 'appleton,wi', 'arcata,ca', 'asheville,nc', 'huntington,wv', 'aspen,co', 'atlanta,ga', 'augusta,ga', 'austin,tx', 'bakersfield,ca', 'baltimore,md', 'bangor,me', 'barrow,ak', 'batonrouge,la', 'saginaw,mi', 'beaumont,tx', 'belleville,il', 'bellingham,wa', 'bemidji,mn', 'bethel,ak', 'billings,mt', 'gulfport,ms', 'johnsoncity,ny', 'birmingham,al', 'bismarck,nd', 'bloomington,il', 'boise,id', 'boston,ma', 'bozeman,mt', 'brainerd,mn', 'bristol,tn', 'brownsville,tx', 'brunswick,ga', 'buffalo,ny', 'burbank,ca', 'burlington,vt', 'butte,mt', 'capegirardeau,mo', 'monterey,ca', 'casper,wy', 'cedarcity,ut', 'cedarrapids,ia', 'champaign,il', 'charleston,sc', 'charleston,wv', 'charlotte,nc', 'charlottesville,va', 'chattanooga,tn', 'cheyenne,wy', 'chicago,il', 'hibbing,mn', 'cincinnati,oh', 'clarksburg,wv', 'stpetersburg,fl', 'cleveland,oh', 'yellowstone,wy', 'collegestation,tx', 'coloradosprings,co', 'columbia,mo', 'columbia,sc', 'columbus,ga', 'columbus,ms', 'columbus,oh', 'cordova,ak', 'corpuschristi,tx', 'fortworth,tx', 'dayton,oh', 'daytonabeach,fl', 'denver,co', 'desmoines,ia', 'detroit,mi', "devil'slake,nd", 'dothan,al', 'dubuque,ia', 'duluth,mn', 'durango,co', 'durham,nc', 'eauclaire,wi', 'elpaso,tx', 'elko,nv', 'elmira,ny', 'erie,pa', 'escanaba,mi', 'eugene,or', 'evansville,in', 'fairbanks,ak', 'fargo,nd', 'fayetteville,ar', 'fayetteville,nc', 'flagstaff,az', 'flint,mi', 'fortlauderdale,fl', 'fortmyers,fl', 'fortsmith,ar', 'valparaiso,fl', 'fortwayne,in', 'fresno,ca', 'gainesville,fl', 'gardencity,ks', 'gillette,wy', 'longview,tx', 'grandforks,nd', 'grandisland,ne', 'grandjunction,co', 'grandrapids,mi', 'greatfalls,mt', 'greenbay,wi', 'greensboro,nc', 'greer,sc', 'gunnison,co', 'hagerstown,md', 'sunvalley,id', 'newportnews,va', 'hancock,mi', 'harlingen,tx', 'harrisburg,pa', 'windsorlocks,ct', 'hayden,co', 'hays,ks', 'helena,mt', 'hilo,hi', 'hiltonhead,sc', 'honolulu,hi', 'houston,tx', 'huntsville,al', 'idahofalls,id', 'indianapolis,in', 'internationalfalls,mn', 'ironmountain,mi', 'islip,ny', 'ithaca,ny', 'jacksonhole,wy', 'jackson,ms', 'jacksonville,fl', 'jacksonville,nc', 'jamestown,nd', 'joplin,mo', 'juneau,ak', 'kahului-maui,hi', 'kalamazoo,mi', 'kansascity,mo', 'kauai,hi', 'kearney,ne', 'ketchikan,ak', 'keywest,fl', 'knoxville,tn', 'kodiak,ak', 'kona,hi', 'kotzebue,ak', 'lacrosse,wi', 'lafayette,la', 'lakecharles,la', 'lansing,mi', 'laramie,wy', 'laredo,tx', 'lasvegas,nv', 'latrobe,pa', 'laurel,ms', 'lawton,ok', 'lewisburg,wv', 'lewiston,id', 'lexington,ky', 'liberal,ks', 'lincoln,ne', 'littlerock,ar', 'longbeach,ca', 'losangeles,ca', 'louisville,ky', 'lubbock,tx', 'madison,wi', 'manchester,nh', 'manhattan,ks', 'marquette,mi', 'mcallen,tx', 'medford,or', 'melbourne,fl', 'memphis,tn', 'meridian,ms', 'miami,fl', 'odessa,tx', 'milwaukee,wi', 'minneapolis,mn', 'minot,nd', 'missoula,mt', 'moab,ut', 'mobile,al', 'moline,il', 'monroe,la', 'montgomery,al', 'montrose,co', 'muskegon,mi', 'myrtlebeach,sc', 'nashville,tn', 'newhaven,ct', 'neworleans,la', 'newyork,ny', 'newark,nj', 'stewartfield,ny', 'nome,ak', 'norfolk,va', 'northbend,or', 'northplatte,ne', 'oakland,ca', 'ogdensburg,ny', 'oklahomacity,ok', 'omaha,ne', 'ontario,ca', 'santaana,ca', 'orlando,fl', 'owensboro,ky', 'paducah,ky', 'palmsprings,ca', 'pasco,wa', 'pellston,mi', 'pensacola,fl', 'peoria,il', 'petersburg,ak', 'philadelphia,pa', 'trenton,nj', 'phoenix,az', 'pierre,sd', 'pittsburgh,pa', 'pocatello,id', 'ponce,pr', 'portland,me', 'portland,or', 'portsmouth,nh', 'prescott,az', 'providence,ri', 'prudhoebay,ak', 'pueblo,co', 'quincy,il', 'rapidcity,sd', 'redding,ca', 'redmond,or', 'reno,nv', 'rhinelander,wi,', 'richmond,va', 'riverton,wy', 'roanoke,va', 'rochester,mn', 'rochester,ny', 'rocksprings,wy', 'roswell,nm', 'sacramento,ca', 'saintcloud,mn', 'saintgeorge,ut', 'saintlouis,mo', 'salina,ks', 'saltlakecity,ut', ' ...

# %%
start_date = '01-JAN-2020'
end_date = '31-JAN-2020'
location_list = cities_unique
frequency = 1

# %%
hist_weather_data_2020 = retrieve_hist_data(weather_api_key,
                                   location_list,
                                   start_date,
                                   end_date,
                                   frequency,
                                   location_label = False,
                                   export_csv = True,
                                   store_df = True)
# Out:
# Retrieving weather data for aberdeen,sd
#
#
# Currently retrieving data for aberdeen,sd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.878448
#
#
# export aberdeen,sd completed!
#
#
#
#
# Retrieving weather data for abilene,tx
#
#
# Currently retrieving data for abilene,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.872637
#
#
# export abilene,tx completed!
#
#
#
#
# Retrieving weather data for adakisland,ak
#
#
# Currently retrieving data for adakisland,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.360756
#
#
# export adakisland,ak completed!
#
#
#
#
# Retrieving weather data for akron,oh
#
#
# Currently retrieving data for akron,oh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.968691
#
#
# export akron,oh completed!
#
#
#
#
# Retrieving weather data for albany,ny
#
#
# Currently retrieving data for albany,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.475540
#
#
# export albany,ny completed!
#
#
#
#
# Retrieving weather data for albuquerque,nm
#
#
# Currently retrieving data for albuquerque,nm: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.103734
#
#
# export albuquerque,nm completed!
#
#
#
#
# Retrieving weather data for alexandria,la
#
#
# Currently retrieving data for alexandria,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.580150
#
#
# export alexandria,la completed!
#
#
#
#
# Retrieving weather data for easton,pa
#
#
# Currently retrieving data for easton,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.610514
#
#
# export easton,pa completed!
#
#
#
#
# Retrieving weather data for alpena,mi
#
#
# Currently retrieving data for alpena,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.662506
#
#
# export alpena,mi completed!
#
#
#
#
# Retrieving weather data for amarillo,tx
#
#
# Currently retrieving data for amarillo,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.108278
#
#
# export amarillo,tx completed!
#
#
#
#
# Retrieving weather data for anchorage,ak
#
#
# Currently retrieving data for anchorage,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.693852
#
#
# export anchorage,ak completed!
#
#
#
#
# Retrieving weather data for appleton,wi
#
#
# Currently retrieving data for appleton,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.573093
#
#
# export appleton,wi completed!
#
#
#
#
# Retrieving weather data for arcata,ca
#
#
# Currently retrieving data for arcata,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.738781
#
#
# export arcata,ca completed!
#
#
#
#
# Retrieving weather data for asheville,nc
#
#
# Currently retrieving data for asheville,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.465820
#
#
# export asheville,nc completed!
#
#
#
#
# Retrieving weather data for huntington,wv
#
#
# Currently retrieving data for huntington,wv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.319235
#
#
# export huntington,wv completed!
#
#
#
#
# Retrieving weather data for aspen,co
#
#
# Currently retrieving data for aspen,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.462740
#
#
# export aspen,co completed!
#
#
#
#
# Retrieving weather data for atlanta,ga
#
#
# Currently retrieving data for atlanta,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.654757
#
#
# export atlanta,ga completed!
#
#
#
#
# Retrieving weather data for augusta,ga
#
#
# Currently retrieving data for augusta,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.423451
#
#
# export augusta,ga completed!
#
#
#
#
# Retrieving weather data for austin,tx
#
#
# Currently retrieving data for austin,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.434444
#
#
# export austin,tx completed!
#
#
#
#
# Retrieving weather data for bakersfield,ca
#
#
# Currently retrieving data for bakersfield,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404536
#
#
# export bakersfield,ca completed!
#
#
#
#
# Retrieving weather data for baltimore,md
#
#
# Currently retrieving data for baltimore,md: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.291910
#
#
# export baltimore,md completed!
#
#
#
#
# Retrieving weather data for bangor,me
#
#
# Currently retrieving data for bangor,me: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.406882
#
#
# export bangor,me completed!
#
#
#
#
# Retrieving weather data for barrow,ak
#
#
# Currently retrieving data for barrow,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.407899
#
#
# export barrow,ak completed!
#
#
#
#
# Retrieving weather data for batonrouge,la
#
#
# Currently retrieving data for batonrouge,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.478279
#
#
# export batonrouge,la completed!
#
#
#
#
# Retrieving weather data for saginaw,mi
#
#
# Currently retrieving data for saginaw,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.390985
#
#
# export saginaw,mi completed!
#
#
#
#
# Retrieving weather data for beaumont,tx
#
#
# Currently retrieving data for beaumont,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.315409
#
#
# export beaumont,tx completed!
#
#
#
#
# Retrieving weather data for belleville,il
#
#
# Currently retrieving data for belleville,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.660185
#
#
# export belleville,il completed!
#
#
#
#
# Retrieving weather data for bellingham,wa
#
#
# Currently retrieving data for bellingham,wa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.609756
#
#
# export bellingham,wa completed!
#
#
#
#
# Retrieving weather data for bemidji,mn
#
#
# Currently retrieving data for bemidji,mn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.263386
#
#
# export bemidji,mn completed!
#
#
#
#
# Retrieving weather data for bethel,ak
#
#
# Currently retrieving data for bethel,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.306628
#
#
# export bethel,ak completed!
#
#
#
#
# Retrieving weather data for billings,mt
#
#
# Currently retrieving data for billings,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.486240
#
#
# export billings,mt completed!
#
#
#
#
# Retrieving weather data for gulfport,ms
#
#
# Currently retrieving data for gulfport,ms: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.559308
#
#
# export gulfport,ms completed!
#
#
#
#
# Retrieving weather data for johnsoncity,ny
#
#
# Currently retrieving data for johnsoncity,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.940074
#
#
# export johnsoncity,ny completed!
#
#
#
#
# Retrieving weather data for birmingham,al
#
#
# Currently retrieving data for birmingham,al: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.265237
#
#
# export birmingham,al completed!
#
#
#
#
# Retrieving weather data for bismarck,nd
#
#
# Currently retrieving data for bismarck,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380825
#
#
# export bismarck,nd completed!
#
#
#
#
# Retrieving weather data for bloomington,il
#
#
# Currently retrieving data for bloomington,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.285768
#
#
# export bloomington,il completed!
#
#
#
#
# Retrieving weather data for boise,id
#
#
# Currently retrieving data for boise,id: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.518010
#
#
# export boise,id completed!
#
#
#
#
# Retrieving weather data for boston,ma
#
#
# Currently retrieving data for boston,ma: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.458534
#
#
# export boston,ma completed!
#
#
#
#
# Retrieving weather data for bozeman,mt
#
#
# Currently retrieving data for bozeman,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.363144
#
#
# export bozeman,mt completed!
#
#
#
#
# Retrieving weather data for brainerd,mn
#
#
# Currently retrieving data for brainerd,mn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.909426
#
#
# export brainerd,mn completed!
#
#
#
#
# Retrieving weather data for bristol,tn
#
#
# Currently retrieving data for bristol,tn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.401445
#
#
# export bristol,tn completed!
#
#
#
#
# Retrieving weather data for brownsville,tx
#
#
# Currently retrieving data for brownsville,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383390
#
#
# export brownsville,tx completed!
#
#
#
#
# Retrieving weather data for brunswick,ga
#
#
# Currently retrieving data for brunswick,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.269891
#
#
# export brunswick,ga completed!
#
#
#
#
# Retrieving weather data for buffalo,ny
#
#
# Currently retrieving data for buffalo,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.359131
#
#
# export buffalo,ny completed!
#
#
#
#
# Retrieving weather data for burbank,ca
#
#
# Currently retrieving data for burbank,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.340587
#
#
# export burbank,ca completed!
#
#
#
#
# Retrieving weather data for burlington,vt
#
#
# Currently retrieving data for burlington,vt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.276906
#
#
# export burlington,vt completed!
#
#
#
#
# Retrieving weather data for butte,mt
#
#
# Currently retrieving data for butte,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.579553
#
#
# export butte,mt completed!
#
#
#
#
# Retrieving weather data for capegirardeau,mo
#
#
# Currently retrieving data for capegirardeau,mo: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.598688
#
#
# export capegirardeau,mo completed!
#
#
#
#
# Retrieving weather data for monterey,ca
#
#
# Currently retrieving data for monterey,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.289893
#
#
# export monterey,ca completed!
#
#
#
#
# Retrieving weather data for casper,wy
#
#
# Currently retrieving data for casper,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.283185
#
#
# export casper,wy completed!
#
#
#
#
# Retrieving weather data for cedarcity,ut
#
#
# Currently retrieving data for cedarcity,ut: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.254483
#
#
# export cedarcity,ut completed!
#
#
#
#
# Retrieving weather data for cedarrapids,ia
#
#
# Currently retrieving data for cedarrapids,ia: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.784837
#
#
# export cedarrapids,ia completed!
#
#
#
#
# Retrieving weather data for champaign,il
#
#
# Currently retrieving data for champaign,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.471289
#
#
# export champaign,il completed!
#
#
#
#
# Retrieving weather data for charleston,sc
#
#
# Currently retrieving data for charleston,sc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.285785
#
#
# export charleston,sc completed!
#
#
#
#
# Retrieving weather data for charleston,wv
#
#
# Currently retrieving data for charleston,wv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.477542
#
#
# export charleston,wv completed!
#
#
#
#
# Retrieving weather data for charlotte,nc
#
#
# Currently retrieving data for charlotte,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.500612
#
#
# export charlotte,nc completed!
#
#
#
#
# Retrieving weather data for charlottesville,va
#
#
# Currently retrieving data for charlottesville,va: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.387454
#
#
# export charlottesville,va completed!
#
#
#
#
# Retrieving weather data for chattanooga,tn
#
#
# Currently retrieving data for chattanooga,tn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.353641
#
#
# export chattanooga,tn completed!
#
#
#
#
# Retrieving weather data for cheyenne,wy
#
#
# Currently retrieving data for cheyenne,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.632488
#
#
# export cheyenne,wy completed!
#
#
#
#
# Retrieving weather data for chicago,il
#
#
# Currently retrieving data for chicago,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.482007
#
#
# export chicago,il completed!
#
#
#
#
# Retrieving weather data for hibbing,mn
#
#
# Currently retrieving data for hibbing,mn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.445325
#
#
# export hibbing,mn completed!
#
#
#
#
# Retrieving weather data for cincinnati,oh
#
#
# Currently retrieving data for cincinnati,oh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.376288
#
#
# export cincinnati,oh completed!
#
#
#
#
# Retrieving weather data for clarksburg,wv
#
#
# Currently retrieving data for clarksburg,wv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.920238
#
#
# export clarksburg,wv completed!
#
#
#
#
# Retrieving weather data for stpetersburg,fl
#
#
# Currently retrieving data for stpetersburg,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.474542
#
#
# export stpetersburg,fl completed!
#
#
#
#
# Retrieving weather data for cleveland,oh
#
#
# Currently retrieving data for cleveland,oh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.636899
#
#
# export cleveland,oh completed!
#
#
#
#
# Retrieving weather data for yellowstone,wy
#
#
# Currently retrieving data for yellowstone,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.397050
#
#
# export yellowstone,wy completed!
#
#
#
#
# Retrieving weather data for collegestation,tx
#
#
# Currently retrieving data for collegestation,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.232267
#
#
# export collegestation,tx completed!
#
#
#
#
# Retrieving weather data for coloradosprings,co
#
#
# Currently retrieving data for coloradosprings,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.310453
#
#
# export coloradosprings,co completed!
#
#
#
#
# Retrieving weather data for columbia,mo
#
#
# Currently retrieving data for columbia,mo: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.586334
#
#
# export columbia,mo completed!
#
#
#
#
# Retrieving weather data for columbia,sc
#
#
# Currently retrieving data for columbia,sc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.392436
#
#
# export columbia,sc completed!
#
#
#
#
# Retrieving weather data for columbus,ga
#
#
# Currently retrieving data for columbus,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.068408
#
#
# export columbus,ga completed!
#
#
#
#
# Retrieving weather data for columbus,ms
#
#
# Currently retrieving data for columbus,ms: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.817610
#
#
# export columbus,ms completed!
#
#
#
#
# Retrieving weather data for columbus,oh
#
#
# Currently retrieving data for columbus,oh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.602550
#
#
# export columbus,oh completed!
#
#
#
#
# Retrieving weather data for cordova,ak
#
#
# Currently retrieving data for cordova,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.231048
#
#
# export cordova,ak completed!
#
#
#
#
# Retrieving weather data for corpuschristi,tx
#
#
# Currently retrieving data for corpuschristi,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.355710
#
#
# export corpuschristi,tx completed!
#
#
#
#
# Retrieving weather data for fortworth,tx
#
#
# Currently retrieving data for fortworth,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.432264
#
#
# export fortworth,tx completed!
#
#
#
#
# Retrieving weather data for dayton,oh
#
#
# Currently retrieving data for dayton,oh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.537352
#
#
# export dayton,oh completed!
#
#
#
#
# Retrieving weather data for daytonabeach,fl
#
#
# Currently retrieving data for daytonabeach,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.603498
#
#
# export daytonabeach,fl completed!
#
#
#
#
# Retrieving weather data for denver,co
#
#
# Currently retrieving data for denver,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.944155
#
#
# export denver,co completed!
#
#
#
#
# Retrieving weather data for desmoines,ia
#
#
# Currently retrieving data for desmoines,ia: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.451631
#
#
# export desmoines,ia completed!
#
#
#
#
# Retrieving weather data for detroit,mi
#
#
# Currently retrieving data for detroit,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.711367
#
#
# export detroit,mi completed!
#
#
#
#
# Retrieving weather data for devil'slake,nd
#
#
# Currently retrieving data for devil'slake,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.476715
#
#
# export devil'slake,nd completed!
#
#
#
#
# Retrieving weather data for dothan,al
#
#
# Currently retrieving data for dothan,al: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.406146
#
#
# export dothan,al completed!
#
#
#
#
# Retrieving weather data for dubuque,ia
#
#
# Currently retrieving data for dubuque,ia: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.633049
#
#
# export dubuque,ia completed!
#
#
#
#
# Retrieving weather data for duluth,mn
#
#
# Currently retrieving data for duluth,mn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.362221
#
#
# export duluth,mn completed!
#
#
#
#
# Retrieving weather data for durango,co
#
#
# Currently retrieving data for durango,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.268555
#
#
# export durango,co completed!
#
#
#
#
# Retrieving weather data for durham,nc
#
#
# Currently retrieving data for durham,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.264011
#
#
# export durham,nc completed!
#
#
#
#
# Retrieving weather data for eauclaire,wi
#
#
# Currently retrieving data for eauclaire,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.457097
#
#
# export eauclaire,wi completed!
#
#
#
#
# Retrieving weather data for elpaso,tx
#
#
# Currently retrieving data for elpaso,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.481009
#
#
# export elpaso,tx completed!
#
#
#
#
# Retrieving weather data for elko,nv
#
#
# Currently retrieving data for elko,nv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.464997
#
#
# export elko,nv completed!
#
#
#
#
# Retrieving weather data for elmira,ny
#
#
# Currently retrieving data for elmira,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.302236
#
#
# export elmira,ny completed!
#
#
#
#
# Retrieving weather data for erie,pa
#
#
# Currently retrieving data for erie,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.498435
#
#
# export erie,pa completed!
#
#
#
#
# Retrieving weather data for escanaba,mi
#
#
# Currently retrieving data for escanaba,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.585475
#
#
# export escanaba,mi completed!
#
#
#
#
# Retrieving weather data for eugene,or
#
#
# Currently retrieving data for eugene,or: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.684274
#
#
# export eugene,or completed!
#
#
#
#
# Retrieving weather data for evansville,in
#
#
# Currently retrieving data for evansville,in: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.288963
#
#
# export evansville,in completed!
#
#
#
#
# Retrieving weather data for fairbanks,ak
#
#
# Currently retrieving data for fairbanks,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.326484
#
#
# export fairbanks,ak completed!
#
#
#
#
# Retrieving weather data for fargo,nd
#
#
# Currently retrieving data for fargo,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.290284
#
#
# export fargo,nd completed!
#
#
#
#
# Retrieving weather data for fayetteville,ar
#
#
# Currently retrieving data for fayetteville,ar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.310850
#
#
# export fayetteville,ar completed!
#
#
#
#
# Retrieving weather data for fayetteville,nc
#
#
# Currently retrieving data for fayetteville,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.642345
#
#
# export fayetteville,nc completed!
#
#
#
#
# Retrieving weather data for flagstaff,az
#
#
# Currently retrieving data for flagstaff,az: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.644477
#
#
# export flagstaff,az completed!
#
#
#
#
# Retrieving weather data for flint,mi
#
#
# Currently retrieving data for flint,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.955672
#
#
# export flint,mi completed!
#
#
#
#
# Retrieving weather data for fortlauderdale,fl
#
#
# Currently retrieving data for fortlauderdale,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.689760
#
#
# export fortlauderdale,fl completed!
#
#
#
#
# Retrieving weather data for fortmyers,fl
#
#
# Currently retrieving data for fortmyers,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.313660
#
#
# export fortmyers,fl completed!
#
#
#
#
# Retrieving weather data for fortsmith,ar
#
#
# Currently retrieving data for fortsmith,ar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.318279
#
#
# export fortsmith,ar completed!
#
#
#
#
# Retrieving weather data for valparaiso,fl
#
#
# Currently retrieving data for valparaiso,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.240729
#
#
# export valparaiso,fl completed!
#
#
#
#
# Retrieving weather data for fortwayne,in
#
#
# Currently retrieving data for fortwayne,in: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.478381
#
#
# export fortwayne,in completed!
#
#
#
#
# Retrieving weather data for fresno,ca
#
#
# Currently retrieving data for fresno,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.292237
#
#
# export fresno,ca completed!
#
#
#
#
# Retrieving weather data for gainesville,fl
#
#
# Currently retrieving data for gainesville,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.337020
#
#
# export gainesville,fl completed!
#
#
#
#
# Retrieving weather data for gardencity,ks
#
#
# Currently retrieving data for gardencity,ks: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.975049
#
#
# export gardencity,ks completed!
#
#
#
#
# Retrieving weather data for gillette,wy
#
#
# Currently retrieving data for gillette,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.512154
#
#
# export gillette,wy completed!
#
#
#
#
# Retrieving weather data for longview,tx
#
#
# Currently retrieving data for longview,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.519298
#
#
# export longview,tx completed!
#
#
#
#
# Retrieving weather data for grandforks,nd
#
#
# Currently retrieving data for grandforks,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.697509
#
#
# export grandforks,nd completed!
#
#
#
#
# Retrieving weather data for grandisland,ne
#
#
# Currently retrieving data for grandisland,ne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.293454
#
#
# export grandisland,ne completed!
#
#
#
#
# Retrieving weather data for grandjunction,co
#
#
# Currently retrieving data for grandjunction,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.334455
#
#
# export grandjunction,co completed!
#
#
#
#
# Retrieving weather data for grandrapids,mi
#
#
# Currently retrieving data for grandrapids,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.522720
#
#
# export grandrapids,mi completed!
#
#
#
#
# Retrieving weather data for greatfalls,mt
#
#
# Currently retrieving data for greatfalls,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.593769
#
#
# export greatfalls,mt completed!
#
#
#
#
# Retrieving weather data for greenbay,wi
#
#
# Currently retrieving data for greenbay,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.847694
#
#
# export greenbay,wi completed!
#
#
#
#
# Retrieving weather data for greensboro,nc
#
#
# Currently retrieving data for greensboro,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.291345
#
#
# export greensboro,nc completed!
#
#
#
#
# Retrieving weather data for greer,sc
#
#
# Currently retrieving data for greer,sc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.256578
#
#
# export greer,sc completed!
#
#
#
#
# Retrieving weather data for gunnison,co
#
#
# Currently retrieving data for gunnison,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.415597
#
#
# export gunnison,co completed!
#
#
#
#
# Retrieving weather data for hagerstown,md
#
#
# Currently retrieving data for hagerstown,md: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.354747
#
#
# export hagerstown,md completed!
#
#
#
#
# Retrieving weather data for sunvalley,id
#
#
# Currently retrieving data for sunvalley,id: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.248816
#
#
# export sunvalley,id completed!
#
#
#
#
# Retrieving weather data for newportnews,va
#
#
# Currently retrieving data for newportnews,va: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.465125
#
#
# export newportnews,va completed!
#
#
#
#
# Retrieving weather data for hancock,mi
#
#
# Currently retrieving data for hancock,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.927141
#
#
# export hancock,mi completed!
#
#
#
#
# Retrieving weather data for harlingen,tx
#
#
# Currently retrieving data for harlingen,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.337130
#
#
# export harlingen,tx completed!
#
#
#
#
# Retrieving weather data for harrisburg,pa
#
#
# Currently retrieving data for harrisburg,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.265911
#
#
# export harrisburg,pa completed!
#
#
#
#
# Retrieving weather data for windsorlocks,ct
#
#
# Currently retrieving data for windsorlocks,ct: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.432681
#
#
# export windsorlocks,ct completed!
#
#
#
#
# Retrieving weather data for hayden,co
#
#
# Currently retrieving data for hayden,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.565390
#
#
# export hayden,co completed!
#
#
#
#
# Retrieving weather data for hays,ks
#
#
# Currently retrieving data for hays,ks: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.385947
#
#
# export hays,ks completed!
#
#
#
#
# Retrieving weather data for helena,mt
#
#
# Currently retrieving data for helena,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.264796
#
#
# export helena,mt completed!
#
#
#
#
# Retrieving weather data for hilo,hi
#
#
# Currently retrieving data for hilo,hi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.413811
#
#
# export hilo,hi completed!
#
#
#
#
# Retrieving weather data for hiltonhead,sc
#
#
# Currently retrieving data for hiltonhead,sc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.567109
#
#
# export hiltonhead,sc completed!
#
#
#
#
# Retrieving weather data for honolulu,hi
#
#
# Currently retrieving data for honolulu,hi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.389389
#
#
# export honolulu,hi completed!
#
#
#
#
# Retrieving weather data for houston,tx
#
#
# Currently retrieving data for houston,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.514655
#
#
# export houston,tx completed!
#
#
#
#
# Retrieving weather data for huntsville,al
#
#
# Currently retrieving data for huntsville,al: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.457182
#
#
# export huntsville,al completed!
#
#
#
#
# Retrieving weather data for idahofalls,id
#
#
# Currently retrieving data for idahofalls,id: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.254939
#
#
# export idahofalls,id completed!
#
#
#
#
# Retrieving weather data for indianapolis,in
#
#
# Currently retrieving data for indianapolis,in: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.599464
#
#
# export indianapolis,in completed!
#
#
#
#
# Retrieving weather data for internationalfalls,mn
#
#
# Currently retrieving data for internationalfalls,mn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.823222
#
#
# export internationalfalls,mn completed!
#
#
#
#
# Retrieving weather data for ironmountain,mi
#
#
# Currently retrieving data for ironmountain,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.789764
#
#
# export ironmountain,mi completed!
#
#
#
#
# Retrieving weather data for islip,ny
#
#
# Currently retrieving data for islip,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.411681
#
#
# export islip,ny completed!
#
#
#
#
# Retrieving weather data for ithaca,ny
#
#
# Currently retrieving data for ithaca,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.311556
#
#
# export ithaca,ny completed!
#
#
#
#
# Retrieving weather data for jacksonhole,wy
#
#
# Currently retrieving data for jacksonhole,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.327908
#
#
# export jacksonhole,wy completed!
#
#
#
#
# Retrieving weather data for jackson,ms
#
#
# Currently retrieving data for jackson,ms: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.450016
#
#
# export jackson,ms completed!
#
#
#
#
# Retrieving weather data for jacksonville,fl
#
#
# Currently retrieving data for jacksonville,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.284406
#
#
# export jacksonville,fl completed!
#
#
#
#
# Retrieving weather data for jacksonville,nc
#
#
# Currently retrieving data for jacksonville,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.444722
#
#
# export jacksonville,nc completed!
#
#
#
#
# Retrieving weather data for jamestown,nd
#
#
# Currently retrieving data for jamestown,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.480721
#
#
# export jamestown,nd completed!
#
#
#
#
# Retrieving weather data for joplin,mo
#
#
# Currently retrieving data for joplin,mo: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.605073
#
#
# export joplin,mo completed!
#
#
#
#
# Retrieving weather data for juneau,ak
#
#
# Currently retrieving data for juneau,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.485469
#
#
# export juneau,ak completed!
#
#
#
#
# Retrieving weather data for kahului-maui,hi
#
#
# Currently retrieving data for kahului-maui,hi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.320150
#
#
# export kahului-maui,hi completed!
#
#
#
#
# Retrieving weather data for kalamazoo,mi
#
#
# Currently retrieving data for kalamazoo,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.317679
#
#
# export kalamazoo,mi completed!
#
#
#
#
# Retrieving weather data for kansascity,mo
#
#
# Currently retrieving data for kansascity,mo: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.281692
#
#
# export kansascity,mo completed!
#
#
#
#
# Retrieving weather data for kauai,hi
#
#
# Currently retrieving data for kauai,hi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.417817
#
#
# export kauai,hi completed!
#
#
#
#
# Retrieving weather data for kearney,ne
#
#
# Currently retrieving data for kearney,ne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.264867
#
#
# export kearney,ne completed!
#
#
#
#
# Retrieving weather data for ketchikan,ak
#
#
# Currently retrieving data for ketchikan,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.767910
#
#
# export ketchikan,ak completed!
#
#
#
#
# Retrieving weather data for keywest,fl
#
#
# Currently retrieving data for keywest,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.021975
#
#
# export keywest,fl completed!
#
#
#
#
# Retrieving weather data for knoxville,tn
#
#
# Currently retrieving data for knoxville,tn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.303846
#
#
# export knoxville,tn completed!
#
#
#
#
# Retrieving weather data for kodiak,ak
#
#
# Currently retrieving data for kodiak,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.473404
#
#
# export kodiak,ak completed!
#
#
#
#
# Retrieving weather data for kona,hi
#
#
# Currently retrieving data for kona,hi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.459590
#
#
# export kona,hi completed!
#
#
#
#
# Retrieving weather data for kotzebue,ak
#
#
# Currently retrieving data for kotzebue,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.584377
#
#
# export kotzebue,ak completed!
#
#
#
#
# Retrieving weather data for lacrosse,wi
#
#
# Currently retrieving data for lacrosse,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.742662
#
#
# export lacrosse,wi completed!
#
#
#
#
# Retrieving weather data for lafayette,la
#
#
# Currently retrieving data for lafayette,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.448755
#
#
# export lafayette,la completed!
#
#
#
#
# Retrieving weather data for lakecharles,la
#
#
# Currently retrieving data for lakecharles,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.372481
#
#
# export lakecharles,la completed!
#
#
#
#
# Retrieving weather data for lansing,mi
#
#
# Currently retrieving data for lansing,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.658595
#
#
# export lansing,mi completed!
#
#
#
#
# Retrieving weather data for laramie,wy
#
#
# Currently retrieving data for laramie,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.254963
#
#
# export laramie,wy completed!
#
#
#
#
# Retrieving weather data for laredo,tx
#
#
# Currently retrieving data for laredo,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.307814
#
#
# export laredo,tx completed!
#
#
#
#
# Retrieving weather data for lasvegas,nv
#
#
# Currently retrieving data for lasvegas,nv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.462658
#
#
# export lasvegas,nv completed!
#
#
#
#
# Retrieving weather data for latrobe,pa
#
#
# Currently retrieving data for latrobe,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.420179
#
#
# export latrobe,pa completed!
#
#
#
#
# Retrieving weather data for laurel,ms
#
#
# Currently retrieving data for laurel,ms: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.282585
#
#
# export laurel,ms completed!
#
#
#
#
# Retrieving weather data for lawton,ok
#
#
# Currently retrieving data for lawton,ok: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.849139
#
#
# export lawton,ok completed!
#
#
#
#
# Retrieving weather data for lewisburg,wv
#
#
# Currently retrieving data for lewisburg,wv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.697741
#
#
# export lewisburg,wv completed!
#
#
#
#
# Retrieving weather data for lewiston,id
#
#
# Currently retrieving data for lewiston,id: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.427865
#
#
# export lewiston,id completed!
#
#
#
#
# Retrieving weather data for lexington,ky
#
#
# Currently retrieving data for lexington,ky: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.376324
#
#
# export lexington,ky completed!
#
#
#
#
# Retrieving weather data for liberal,ks
#
#
# Currently retrieving data for liberal,ks: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.323378
#
#
# export liberal,ks completed!
#
#
#
#
# Retrieving weather data for lincoln,ne
#
#
# Currently retrieving data for lincoln,ne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.340484
#
#
# export lincoln,ne completed!
#
#
#
#
# Retrieving weather data for littlerock,ar
#
#
# Currently retrieving data for littlerock,ar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.337164
#
#
# export littlerock,ar completed!
#
#
#
#
# Retrieving weather data for longbeach,ca
#
#
# Currently retrieving data for longbeach,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.446367
#
#
# export longbeach,ca completed!
#
#
#
#
# Retrieving weather data for losangeles,ca
#
#
# Currently retrieving data for losangeles,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.432546
#
#
# export losangeles,ca completed!
#
#
#
#
# Retrieving weather data for louisville,ky
#
#
# Currently retrieving data for louisville,ky: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.041981
#
#
# export louisville,ky completed!
#
#
#
#
# Retrieving weather data for lubbock,tx
#
#
# Currently retrieving data for lubbock,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.346011
#
#
# export lubbock,tx completed!
#
#
#
#
# Retrieving weather data for madison,wi
#
#
# Currently retrieving data for madison,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.446332
#
#
# export madison,wi completed!
#
#
#
#
# Retrieving weather data for manchester,nh
#
#
# Currently retrieving data for manchester,nh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.242537
#
#
# export manchester,nh completed!
#
#
#
#
# Retrieving weather data for manhattan,ks
#
#
# Currently retrieving data for manhattan,ks: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.289292
#
#
# export manhattan,ks completed!
#
#
#
#
# Retrieving weather data for marquette,mi
#
#
# Currently retrieving data for marquette,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.432581
#
#
# export marquette,mi completed!
#
#
#
#
# Retrieving weather data for mcallen,tx
#
#
# Currently retrieving data for mcallen,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.319342
#
#
# export mcallen,tx completed!
#
#
#
#
# Retrieving weather data for medford,or
#
#
# Currently retrieving data for medford,or: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.652103
#
#
# export medford,or completed!
#
#
#
#
# Retrieving weather data for melbourne,fl
#
#
# Currently retrieving data for melbourne,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.390650
#
#
# export melbourne,fl completed!
#
#
#
#
# Retrieving weather data for memphis,tn
#
#
# Currently retrieving data for memphis,tn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.561500
#
#
# export memphis,tn completed!
#
#
#
#
# Retrieving weather data for meridian,ms
#
#
# Currently retrieving data for meridian,ms: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.635642
#
#
# export meridian,ms completed!
#
#
#
#
# Retrieving weather data for miami,fl
#
#
# Currently retrieving data for miami,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.397999
#
#
# export miami,fl completed!
#
#
#
#
# Retrieving weather data for odessa,tx
#
#
# Currently retrieving data for odessa,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.232199
#
#
# export odessa,tx completed!
#
#
#
#
# Retrieving weather data for milwaukee,wi
#
#
# Currently retrieving data for milwaukee,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.476493
#
#
# export milwaukee,wi completed!
#
#
#
#
# Retrieving weather data for minneapolis,mn
#
#
# Currently retrieving data for minneapolis,mn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.249331
#
#
# export minneapolis,mn completed!
#
#
#
#
# Retrieving weather data for minot,nd
#
#
# Currently retrieving data for minot,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.229491
#
#
# export minot,nd completed!
#
#
#
#
# Retrieving weather data for missoula,mt
#
#
# Currently retrieving data for missoula,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.853902
#
#
# export missoula,mt completed!
#
#
#
#
# Retrieving weather data for moab,ut
#
#
# Currently retrieving data for moab,ut: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.680718
#
#
# export moab,ut completed!
#
#
#
#
# Retrieving weather data for mobile,al
#
#
# Currently retrieving data for mobile,al: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404615
#
#
# export mobile,al completed!
#
#
#
#
# Retrieving weather data for moline,il
#
#
# Currently retrieving data for moline,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.233234
#
#
# export moline,il completed!
#
#
#
#
# Retrieving weather data for monroe,la
#
#
# Currently retrieving data for monroe,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.446961
#
#
# export monroe,la completed!
#
#
#
#
# Retrieving weather data for montgomery,al
#
#
# Currently retrieving data for montgomery,al: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.317327
#
#
# export montgomery,al completed!
#
#
#
#
# Retrieving weather data for montrose,co
#
#
# Currently retrieving data for montrose,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.450971
#
#
# export montrose,co completed!
#
#
#
#
# Retrieving weather data for muskegon,mi
#
#
# Currently retrieving data for muskegon,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.504816
#
#
# export muskegon,mi completed!
#
#
#
#
# Retrieving weather data for myrtlebeach,sc
#
#
# Currently retrieving data for myrtlebeach,sc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.488226
#
#
# export myrtlebeach,sc completed!
#
#
#
#
# Retrieving weather data for nashville,tn
#
#
# Currently retrieving data for nashville,tn: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.266565
#
#
# export nashville,tn completed!
#
#
#
#
# Retrieving weather data for newhaven,ct
#
#
# Currently retrieving data for newhaven,ct: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.478952
#
#
# export newhaven,ct completed!
#
#
#
#
# Retrieving weather data for neworleans,la
#
#
# Currently retrieving data for neworleans,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.302321
#
#
# export neworleans,la completed!
#
#
#
#
# Retrieving weather data for newyork,ny
#
#
# Currently retrieving data for newyork,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.371531
#
#
# export newyork,ny completed!
#
#
#
#
# Retrieving weather data for newark,nj
#
#
# Currently retrieving data for newark,nj: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.253488
#
#
# export newark,nj completed!
#
#
#
#
# Retrieving weather data for stewartfield,ny
#
#
# Currently retrieving data for stewartfield,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.781186
#
#
# export stewartfield,ny completed!
#
#
#
#
# Retrieving weather data for nome,ak
#
#
# Currently retrieving data for nome,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.930001
#
#
# export nome,ak completed!
#
#
#
#
# Retrieving weather data for norfolk,va
#
#
# Currently retrieving data for norfolk,va: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.419997
#
#
# export norfolk,va completed!
#
#
#
#
# Retrieving weather data for northbend,or
#
#
# Currently retrieving data for northbend,or: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.454901
#
#
# export northbend,or completed!
#
#
#
#
# Retrieving weather data for northplatte,ne
#
#
# Currently retrieving data for northplatte,ne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.644530
#
#
# export northplatte,ne completed!
#
#
#
#
# Retrieving weather data for oakland,ca
#
#
# Currently retrieving data for oakland,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.476952
#
#
# export oakland,ca completed!
#
#
#
#
# Retrieving weather data for ogdensburg,ny
#
#
# Currently retrieving data for ogdensburg,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.850326
#
#
# export ogdensburg,ny completed!
#
#
#
#
# Retrieving weather data for oklahomacity,ok
#
#
# Currently retrieving data for oklahomacity,ok: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.438338
#
#
# export oklahomacity,ok completed!
#
#
#
#
# Retrieving weather data for omaha,ne
#
#
# Currently retrieving data for omaha,ne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.007911
#
#
# export omaha,ne completed!
#
#
#
#
# Retrieving weather data for ontario,ca
#
#
# Currently retrieving data for ontario,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.612382
#
#
# export ontario,ca completed!
#
#
#
#
# Retrieving weather data for santaana,ca
#
#
# Currently retrieving data for santaana,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.256014
#
#
# export santaana,ca completed!
#
#
#
#
# Retrieving weather data for orlando,fl
#
#
# Currently retrieving data for orlando,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.336515
#
#
# export orlando,fl completed!
#
#
#
#
# Retrieving weather data for owensboro,ky
#
#
# Currently retrieving data for owensboro,ky: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.402540
#
#
# export owensboro,ky completed!
#
#
#
#
# Retrieving weather data for paducah,ky
#
#
# Currently retrieving data for paducah,ky: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.289258
#
#
# export paducah,ky completed!
#
#
#
#
# Retrieving weather data for palmsprings,ca
#
#
# Currently retrieving data for palmsprings,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.315669
#
#
# export palmsprings,ca completed!
#
#
#
#
# Retrieving weather data for pasco,wa
#
#
# Currently retrieving data for pasco,wa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.430174
#
#
# export pasco,wa completed!
#
#
#
#
# Retrieving weather data for pellston,mi
#
#
# Currently retrieving data for pellston,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.899454
#
#
# export pellston,mi completed!
#
#
#
#
# Retrieving weather data for pensacola,fl
#
#
# Currently retrieving data for pensacola,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.589161
#
#
# export pensacola,fl completed!
#
#
#
#
# Retrieving weather data for peoria,il
#
#
# Currently retrieving data for peoria,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.552300
#
#
# export peoria,il completed!
#
#
#
#
# Retrieving weather data for petersburg,ak
#
#
# Currently retrieving data for petersburg,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.690879
#
#
# export petersburg,ak completed!
#
#
#
#
# Retrieving weather data for philadelphia,pa
#
#
# Currently retrieving data for philadelphia,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.361971
#
#
# export philadelphia,pa completed!
#
#
#
#
# Retrieving weather data for trenton,nj
#
#
# Currently retrieving data for trenton,nj: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.366698
#
#
# export trenton,nj completed!
#
#
#
#
# Retrieving weather data for phoenix,az
#
#
# Currently retrieving data for phoenix,az: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380354
#
#
# export phoenix,az completed!
#
#
#
#
# Retrieving weather data for pierre,sd
#
#
# Currently retrieving data for pierre,sd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.406067
#
#
# export pierre,sd completed!
#
#
#
#
# Retrieving weather data for pittsburgh,pa
#
#
# Currently retrieving data for pittsburgh,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.612474
#
#
# export pittsburgh,pa completed!
#
#
#
#
# Retrieving weather data for pocatello,id
#
#
# Currently retrieving data for pocatello,id: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.386423
#
#
# export pocatello,id completed!
#
#
#
#
# Retrieving weather data for ponce,pr
#
#
# Currently retrieving data for ponce,pr: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.368194
#
#
# export ponce,pr completed!
#
#
#
#
# Retrieving weather data for portland,me
#
#
# Currently retrieving data for portland,me: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.392733
#
#
# export portland,me completed!
#
#
#
#
# Retrieving weather data for portland,or
#
#
# Currently retrieving data for portland,or: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.381503
#
#
# export portland,or completed!
#
#
#
#
# Retrieving weather data for portsmouth,nh
#
#
# Currently retrieving data for portsmouth,nh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.607017
#
#
# export portsmouth,nh completed!
#
#
#
#
# Retrieving weather data for prescott,az
#
#
# Currently retrieving data for prescott,az: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.963148
#
#
# export prescott,az completed!
#
#
#
#
# Retrieving weather data for providence,ri
#
#
# Currently retrieving data for providence,ri: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.626641
#
#
# export providence,ri completed!
#
#
#
#
# Retrieving weather data for prudhoebay,ak
#
#
# Currently retrieving data for prudhoebay,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.712567
#
#
# export prudhoebay,ak completed!
#
#
#
#
# Retrieving weather data for pueblo,co
#
#
# Currently retrieving data for pueblo,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.806480
#
#
# export pueblo,co completed!
#
#
#
#
# Retrieving weather data for quincy,il
#
#
# Currently retrieving data for quincy,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.532133
#
#
# export quincy,il completed!
#
#
#
#
# Retrieving weather data for rapidcity,sd
#
#
# Currently retrieving data for rapidcity,sd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.468566
#
#
# export rapidcity,sd completed!
#
#
#
#
# Retrieving weather data for redding,ca
#
#
# Currently retrieving data for redding,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.651558
#
#
# export redding,ca completed!
#
#
#
#
# Retrieving weather data for redmond,or
#
#
# Currently retrieving data for redmond,or: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.226259
#
#
# export redmond,or completed!
#
#
#
#
# Retrieving weather data for reno,nv
#
#
# Currently retrieving data for reno,nv: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.617044
#
#
# export reno,nv completed!
#
#
#
#
# Retrieving weather data for rhinelander,wi,
#
#
# Currently retrieving data for rhinelander,wi,: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.557512
#
#
# export rhinelander,wi, completed!
#
#
#
#
# Retrieving weather data for richmond,va
#
#
# ...
#
#
#
#
# Retrieving weather data for salina,ks
#
#
# Currently retrieving data for salina,ks: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.290732
#
#
# export salina,ks completed!
#
#
#
#
# Retrieving weather data for saltlakecity,ut
#
#
# Currently retrieving data for saltlakecity,ut: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.325362
#
#
# export saltlakecity,ut completed!
#
#
#
#
# Retrieving weather data for sanangelo,tx
#
#
# Currently retrieving data for sanangelo,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.015377
#
#
# export sanangelo,tx completed!
#
#
#
#
# Retrieving weather data for sanantonio,tx
#
#
# Currently retrieving data for sanantonio,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.211246
#
#
# export sanantonio,tx completed!
#
#
#
#
# Retrieving weather data for sandiego,ca
#
#
# Currently retrieving data for sandiego,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.091210
#
#
# export sandiego,ca completed!
#
#
#
#
# Retrieving weather data for sanfrancisco,ca
#
#
# Currently retrieving data for sanfrancisco,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.289256
#
#
# export sanfrancisco,ca completed!
#
#
#
#
# Retrieving weather data for sanjose,ca
#
#
# Currently retrieving data for sanjose,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.091803
#
#
# export sanjose,ca completed!
#
#
#
#
# Retrieving weather data for sanjuan,pr
#
#
# Currently retrieving data for sanjuan,pr: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.315449
#
#
# export sanjuan,pr completed!
#
#
#
#
# Retrieving weather data for sanluisobispo,ca
#
#
# Currently retrieving data for sanluisobispo,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.342770
#
#
# export sanluisobispo,ca completed!
#
#
#
#
# Retrieving weather data for santabarbara,ca
#
#
# Currently retrieving data for santabarbara,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.201201
#
#
# export santabarbara,ca completed!
#
#
#
#
# Retrieving weather data for santafe,nm
#
#
# Currently retrieving data for santafe,nm: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.458873
#
#
# export santafe,nm completed!
#
#
#
#
# Retrieving weather data for santamaria,ca
#
#
# Currently retrieving data for santamaria,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.264098
#
#
# export santamaria,ca completed!
#
#
#
#
# Retrieving weather data for santarosa,ca
#
#
# Currently retrieving data for santarosa,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.279902
#
#
# export santarosa,ca completed!
#
#
#
#
# Retrieving weather data for sarasota,fl
#
#
# Currently retrieving data for sarasota,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.282644
#
#
# export sarasota,fl completed!
#
#
#
#
# Retrieving weather data for saultstemarie,mi,
#
#
# Currently retrieving data for saultstemarie,mi,: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.238218
#
#
# export saultstemarie,mi, completed!
#
#
#
#
# Retrieving weather data for savannah,ga
#
#
# Currently retrieving data for savannah,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.272337
#
#
# export savannah,ga completed!
#
#
#
#
# Retrieving weather data for scottsbluff,ne
#
#
# Currently retrieving data for scottsbluff,ne: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.808439
#
#
# export scottsbluff,ne completed!
#
#
#
#
# Retrieving weather data for scranton,pa
#
#
# Currently retrieving data for scranton,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.580497
#
#
# export scranton,pa completed!
#
#
#
#
# Retrieving weather data for seattle,wa
#
#
# Currently retrieving data for seattle,wa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.408634
#
#
# export seattle,wa completed!
#
#
#
#
# Retrieving weather data for sheridan,wy
#
#
# Currently retrieving data for sheridan,wy: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.191691
#
#
# export sheridan,wy completed!
#
#
#
#
# Retrieving weather data for shreveport,la
#
#
# Currently retrieving data for shreveport,la: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.212712
#
#
# export shreveport,la completed!
#
#
#
#
# Retrieving weather data for siouxcity,ia
#
#
# Currently retrieving data for siouxcity,ia: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.165761
#
#
# export siouxcity,ia completed!
#
#
#
#
# Retrieving weather data for siouxfalls,sd
#
#
# Currently retrieving data for siouxfalls,sd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.218173
#
#
# export siouxfalls,sd completed!
#
#
#
#
# Retrieving weather data for sitka,ak
#
#
# Currently retrieving data for sitka,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.211303
#
#
# export sitka,ak completed!
#
#
#
#
# Retrieving weather data for southbend,in
#
#
# Currently retrieving data for southbend,in: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.190232
#
#
# export southbend,in completed!
#
#
#
#
# Retrieving weather data for spokane,wa
#
#
# Currently retrieving data for spokane,wa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.427077
#
#
# export spokane,wa completed!
#
#
#
#
# Retrieving weather data for springfield,il
#
#
# Currently retrieving data for springfield,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.313597
#
#
# export springfield,il completed!
#
#
#
#
# Retrieving weather data for springfield,mo
#
#
# Currently retrieving data for springfield,mo: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.197067
#
#
# export springfield,mo completed!
#
#
#
#
# Retrieving weather data for universitypark,pa
#
#
# Currently retrieving data for universitypark,pa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.213705
#
#
# export universitypark,pa completed!
#
#
#
#
# Retrieving weather data for staunton,va
#
#
# Currently retrieving data for staunton,va: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.279723
#
#
# export staunton,va completed!
#
#
#
#
# Retrieving weather data for mosinee,wi
#
#
# Currently retrieving data for mosinee,wi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.234700
#
#
# export mosinee,wi completed!
#
#
#
#
# Retrieving weather data for stockton,ca
#
#
# Currently retrieving data for stockton,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.244104
#
#
# export stockton,ca completed!
#
#
#
#
# Retrieving weather data for syracuse,ny
#
#
# Currently retrieving data for syracuse,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.303627
#
#
# export syracuse,ny completed!
#
#
#
#
# Retrieving weather data for tallahassee,fl
#
#
# Currently retrieving data for tallahassee,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.603244
#
#
# export tallahassee,fl completed!
#
#
#
#
# Retrieving weather data for tampa,fl
#
#
# Currently retrieving data for tampa,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.892700
#
#
# export tampa,fl completed!
#
#
#
#
# Retrieving weather data for texarkana,ar
#
#
# Currently retrieving data for texarkana,ar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.211627
#
#
# export texarkana,ar completed!
#
#
#
#
# Retrieving weather data for toledo,oh
#
#
# Currently retrieving data for toledo,oh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.263455
#
#
# export toledo,oh completed!
#
#
#
#
# Retrieving weather data for traversecity,mi
#
#
# Currently retrieving data for traversecity,mi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.212996
#
#
# export traversecity,mi completed!
#
#
#
#
# Retrieving weather data for tucson,az
#
#
# Currently retrieving data for tucson,az: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.247388
#
#
# export tucson,az completed!
#
#
#
#
# Retrieving weather data for tulsa,ok
#
#
# Currently retrieving data for tulsa,ok: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.257164
#
#
# export tulsa,ok completed!
#
#
#
#
# Retrieving weather data for twinfalls,id
#
#
# Currently retrieving data for twinfalls,id: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.320173
#
#
# export twinfalls,id completed!
#
#
#
#
# Retrieving weather data for tyler,tx
#
#
# Currently retrieving data for tyler,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.471024
#
#
# export tyler,tx completed!
#
#
#
#
# Retrieving weather data for vail,co
#
#
# Currently retrieving data for vail,co: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.689433
#
#
# export vail,co completed!
#
#
#
#
# Retrieving weather data for valdosta,ga
#
#
# Currently retrieving data for valdosta,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.298676
#
#
# export valdosta,ga completed!
#
#
#
#
# Retrieving weather data for vernal,ut
#
#
# Currently retrieving data for vernal,ut: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.194366
#
#
# export vernal,ut completed!
#
#
#
#
# Retrieving weather data for waco,tx
#
#
# Currently retrieving data for waco,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.275365
#
#
# export waco,tx completed!
#
#
#
#
# Retrieving weather data for washington,dc
#
#
# Currently retrieving data for washington,dc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.270924
#
#
# export washington,dc completed!
#
#
#
#
# Retrieving weather data for waterloo,ia
#
#
# Currently retrieving data for waterloo,ia: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.209600
#
#
# export waterloo,ia completed!
#
#
#
#
# Retrieving weather data for watertown,ny
#
#
# Currently retrieving data for watertown,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.214434
#
#
# export watertown,ny completed!
#
#
#
#
# Retrieving weather data for watertown,sd
#
#
# Currently retrieving data for watertown,sd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.534957
#
#
# export watertown,sd completed!
#
#
#
#
# Retrieving weather data for westpalmbeach,fl
#
#
# Currently retrieving data for westpalmbeach,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.572836
#
#
# export westpalmbeach,fl completed!
#
#
#
#
# Retrieving weather data for westchestercounty,ny
#
#
# Currently retrieving data for westchestercounty,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.217382
#
#
# export westchestercounty,ny completed!
#
#
#
#
# Retrieving weather data for wichitafalls,tx
#
#
# Currently retrieving data for wichitafalls,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.133032
#
#
# export wichitafalls,tx completed!
#
#
#
#
# Retrieving weather data for wichita,ks
#
#
# Currently retrieving data for wichita,ks: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.271490
#
#
# export wichita,ks completed!
#
#
#
#
# Retrieving weather data for williston,nd
#
#
# Currently retrieving data for williston,nd: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.213482
#
#
# export williston,nd completed!
#
#
#
#
# Retrieving weather data for wilmington,nc
#
#
# Currently retrieving data for wilmington,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.310704
#
#
# export wilmington,nc completed!
#
#
#
#
# Retrieving weather data for worcester,ma
#
#
# Currently retrieving data for worcester,ma: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.221144
#
#
# export worcester,ma completed!
#
#
#
#
# Retrieving weather data for wrangell,ak
#
#
# Currently retrieving data for wrangell,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.341858
#
#
# export wrangell,ak completed!
#
#
#
#
# Retrieving weather data for yakutat,ak
#
#
# Currently retrieving data for yakutat,ak: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.221191
#
#
# export yakutat,ak completed!
#
#
#
#
# Retrieving weather data for yuma,az
#
#
# Currently retrieving data for yuma,az: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.239390
#
#
# export yuma,az completed!
#
#
#
#
# Retrieving weather data for sanford,fl
#
#
# Currently retrieving data for sanford,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.338548
#
#
# export sanford,fl completed!
#
#
#
#
# Retrieving weather data for plattsburgh,ny
#
#
# Currently retrieving data for plattsburgh,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.219780
#
#
# export plattsburgh,ny completed!
#
#
#
#
# Retrieving weather data for concord,nc
#
#
# Currently retrieving data for concord,nc: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.296153
#
#
# export concord,nc completed!
#
#
#
#
# Retrieving weather data for niagarafalls,ny
#
#
# Currently retrieving data for niagarafalls,ny: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.193757
#
#
# export niagarafalls,ny completed!
#
#
#
#
# Retrieving weather data for christiansted,vi
#
#
# Currently retrieving data for christiansted,vi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.233649
#
#
# export christiansted,vi completed!
#
#
#
#
# Retrieving weather data for aguadillapueblo,pr
#
#
# Currently retrieving data for aguadillapueblo,pr: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.274443
#
#
# export aguadillapueblo,pr completed!
#
#
#
#
# Retrieving weather data for stthomas,vi
#
#
# Currently retrieving data for stthomas,vi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.683740
#
#
# export stthomas,vi completed!
#
#
#
#
# Retrieving weather data for hobbs,nm
#
#
# Currently retrieving data for hobbs,nm: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.309860
#
#
# export hobbs,nm completed!
#
#
#
#
# Retrieving weather data for panamacity,fl
#
#
# Currently retrieving data for panamacity,fl: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.317942
#
#
# export panamacity,fl completed!
#
#
#
#
# Retrieving weather data for atlanticcity,nj
#
#
# Currently retrieving data for atlanticcity,nj: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.272948
#
#
# export atlanticcity,nj completed!
#
#
#
#
# Retrieving weather data for dallas,tx
#
#
# Currently retrieving data for dallas,tx: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.214406
#
#
# export dallas,tx completed!
#
#
#
#
# Retrieving weather data for kalispell,mt
#
#
# Currently retrieving data for kalispell,mt: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.266852
#
#
# export kalispell,mt completed!
#
#
#
#
# Retrieving weather data for albany,ga
#
#
# Currently retrieving data for albany,ga: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.205739
#
#
# export albany,ga completed!
#
#
#
#
# Retrieving weather data for mammothlakes,ca
#
#
# Currently retrieving data for mammothlakes,ca: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.208507
#
#
# export mammothlakes,ca completed!
#
#
#
#
# Retrieving weather data for tamuning,gu
#
#
# Currently retrieving data for tamuning,gu: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.507560
#
#
# export tamuning,gu completed!
#
#
#
#
# Retrieving weather data for fadang,mp
#
#
# Currently retrieving data for fadang,mp: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.319855
#
#
# export fadang,mp completed!
#
#
#
#
# Retrieving weather data for provo,ut
#
#
# Currently retrieving data for provo,ut: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.228214
#
#
# export provo,ut completed!
#
#
#
#
# Retrieving weather data for rockford,il
#
#
# Currently retrieving data for rockford,il: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.257155
#
#
# export rockford,il completed!
#
#
#
#
# Retrieving weather data for tafuna,as
#
#
# Currently retrieving data for tafuna,as: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.242207
#
#
# export tafuna,as completed!
#
#
#
#
# Retrieving weather data for ogden,ut
#
#
# Currently retrieving data for ogden,ut: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.245395
#
#
# export ogden,ut completed!
#
#
#
#
# Retrieving weather data for lynchburg,va
#
#
# Currently retrieving data for lynchburg,va: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.297964
#
#
# export lynchburg,va completed!
#
#
#
#
# Retrieving weather data for everett,wa
#
#
# Currently retrieving data for everett,wa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.237411
#
#
# export everett,wa completed!

# %%
#Create variables to hold all csv files and CSVs
all_files = glob.glob(os.path.join("*.csv"))
all_df = []

# Loop through all files, create df's and add all dataframes to the dataframes list
for x in all_files:
    df = pd.read_csv(x, sep=',')
    df['file'] = x.split('/')[-1]
    all_df.append(df)

# %%
#Merge all dataframes
merged_2020_df = pd.concat(all_df, ignore_index=True, sort=True)
merged_2020_df
# Out:
#         DewPointC  FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  \
# 0               0           2           6           2            38
# 1              -1           1           5           1            37
# 2              -3           0           5           0            35
# 3              -4          -1           4          -1            34
# 4              -4          -1           3          -1            34
# ...           ...         ...         ...         ...           ...
# 264115         10          17          17          17            15
# 264116         11          17          17          17            14
# 264117         11          17          17          17            13
# 264118         11          16          16          16            12
# 264119         11          16          16          16            11
#
#         cloudcover            date_time             file  humidity  \
# 0               63  2020-01-01 00:00:00     islip,ny.csv        67
# 1               49  2020-01-01 01:00:00     islip,ny.csv        63
# 2               35  2020-01-01 02:00:00     islip,ny.csv        60
# 3               21  2020-01-01 03:00:00     islip,ny.csv        57
# 4               19  2020-01-01 04:00:00     islip,ny.csv        56
# ...            ...                  ...              ...       ...
# 264115          64  2020-01-31 19:00:00  santaana,ca.csv        64
# 264116          59  2020-01-31 20:00:00  santaana,ca.csv        67
# 264117          53  2020-01-31 21:00:00  santaana,ca.csv        70
# 264118          61  2020-01-31 22:00:00  santaana,ca.csv        71
# 264119          68  2020-01-31 23:00:00  santaana,ca.csv        73
#
#            location  ...  pressure  sunHour   sunrise    sunset tempC  \
# 0          islip,ny  ...      1004      8.7  08:17 AM  05:36 PM     6
# 1          islip,ny  ...      1004      8.7  08:17 AM  05:36 PM     5
# 2          islip,ny  ...      1004      8.7  08:17 AM  05:36 PM     5
# 3          islip,ny  ...      1004      8.7  08:17 AM  05:36 PM     4
# 4          islip,ny  ...      1005      8.7  08:17 AM  05:36 PM     3
# ...             ...  ...       ...      ...       ...       ...   ...
# 264115  santaana,ca  ...      1019      7.2  06:33 AM  05:43 PM    17
# 264116  santaana,ca  ...      1019      7.2  06:33 AM  05:43 PM    17
# 264117  santaana,ca  ...      1020      7.2  06:33 AM  05:43 PM    17
# 264118  santaana,ca  ...      1020      7.2  06:33 AM  05:43 PM    16
# 264119  santaana,ca  ...      1020      7.2  06:33 AM  05:43 PM    16
#
#         totalSnow_cm  uvIndex  visibility winddirDegree windspeedKmph
# 0                0.0        2           9           271            26
# 1                0.0        2          10           274            25
# 2                0.0        2          10           276            24
# 3                0.0        2          10           279            24
# 4                0.0        2          10           280            24
# ...              ...      ...         ...           ...           ...
# 264115           0.0        5          10           157            10
# 264116           0.0        5          10           153             9
# 264117           0.0        5          10           149             9
# 264118           0.0        5          10           143             8
# 264119           0.0        5          10           137             7
#
# [264120 rows x 26 columns]

# %%
weather_2020_df = pd.DataFrame(merged_2020_df, columns = ['location','date_time','precipMM','visibility','cloudcover','windspeedKmph','humidity',])
weather_2020_df
# Out:
#            location            date_time  precipMM  visibility  cloudcover  \
# 0          islip,ny  2020-01-01 00:00:00       0.1           9          63
# 1          islip,ny  2020-01-01 01:00:00       0.1          10          49
# 2          islip,ny  2020-01-01 02:00:00       0.0          10          35
# 3          islip,ny  2020-01-01 03:00:00       0.0          10          21
# 4          islip,ny  2020-01-01 04:00:00       0.0          10          19
# ...             ...                  ...       ...         ...         ...
# 264115  santaana,ca  2020-01-31 19:00:00       0.0          10          64
# 264116  santaana,ca  2020-01-31 20:00:00       0.0          10          59
# 264117  santaana,ca  2020-01-31 21:00:00       0.0          10          53
# 264118  santaana,ca  2020-01-31 22:00:00       0.0          10          61
# 264119  santaana,ca  2020-01-31 23:00:00       0.0          10          68
#
#         windspeedKmph  humidity
# 0                  26        67
# 1                  25        63
# 2                  24        60
# 3                  24        57
# 4                  24        56
# ...               ...       ...
# 264115             10        64
# 264116              9        67
# 264117              9        70
# 264118              8        71
# 264119              7        73
#
# [264120 rows x 7 columns]

# %%
#Export to CSV
weather_2020_df.to_csv("../../weather_data/weather_2020_df.csv", index=False)
