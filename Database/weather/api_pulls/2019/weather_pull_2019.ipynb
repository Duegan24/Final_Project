# %%
#Import requests library and API key
import requests
from config import weather_api_key

# Import Dependencies
import pandas as pd

# Import Historical API Package
from wwo_hist import retrieve_hist_data

# Import glob dependncies
import os, glob

# %%
# Import CSV
city_code_api_df = pd.read_csv('../../../Flight_data_files/post_hardcode_cities.csv',index_col='Unnamed: 0')
city_code_api_df
# Out:
#     Airport Code           City
# 0            ABR    aberdeen,sd
# 1            ABI     abilene,tx
# 2            ADK  adakisland,ak
# 3            CAK       akron,oh
# 4            ALB      albany,ny
# ..           ...            ...
# 317          ILM  wilmington,nc
# 318          ORH   worcester,ma
# 319          WRG    wrangell,ak
# 320          YAK     yakutat,ak
# 321          YUM        yuma,az
#
# [322 rows x 2 columns]

# %%
cities_unique = []
for city in city_code_api_df['City']:
    if city not in cities_unique:
        cities_unique.append(city)
print(cities_unique)
# Out:
# ['aberdeen,sd', 'abilene,tx', 'adakisland,ak', 'akron,oh', 'albany,ny', 'albuquerque,nm', 'alexandria,la', 'easton,pa', 'alpena,mi', 'amarillo,tx', 'anchorage,ak', 'appleton,wi', 'arcata,ca', 'asheville,nc', 'huntington,wv', 'aspen,co', 'atlanta,ga', 'augusta,ga', 'austin,tx', 'bakersfield,ca', 'baltimore,md', 'bangor,me', 'barrow,ak', 'batonrouge,la', 'saginaw,mi', 'beaumont,tx', 'belleville,il', 'bellingham,wa', 'bemidji,mn', 'bethel,ak', 'billings,mt', 'gulfport,ms', 'binghamton,ny', 'birmingham,al', 'bismarck,nd', 'bloomington,il', 'boise,id', 'boston,ma', 'bozeman,mt', 'brainerd,mn', 'bristol,tn', 'brownsville,tx', 'brunswick,ga', 'buffalo,ny', 'burbank,ca', 'burlington,vt', 'butte,mt', 'capegirardeau,mo', 'monterey,ca', 'casper,wy', 'cedarcity,ut', 'cedarrapids,ia', 'champaign,il', 'charleston,sc', 'charleston,wv', 'charlotte,nc', 'charlottesville,va', 'chattanooga,tn', 'cheyenne,wy', 'chicago,il', 'chisholm,mn', 'cincinnati,oh', 'clarksburg,wv', 'clearwater,fl', 'cleveland,oh', 'yellowstone,wy', 'collegestation,tx', 'coloradosprings,co', 'columbia,mo', 'columbia,sc', 'columbus,ga', 'columbus,ms', 'columbus,oh', 'cordova,ak', 'corpuschristi,tx', 'fortworth,tx', 'dayton,oh', 'daytonabeach,fl', 'denver,co', 'desmoines,ia', 'detroit,mi', "devil'slake,nd", 'dothan,al', 'dubuque,ia', 'duluth,mn', 'durango,co', 'durham,nc', 'eauclaire,wi', 'elpaso,tx', 'elko,nv', 'elmira,ny', 'erie,pa', 'escanaba,mi', 'eugene,or', 'evansville,in', 'fairbanks,ak', 'fargo,nd', 'fayetteville,ar', 'fayetteville,nc', 'flagstaff,az', 'flint,mi', 'fortlauderdale,fl', 'fortmyers,fl', 'fortsmith,ar', 'fortwaltonbeach,fl', 'fortwayne,in', 'fresno,ca', 'gainesville,fl', 'gardencity,ks', 'gillette,wy', 'longview,tx', 'grandforks,nd', 'grandisland,ne', 'grandjunction,co', 'grandrapids,mi', 'greatfalls,mt', 'greenbay,wi', 'greensboro,nc', 'greenville,sc', 'gunnison,co', 'hagerstown,md', 'hailey,id', 'hampton,va', 'hancock,mi', 'harlingen,tx', 'harrisburg,pa', 'hartford,ct', 'hayden,co', 'hays,ks', 'helena,mt', 'hilo,hi', 'hiltonhead,sc', 'honolulu,hi', 'houston,tx', 'huntsville,al', 'idahofalls,id', 'indianapolis,in', 'internationalfalls,mn', 'ironmountain,mi', 'islip,ny', 'ithaca,ny', 'jacksonhole,wy', 'jackson,ms', 'jacksonville,fl', 'jacksonville,nc', 'jamestown,nd', 'joplin,mo', 'juneau,ak', 'maui,hi', 'kalamazoo,mi', 'kansascity,mo', 'kauai,hi', 'kearney,ne', 'ketchikan,ak', 'keywest,fl', 'knoxville,tn', 'kodiak,ak', 'kona,hi', 'kotzebue,ak', 'lacrosse,wi', 'lafayette,la', 'lakecharles,la', 'lansing,mi', 'laramie,wy', 'laredo,tx', 'lasvegas,nv', 'latrobe,pa', 'laurel,ms', 'lawton,ok', 'lewisburg,wv', 'lewiston,id', 'lexington,ky', 'liberal,ks', 'lincoln,ne', 'littlerock,ar', 'longbeach,ca', 'losangeles,ca', 'louisville,ky', 'lubbock,tx', 'madison,wi', 'manchester,nh', 'manhattan,ks', 'marquette,mi', 'mcallen,tx', 'medford,or', 'melbourne,fl', 'memphis,tn', 'meridian,ms', 'miami,fl', 'odessa,tx', 'milwaukee,wi', 'minneapolis,mn', 'minot,nd', 'missoula,mt', 'moab,ut', 'mobile,al', 'moline,il', 'monroe,la', 'montgomery,al', 'montrose,co', 'muskegon,mi', 'myrtlebeach,sc', 'nashville,tn', 'newhaven,ct', 'neworleans,la', 'newyork,ny', 'newark,nj', 'newburgh,ny', 'nome,ak', 'norfolk,va', 'northbend,or', 'northplatte,ne', 'oakland,ca', 'ogdensburg,ny', 'oklahomacity,ok', 'omaha,ne', 'ontario,ca', 'orangecounty,ca', 'orlando,fl', 'owensboro,ky', 'paducah,ky', 'palmsprings,ca', 'pasco,wa', 'pellston,mi', 'pensacola,fl', 'peoria,il', 'petersburg,ak', 'philadelphia,pa', 'trenton,nj', 'phoenix,az', 'pierre,sd', 'pittsburgh,pa', 'pocatello,id', 'ponce,puertorico', 'portland,me', 'portland,or', 'portsmouth,nh', 'prescott,az', 'providence,ri', 'deadhorse,ak', 'pueblo,co', 'quincy,il', 'rapidcity,sd', 'redding,ca', 'redmond,or', 'reno,nv', 'rhinelander,wi,', 'richmond,va', 'riverton,wy', 'roanoke,va', 'rochester,mn', 'rochester,ny', 'rocksprings,wy', 'roswell,nm', 'sacramento,ca', 'saintcloud,mn', 'saintgeorge,ut', 'saintlouis,mo', 'salina,ks', 'saltlakecity,ut', 'sana ...

# %%
start_date = '01-JAN-2019'
end_date = '31-JAN-2019'
location_list = cities_unique
frequency = 1

# %%
hist_weather_data_2019 = retrieve_hist_data(weather_api_key,
                                   location_list,
                                   start_date,
                                   end_date,
                                   frequency,
                                   location_label = False,
                                   export_csv = True,
                                   store_df = True)
# Out:
# Retrieving weather data for aberdeen,sd
#
#
# Currently retrieving data for aberdeen,sd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.465034
#
#
# export aberdeen,sd completed!
#
#
#
#
# Retrieving weather data for abilene,tx
#
#
# Currently retrieving data for abilene,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.827061
#
#
# export abilene,tx completed!
#
#
#
#
# Retrieving weather data for adakisland,ak
#
#
# Currently retrieving data for adakisland,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.507816
#
#
# export adakisland,ak completed!
#
#
#
#
# Retrieving weather data for akron,oh
#
#
# Currently retrieving data for akron,oh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.462055
#
#
# export akron,oh completed!
#
#
#
#
# Retrieving weather data for albany,ny
#
#
# Currently retrieving data for albany,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.434466
#
#
# export albany,ny completed!
#
#
#
#
# Retrieving weather data for albuquerque,nm
#
#
# Currently retrieving data for albuquerque,nm: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.417763
#
#
# export albuquerque,nm completed!
#
#
#
#
# Retrieving weather data for alexandria,la
#
#
# Currently retrieving data for alexandria,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.461966
#
#
# export alexandria,la completed!
#
#
#
#
# Retrieving weather data for easton,pa
#
#
# Currently retrieving data for easton,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.407863
#
#
# export easton,pa completed!
#
#
#
#
# Retrieving weather data for alpena,mi
#
#
# Currently retrieving data for alpena,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.431752
#
#
# export alpena,mi completed!
#
#
#
#
# Retrieving weather data for amarillo,tx
#
#
# Currently retrieving data for amarillo,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.479340
#
#
# export amarillo,tx completed!
#
#
#
#
# Retrieving weather data for anchorage,ak
#
#
# Currently retrieving data for anchorage,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.822039
#
#
# export anchorage,ak completed!
#
#
#
#
# Retrieving weather data for appleton,wi
#
#
# Currently retrieving data for appleton,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.654332
#
#
# export appleton,wi completed!
#
#
#
#
# Retrieving weather data for arcata,ca
#
#
# Currently retrieving data for arcata,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.568998
#
#
# export arcata,ca completed!
#
#
#
#
# Retrieving weather data for asheville,nc
#
#
# Currently retrieving data for asheville,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.449766
#
#
# export asheville,nc completed!
#
#
#
#
# Retrieving weather data for huntington,wv
#
#
# Currently retrieving data for huntington,wv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.483430
#
#
# export huntington,wv completed!
#
#
#
#
# Retrieving weather data for aspen,co
#
#
# Currently retrieving data for aspen,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.623763
#
#
# export aspen,co completed!
#
#
#
#
# Retrieving weather data for atlanta,ga
#
#
# Currently retrieving data for atlanta,ga: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.778820
#
#
# export atlanta,ga completed!
#
#
#
#
# Retrieving weather data for augusta,ga
#
#
# Currently retrieving data for augusta,ga: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.629551
#
#
# export augusta,ga completed!
#
#
#
#
# Retrieving weather data for austin,tx
#
#
# Currently retrieving data for austin,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.886503
#
#
# export austin,tx completed!
#
#
#
#
# Retrieving weather data for bakersfield,ca
#
#
# Currently retrieving data for bakersfield,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.451099
#
#
# export bakersfield,ca completed!
#
#
#
#
# Retrieving weather data for baltimore,md
#
#
# Currently retrieving data for baltimore,md: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.471117
#
#
# export baltimore,md completed!
#
#
#
#
# Retrieving weather data for bangor,me
#
#
# Currently retrieving data for bangor,me: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.437869
#
#
# export bangor,me completed!
#
#
#
#
# Retrieving weather data for barrow,ak
#
#
# Currently retrieving data for barrow,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.489793
#
#
# export barrow,ak completed!
#
#
#
#
# Retrieving weather data for batonrouge,la
#
#
# Currently retrieving data for batonrouge,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.400432
#
#
# export batonrouge,la completed!
#
#
#
#
# Retrieving weather data for saginaw,mi
#
#
# Currently retrieving data for saginaw,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.318700
#
#
# export saginaw,mi completed!
#
#
#
#
# Retrieving weather data for beaumont,tx
#
#
# Currently retrieving data for beaumont,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.556683
#
#
# export beaumont,tx completed!
#
#
#
#
# Retrieving weather data for belleville,il
#
#
# Currently retrieving data for belleville,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.356816
#
#
# export belleville,il completed!
#
#
#
#
# Retrieving weather data for bellingham,wa
#
#
# Currently retrieving data for bellingham,wa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.410807
#
#
# export bellingham,wa completed!
#
#
#
#
# Retrieving weather data for bemidji,mn
#
#
# Currently retrieving data for bemidji,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.552290
#
#
# export bemidji,mn completed!
#
#
#
#
# Retrieving weather data for bethel,ak
#
#
# Currently retrieving data for bethel,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.403496
#
#
# export bethel,ak completed!
#
#
#
#
# Retrieving weather data for billings,mt
#
#
# Currently retrieving data for billings,mt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.496716
#
#
# export billings,mt completed!
#
#
#
#
# Retrieving weather data for gulfport,ms
#
#
# Currently retrieving data for gulfport,ms: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.417442
#
#
# export gulfport,ms completed!
#
#
#
#
# Retrieving weather data for binghamton,ny
#
#
# Currently retrieving data for binghamton,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.048380
#
#
# export binghamton,ny completed!
#
#
#
#
# Retrieving weather data for birmingham,al
#
#
# Currently retrieving data for birmingham,al: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.571838
#
#
# export birmingham,al completed!
#
#
#
#
# Retrieving weather data for bismarck,nd
#
#
# Currently retrieving data for bismarck,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.483264
#
#
# export bismarck,nd completed!
#
#
#
#
# Retrieving weather data for bloomington,il
#
#
# Currently retrieving data for bloomington,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.437228
#
#
# export bloomington,il completed!
#
#
#
#
# Retrieving weather data for boise,id
#
#
# Currently retrieving data for boise,id: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.379327
#
#
# export boise,id completed!
#
#
#
#
# Retrieving weather data for boston,ma
#
#
# Currently retrieving data for boston,ma: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.247376
#
#
# export boston,ma completed!
#
#
#
#
# Retrieving weather data for bozeman,mt
#
#
# Currently retrieving data for bozeman,mt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.398718
#
#
# export bozeman,mt completed!
#
#
#
#
# Retrieving weather data for brainerd,mn
#
#
# Currently retrieving data for brainerd,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.603040
#
#
# export brainerd,mn completed!
#
#
#
#
# Retrieving weather data for bristol,tn
#
#
# Currently retrieving data for bristol,tn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.264088
#
#
# export bristol,tn completed!
#
#
#
#
# Retrieving weather data for brownsville,tx
#
#
# Currently retrieving data for brownsville,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.353967
#
#
# export brownsville,tx completed!
#
#
#
#
# Retrieving weather data for brunswick,ga
#
#
# Currently retrieving data for brunswick,ga: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.324529
#
#
# export brunswick,ga completed!
#
#
#
#
# Retrieving weather data for buffalo,ny
#
#
# Currently retrieving data for buffalo,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.369115
#
#
# export buffalo,ny completed!
#
#
#
#
# Retrieving weather data for burbank,ca
#
#
# Currently retrieving data for burbank,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.386185
#
#
# export burbank,ca completed!
#
#
#
#
# Retrieving weather data for burlington,vt
#
#
# Currently retrieving data for burlington,vt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.369489
#
#
# export burlington,vt completed!
#
#
#
#
# Retrieving weather data for butte,mt
#
#
# Currently retrieving data for butte,mt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.367559
#
#
# export butte,mt completed!
#
#
#
#
# Retrieving weather data for capegirardeau,mo
#
#
# Currently retrieving data for capegirardeau,mo: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.510724
#
#
# export capegirardeau,mo completed!
#
#
#
#
# Retrieving weather data for monterey,ca
#
#
# Currently retrieving data for monterey,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.937107
#
#
# export monterey,ca completed!
#
#
#
#
# Retrieving weather data for casper,wy
#
#
# Currently retrieving data for casper,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.456471
#
#
# export casper,wy completed!
#
#
#
#
# Retrieving weather data for cedarcity,ut
#
#
# Currently retrieving data for cedarcity,ut: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.411075
#
#
# export cedarcity,ut completed!
#
#
#
#
# Retrieving weather data for cedarrapids,ia
#
#
# Currently retrieving data for cedarrapids,ia: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.486599
#
#
# export cedarrapids,ia completed!
#
#
#
#
# Retrieving weather data for champaign,il
#
#
# Currently retrieving data for champaign,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.426969
#
#
# export champaign,il completed!
#
#
#
#
# Retrieving weather data for charleston,sc
#
#
# Currently retrieving data for charleston,sc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.324431
#
#
# export charleston,sc completed!
#
#
#
#
# Retrieving weather data for charleston,wv
#
#
# Currently retrieving data for charleston,wv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.367525
#
#
# export charleston,wv completed!
#
#
#
#
# Retrieving weather data for charlotte,nc
#
#
# Currently retrieving data for charlotte,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.620700
#
#
# export charlotte,nc completed!
#
#
#
#
# Retrieving weather data for charlottesville,va
#
#
# Currently retrieving data for charlottesville,va: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.482516
#
#
# export charlottesville,va completed!
#
#
#
#
# Retrieving weather data for chattanooga,tn
#
#
# Currently retrieving data for chattanooga,tn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.369622
#
#
# export chattanooga,tn completed!
#
#
#
#
# Retrieving weather data for cheyenne,wy
#
#
# Currently retrieving data for cheyenne,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.422178
#
#
# export cheyenne,wy completed!
#
#
#
#
# Retrieving weather data for chicago,il
#
#
# Currently retrieving data for chicago,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.441948
#
#
# export chicago,il completed!
#
#
#
#
# Retrieving weather data for chisholm,mn
#
#
# Currently retrieving data for chisholm,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.396600
#
#
# export chisholm,mn completed!
#
#
#
#
# Retrieving weather data for cincinnati,oh
#
#
# Currently retrieving data for cincinnati,oh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.412320
#
#
# export cincinnati,oh completed!
#
#
#
#
# Retrieving weather data for clarksburg,wv
#
#
# Currently retrieving data for clarksburg,wv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.398437
#
#
# export clarksburg,wv completed!
#
#
#
#
# Retrieving weather data for clearwater,fl
#
#
# Currently retrieving data for clearwater,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.424347
#
#
# export clearwater,fl completed!
#
#
#
#
# Retrieving weather data for cleveland,oh
#
#
# Currently retrieving data for cleveland,oh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.813427
#
#
# export cleveland,oh completed!
#
#
#
#
# Retrieving weather data for yellowstone,wy
#
#
# Currently retrieving data for yellowstone,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.463390
#
#
# export yellowstone,wy completed!
#
#
#
#
# Retrieving weather data for collegestation,tx
#
#
# Currently retrieving data for collegestation,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.387502
#
#
# export collegestation,tx completed!
#
#
#
#
# Retrieving weather data for coloradosprings,co
#
#
# Currently retrieving data for coloradosprings,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.443932
#
#
# export coloradosprings,co completed!
#
#
#
#
# Retrieving weather data for columbia,mo
#
#
# Currently retrieving data for columbia,mo: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.386240
#
#
# export columbia,mo completed!
#
#
#
#
# Retrieving weather data for columbia,sc
#
#
# Currently retrieving data for columbia,sc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.329153
#
#
# export columbia,sc completed!
#
#
#
#
# Retrieving weather data for columbus,ga
#
#
# Currently retrieving data for columbus,ga: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.412557
#
#
# export columbus,ga completed!
#
#
#
#
# Retrieving weather data for columbus,ms
#
#
# Currently retrieving data for columbus,ms: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.599934
#
#
# export columbus,ms completed!
#
#
#
#
# Retrieving weather data for columbus,oh
#
#
# Currently retrieving data for columbus,oh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.726735
#
#
# export columbus,oh completed!
#
#
#
#
# Retrieving weather data for cordova,ak
#
#
# Currently retrieving data for cordova,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.414994
#
#
# export cordova,ak completed!
#
#
#
#
# Retrieving weather data for corpuschristi,tx
#
#
# Currently retrieving data for corpuschristi,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.181811
#
#
# export corpuschristi,tx completed!
#
#
#
#
# Retrieving weather data for fortworth,tx
#
#
# Currently retrieving data for fortworth,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.605072
#
#
# export fortworth,tx completed!
#
#
#
#
# Retrieving weather data for dayton,oh
#
#
# Currently retrieving data for dayton,oh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.355313
#
#
# export dayton,oh completed!
#
#
#
#
# Retrieving weather data for daytonabeach,fl
#
#
# Currently retrieving data for daytonabeach,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.452837
#
#
# export daytonabeach,fl completed!
#
#
#
#
# Retrieving weather data for denver,co
#
#
# Currently retrieving data for denver,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.447563
#
#
# export denver,co completed!
#
#
#
#
# Retrieving weather data for desmoines,ia
#
#
# Currently retrieving data for desmoines,ia: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.407380
#
#
# export desmoines,ia completed!
#
#
#
#
# Retrieving weather data for detroit,mi
#
#
# Currently retrieving data for detroit,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.703157
#
#
# export detroit,mi completed!
#
#
#
#
# Retrieving weather data for devil'slake,nd
#
#
# Currently retrieving data for devil'slake,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.576910
#
#
# export devil'slake,nd completed!
#
#
#
#
# Retrieving weather data for dothan,al
#
#
# Currently retrieving data for dothan,al: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.368631
#
#
# export dothan,al completed!
#
#
#
#
# Retrieving weather data for dubuque,ia
#
#
# Currently retrieving data for dubuque,ia: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.408963
#
#
# export dubuque,ia completed!
#
#
#
#
# Retrieving weather data for duluth,mn
#
#
# Currently retrieving data for duluth,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.330194
#
#
# export duluth,mn completed!
#
#
#
#
# Retrieving weather data for durango,co
#
#
# Currently retrieving data for durango,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.456160
#
#
# export durango,co completed!
#
#
#
#
# Retrieving weather data for durham,nc
#
#
# Currently retrieving data for durham,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404501
#
#
# export durham,nc completed!
#
#
#
#
# Retrieving weather data for eauclaire,wi
#
#
# Currently retrieving data for eauclaire,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.364872
#
#
# export eauclaire,wi completed!
#
#
#
#
# Retrieving weather data for elpaso,tx
#
#
# Currently retrieving data for elpaso,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.200862
#
#
# export elpaso,tx completed!
#
#
#
#
# Retrieving weather data for elko,nv
#
#
# Currently retrieving data for elko,nv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.424417
#
#
# export elko,nv completed!
#
#
#
#
# Retrieving weather data for elmira,ny
#
#
# Currently retrieving data for elmira,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.401378
#
#
# export elmira,ny completed!
#
#
#
#
# Retrieving weather data for erie,pa
#
#
# Currently retrieving data for erie,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.358451
#
#
# export erie,pa completed!
#
#
#
#
# Retrieving weather data for escanaba,mi
#
#
# Currently retrieving data for escanaba,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.418555
#
#
# export escanaba,mi completed!
#
#
#
#
# Retrieving weather data for eugene,or
#
#
# Currently retrieving data for eugene,or: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.353208
#
#
# export eugene,or completed!
#
#
#
#
# Retrieving weather data for evansville,in
#
#
# Currently retrieving data for evansville,in: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.366251
#
#
# export evansville,in completed!
#
#
#
#
# Retrieving weather data for fairbanks,ak
#
#
# Currently retrieving data for fairbanks,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.454411
#
#
# export fairbanks,ak completed!
#
#
#
#
# Retrieving weather data for fargo,nd
#
#
# Currently retrieving data for fargo,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.402797
#
#
# export fargo,nd completed!
#
#
#
#
# Retrieving weather data for fayetteville,ar
#
#
# Currently retrieving data for fayetteville,ar: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.427435
#
#
# export fayetteville,ar completed!
#
#
#
#
# Retrieving weather data for fayetteville,nc
#
#
# Currently retrieving data for fayetteville,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.310089
#
#
# export fayetteville,nc completed!
#
#
#
#
# Retrieving weather data for flagstaff,az
#
#
# Currently retrieving data for flagstaff,az: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.438370
#
#
# export flagstaff,az completed!
#
#
#
#
# Retrieving weather data for flint,mi
#
#
# Currently retrieving data for flint,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.343613
#
#
# export flint,mi completed!
#
#
#
#
# Retrieving weather data for fortlauderdale,fl
#
#
# Currently retrieving data for fortlauderdale,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383215
#
#
# export fortlauderdale,fl completed!
#
#
#
#
# Retrieving weather data for fortmyers,fl
#
#
# Currently retrieving data for fortmyers,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.471291
#
#
# export fortmyers,fl completed!
#
#
#
#
# Retrieving weather data for fortsmith,ar
#
#
# Currently retrieving data for fortsmith,ar: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.424852
#
#
# export fortsmith,ar completed!
#
#
#
#
# Retrieving weather data for fortwaltonbeach,fl
#
#
# Currently retrieving data for fortwaltonbeach,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.447687
#
#
# export fortwaltonbeach,fl completed!
#
#
#
#
# Retrieving weather data for fortwayne,in
#
#
# Currently retrieving data for fortwayne,in: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.405458
#
#
# export fortwayne,in completed!
#
#
#
#
# Retrieving weather data for fresno,ca
#
#
# Currently retrieving data for fresno,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.343298
#
#
# export fresno,ca completed!
#
#
#
#
# Retrieving weather data for gainesville,fl
#
#
# Currently retrieving data for gainesville,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.288740
#
#
# export gainesville,fl completed!
#
#
#
#
# Retrieving weather data for gardencity,ks
#
#
# Currently retrieving data for gardencity,ks: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.420631
#
#
# export gardencity,ks completed!
#
#
#
#
# Retrieving weather data for gillette,wy
#
#
# Currently retrieving data for gillette,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.319049
#
#
# export gillette,wy completed!
#
#
#
#
# Retrieving weather data for longview,tx
#
#
# Currently retrieving data for longview,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.565932
#
#
# export longview,tx completed!
#
#
#
#
# Retrieving weather data for grandforks,nd
#
#
# Currently retrieving data for grandforks,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.561233
#
#
# export grandforks,nd completed!
#
#
#
#
# Retrieving weather data for grandisland,ne
#
#
# Currently retrieving data for grandisland,ne: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.678797
#
#
# export grandisland,ne completed!
#
#
#
#
# Retrieving weather data for grandjunction,co
#
#
# Currently retrieving data for grandjunction,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.643235
#
#
# export grandjunction,co completed!
#
#
#
#
# Retrieving weather data for grandrapids,mi
#
#
# Currently retrieving data for grandrapids,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.414335
#
#
# export grandrapids,mi completed!
#
#
#
#
# Retrieving weather data for greatfalls,mt
#
#
# Currently retrieving data for greatfalls,mt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.412129
#
#
# export greatfalls,mt completed!
#
#
#
#
# Retrieving weather data for greenbay,wi
#
#
# Currently retrieving data for greenbay,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.357936
#
#
# export greenbay,wi completed!
#
#
#
#
# Retrieving weather data for greensboro,nc
#
#
# Currently retrieving data for greensboro,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.373437
#
#
# export greensboro,nc completed!
#
#
#
#
# Retrieving weather data for greenville,sc
#
#
# Currently retrieving data for greenville,sc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.392146
#
#
# export greenville,sc completed!
#
#
#
#
# Retrieving weather data for gunnison,co
#
#
# Currently retrieving data for gunnison,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.390847
#
#
# export gunnison,co completed!
#
#
#
#
# Retrieving weather data for hagerstown,md
#
#
# Currently retrieving data for hagerstown,md: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.595460
#
#
# export hagerstown,md completed!
#
#
#
#
# Retrieving weather data for hailey,id
#
#
# Currently retrieving data for hailey,id: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.511657
#
#
# export hailey,id completed!
#
#
#
#
# Retrieving weather data for hampton,va
#
#
# Currently retrieving data for hampton,va: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.323778
#
#
# export hampton,va completed!
#
#
#
#
# Retrieving weather data for hancock,mi
#
#
# Currently retrieving data for hancock,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.366864
#
#
# export hancock,mi completed!
#
#
#
#
# Retrieving weather data for harlingen,tx
#
#
# Currently retrieving data for harlingen,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.358791
#
#
# export harlingen,tx completed!
#
#
#
#
# Retrieving weather data for harrisburg,pa
#
#
# Currently retrieving data for harrisburg,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.502395
#
#
# export harrisburg,pa completed!
#
#
#
#
# Retrieving weather data for hartford,ct
#
#
# Currently retrieving data for hartford,ct: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.286371
#
#
# export hartford,ct completed!
#
#
#
#
# Retrieving weather data for hayden,co
#
#
# Currently retrieving data for hayden,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.387518
#
#
# export hayden,co completed!
#
#
#
#
# Retrieving weather data for hays,ks
#
#
# Currently retrieving data for hays,ks: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.663730
#
#
# export hays,ks completed!
#
#
#
#
# Retrieving weather data for helena,mt
#
#
# Currently retrieving data for helena,mt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.766877
#
#
# export helena,mt completed!
#
#
#
#
# Retrieving weather data for hilo,hi
#
#
# Currently retrieving data for hilo,hi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.494088
#
#
# export hilo,hi completed!
#
#
#
#
# Retrieving weather data for hiltonhead,sc
#
#
# Currently retrieving data for hiltonhead,sc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.542378
#
#
# export hiltonhead,sc completed!
#
#
#
#
# Retrieving weather data for honolulu,hi
#
#
# Currently retrieving data for honolulu,hi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.656916
#
#
# export honolulu,hi completed!
#
#
#
#
# Retrieving weather data for houston,tx
#
#
# Currently retrieving data for houston,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.518594
#
#
# export houston,tx completed!
#
#
#
#
# Retrieving weather data for huntsville,al
#
#
# Currently retrieving data for huntsville,al: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.363341
#
#
# export huntsville,al completed!
#
#
#
#
# Retrieving weather data for idahofalls,id
#
#
# Currently retrieving data for idahofalls,id: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.366746
#
#
# export idahofalls,id completed!
#
#
#
#
# Retrieving weather data for indianapolis,in
#
#
# Currently retrieving data for indianapolis,in: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.565984
#
#
# export indianapolis,in completed!
#
#
#
#
# Retrieving weather data for internationalfalls,mn
#
#
# Currently retrieving data for internationalfalls,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.614090
#
#
# export internationalfalls,mn completed!
#
#
#
#
# Retrieving weather data for ironmountain,mi
#
#
# Currently retrieving data for ironmountain,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.340108
#
#
# export ironmountain,mi completed!
#
#
#
#
# Retrieving weather data for islip,ny
#
#
# Currently retrieving data for islip,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.344662
#
#
# export islip,ny completed!
#
#
#
#
# Retrieving weather data for ithaca,ny
#
#
# Currently retrieving data for ithaca,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.360817
#
#
# export ithaca,ny completed!
#
#
#
#
# Retrieving weather data for jacksonhole,wy
#
#
# Currently retrieving data for jacksonhole,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.395641
#
#
# export jacksonhole,wy completed!
#
#
#
#
# Retrieving weather data for jackson,ms
#
#
# Currently retrieving data for jackson,ms: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.422777
#
#
# export jackson,ms completed!
#
#
#
#
# Retrieving weather data for jacksonville,fl
#
#
# Currently retrieving data for jacksonville,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.334844
#
#
# export jacksonville,fl completed!
#
#
#
#
# Retrieving weather data for jacksonville,nc
#
#
# Currently retrieving data for jacksonville,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.464890
#
#
# export jacksonville,nc completed!
#
#
#
#
# Retrieving weather data for jamestown,nd
#
#
# Currently retrieving data for jamestown,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.914052
#
#
# export jamestown,nd completed!
#
#
#
#
# Retrieving weather data for joplin,mo
#
#
# Currently retrieving data for joplin,mo: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.520776
#
#
# export joplin,mo completed!
#
#
#
#
# Retrieving weather data for juneau,ak
#
#
# Currently retrieving data for juneau,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.429029
#
#
# export juneau,ak completed!
#
#
#
#
# Retrieving weather data for maui,hi
#
#
# Currently retrieving data for maui,hi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.399999
#
#
# export maui,hi completed!
#
#
#
#
# Retrieving weather data for kalamazoo,mi
#
#
# Currently retrieving data for kalamazoo,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.402250
#
#
# export kalamazoo,mi completed!
#
#
#
#
# Retrieving weather data for kansascity,mo
#
#
# Currently retrieving data for kansascity,mo: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.339484
#
#
# export kansascity,mo completed!
#
#
#
#
# Retrieving weather data for kauai,hi
#
#
# Currently retrieving data for kauai,hi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.425068
#
#
# export kauai,hi completed!
#
#
#
#
# Retrieving weather data for kearney,ne
#
#
# Currently retrieving data for kearney,ne: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.526793
#
#
# export kearney,ne completed!
#
#
#
#
# Retrieving weather data for ketchikan,ak
#
#
# Currently retrieving data for ketchikan,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.244622
#
#
# export ketchikan,ak completed!
#
#
#
#
# Retrieving weather data for keywest,fl
#
#
# Currently retrieving data for keywest,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.412834
#
#
# export keywest,fl completed!
#
#
#
#
# Retrieving weather data for knoxville,tn
#
#
# Currently retrieving data for knoxville,tn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.436687
#
#
# export knoxville,tn completed!
#
#
#
#
# Retrieving weather data for kodiak,ak
#
#
# Currently retrieving data for kodiak,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.313911
#
#
# export kodiak,ak completed!
#
#
#
#
# Retrieving weather data for kona,hi
#
#
# Currently retrieving data for kona,hi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.418693
#
#
# export kona,hi completed!
#
#
#
#
# Retrieving weather data for kotzebue,ak
#
#
# Currently retrieving data for kotzebue,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.453133
#
#
# export kotzebue,ak completed!
#
#
#
#
# Retrieving weather data for lacrosse,wi
#
#
# Currently retrieving data for lacrosse,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.323888
#
#
# export lacrosse,wi completed!
#
#
#
#
# Retrieving weather data for lafayette,la
#
#
# Currently retrieving data for lafayette,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.583443
#
#
# export lafayette,la completed!
#
#
#
#
# Retrieving weather data for lakecharles,la
#
#
# Currently retrieving data for lakecharles,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.560976
#
#
# export lakecharles,la completed!
#
#
#
#
# Retrieving weather data for lansing,mi
#
#
# Currently retrieving data for lansing,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.558760
#
#
# export lansing,mi completed!
#
#
#
#
# Retrieving weather data for laramie,wy
#
#
# Currently retrieving data for laramie,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.457641
#
#
# export laramie,wy completed!
#
#
#
#
# Retrieving weather data for laredo,tx
#
#
# Currently retrieving data for laredo,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.448521
#
#
# export laredo,tx completed!
#
#
#
#
# Retrieving weather data for lasvegas,nv
#
#
# Currently retrieving data for lasvegas,nv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.410652
#
#
# export lasvegas,nv completed!
#
#
#
#
# Retrieving weather data for latrobe,pa
#
#
# Currently retrieving data for latrobe,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.395374
#
#
# export latrobe,pa completed!
#
#
#
#
# Retrieving weather data for laurel,ms
#
#
# Currently retrieving data for laurel,ms: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.344483
#
#
# export laurel,ms completed!
#
#
#
#
# Retrieving weather data for lawton,ok
#
#
# Currently retrieving data for lawton,ok: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.489972
#
#
# export lawton,ok completed!
#
#
#
#
# Retrieving weather data for lewisburg,wv
#
#
# Currently retrieving data for lewisburg,wv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.012558
#
#
# export lewisburg,wv completed!
#
#
#
#
# Retrieving weather data for lewiston,id
#
#
# Currently retrieving data for lewiston,id: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.387891
#
#
# export lewiston,id completed!
#
#
#
#
# Retrieving weather data for lexington,ky
#
#
# Currently retrieving data for lexington,ky: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.374768
#
#
# export lexington,ky completed!
#
#
#
#
# Retrieving weather data for liberal,ks
#
#
# Currently retrieving data for liberal,ks: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.367262
#
#
# export liberal,ks completed!
#
#
#
#
# Retrieving weather data for lincoln,ne
#
#
# Currently retrieving data for lincoln,ne: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.333027
#
#
# export lincoln,ne completed!
#
#
#
#
# Retrieving weather data for littlerock,ar
#
#
# Currently retrieving data for littlerock,ar: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383865
#
#
# export littlerock,ar completed!
#
#
#
#
# Retrieving weather data for longbeach,ca
#
#
# Currently retrieving data for longbeach,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404966
#
#
# export longbeach,ca completed!
#
#
#
#
# Retrieving weather data for losangeles,ca
#
#
# Currently retrieving data for losangeles,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.550849
#
#
# export losangeles,ca completed!
#
#
#
#
# Retrieving weather data for louisville,ky
#
#
# Currently retrieving data for louisville,ky: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.756688
#
#
# export louisville,ky completed!
#
#
#
#
# Retrieving weather data for lubbock,tx
#
#
# Currently retrieving data for lubbock,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.406473
#
#
# export lubbock,tx completed!
#
#
#
#
# Retrieving weather data for madison,wi
#
#
# Currently retrieving data for madison,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.382621
#
#
# export madison,wi completed!
#
#
#
#
# Retrieving weather data for manchester,nh
#
#
# Currently retrieving data for manchester,nh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.362549
#
#
# export manchester,nh completed!
#
#
#
#
# Retrieving weather data for manhattan,ks
#
#
# Currently retrieving data for manhattan,ks: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.389605
#
#
# export manhattan,ks completed!
#
#
#
#
# Retrieving weather data for marquette,mi
#
#
# Currently retrieving data for marquette,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.338281
#
#
# export marquette,mi completed!
#
#
#
#
# Retrieving weather data for mcallen,tx
#
#
# Currently retrieving data for mcallen,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.390080
#
#
# export mcallen,tx completed!
#
#
#
#
# Retrieving weather data for medford,or
#
#
# Currently retrieving data for medford,or: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.507342
#
#
# export medford,or completed!
#
#
#
#
# Retrieving weather data for melbourne,fl
#
#
# Currently retrieving data for melbourne,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.456049
#
#
# export melbourne,fl completed!
#
#
#
#
# Retrieving weather data for memphis,tn
#
#
# Currently retrieving data for memphis,tn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.500103
#
#
# export memphis,tn completed!
#
#
#
#
# Retrieving weather data for meridian,ms
#
#
# Currently retrieving data for meridian,ms: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.359174
#
#
# export meridian,ms completed!
#
#
#
#
# Retrieving weather data for miami,fl
#
#
# Currently retrieving data for miami,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.430906
#
#
# export miami,fl completed!
#
#
#
#
# Retrieving weather data for odessa,tx
#
#
# Currently retrieving data for odessa,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.440311
#
#
# export odessa,tx completed!
#
#
#
#
# Retrieving weather data for milwaukee,wi
#
#
# Currently retrieving data for milwaukee,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.442897
#
#
# export milwaukee,wi completed!
#
#
#
#
# Retrieving weather data for minneapolis,mn
#
#
# Currently retrieving data for minneapolis,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.488927
#
#
# export minneapolis,mn completed!
#
#
#
#
# Retrieving weather data for minot,nd
#
#
# Currently retrieving data for minot,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.527722
#
#
# export minot,nd completed!
#
#
#
#
# Retrieving weather data for missoula,mt
#
#
# Currently retrieving data for missoula,mt: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.659613
#
#
# export missoula,mt completed!
#
#
#
#
# Retrieving weather data for moab,ut
#
#
# Currently retrieving data for moab,ut: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.340771
#
#
# export moab,ut completed!
#
#
#
#
# Retrieving weather data for mobile,al
#
#
# Currently retrieving data for mobile,al: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380420
#
#
# export mobile,al completed!
#
#
#
#
# Retrieving weather data for moline,il
#
#
# Currently retrieving data for moline,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.420772
#
#
# export moline,il completed!
#
#
#
#
# Retrieving weather data for monroe,la
#
#
# Currently retrieving data for monroe,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.504483
#
#
# export monroe,la completed!
#
#
#
#
# Retrieving weather data for montgomery,al
#
#
# Currently retrieving data for montgomery,al: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.515506
#
#
# export montgomery,al completed!
#
#
#
#
# Retrieving weather data for montrose,co
#
#
# Currently retrieving data for montrose,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.432412
#
#
# export montrose,co completed!
#
#
#
#
# Retrieving weather data for muskegon,mi
#
#
# Currently retrieving data for muskegon,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.563571
#
#
# export muskegon,mi completed!
#
#
#
#
# Retrieving weather data for myrtlebeach,sc
#
#
# Currently retrieving data for myrtlebeach,sc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.288541
#
#
# export myrtlebeach,sc completed!
#
#
#
#
# Retrieving weather data for nashville,tn
#
#
# Currently retrieving data for nashville,tn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.421097
#
#
# export nashville,tn completed!
#
#
#
#
# Retrieving weather data for newhaven,ct
#
#
# Currently retrieving data for newhaven,ct: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.472215
#
#
# export newhaven,ct completed!
#
#
#
#
# Retrieving weather data for neworleans,la
#
#
# Currently retrieving data for neworleans,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.379763
#
#
# export neworleans,la completed!
#
#
#
#
# Retrieving weather data for newyork,ny
#
#
# Currently retrieving data for newyork,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.854329
#
#
# export newyork,ny completed!
#
#
#
#
# Retrieving weather data for newark,nj
#
#
# Currently retrieving data for newark,nj: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.805158
#
#
# export newark,nj completed!
#
#
#
#
# Retrieving weather data for newburgh,ny
#
#
# Currently retrieving data for newburgh,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.337882
#
#
# export newburgh,ny completed!
#
#
#
#
# Retrieving weather data for nome,ak
#
#
# Currently retrieving data for nome,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.819428
#
#
# export nome,ak completed!
#
#
#
#
# Retrieving weather data for norfolk,va
#
#
# Currently retrieving data for norfolk,va: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.607847
#
#
# export norfolk,va completed!
#
#
#
#
# Retrieving weather data for northbend,or
#
#
# Currently retrieving data for northbend,or: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.308949
#
#
# export northbend,or completed!
#
#
#
#
# Retrieving weather data for northplatte,ne
#
#
# Currently retrieving data for northplatte,ne: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.457394
#
#
# export northplatte,ne completed!
#
#
#
#
# Retrieving weather data for oakland,ca
#
#
# Currently retrieving data for oakland,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.316908
#
#
# export oakland,ca completed!
#
#
#
#
# Retrieving weather data for ogdensburg,ny
#
#
# Currently retrieving data for ogdensburg,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383389
#
#
# export ogdensburg,ny completed!
#
#
#
#
# Retrieving weather data for oklahomacity,ok
#
#
# Currently retrieving data for oklahomacity,ok: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.363308
#
#
# export oklahomacity,ok completed!
#
#
#
#
# Retrieving weather data for omaha,ne
#
#
# Currently retrieving data for omaha,ne: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.312542
#
#
# export omaha,ne completed!
#
#
#
#
# Retrieving weather data for ontario,ca
#
#
# Currently retrieving data for ontario,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.401354
#
#
# export ontario,ca completed!
#
#
#
#
# Retrieving weather data for orangecounty,ca
#
#
# Currently retrieving data for orangecounty,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.599934
#
#
# export orangecounty,ca completed!
#
#
#
#
# Retrieving weather data for orlando,fl
#
#
# Currently retrieving data for orlando,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.529042
#
#
# export orlando,fl completed!
#
#
#
#
# Retrieving weather data for owensboro,ky
#
#
# Currently retrieving data for owensboro,ky: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404805
#
#
# export owensboro,ky completed!
#
#
#
#
# Retrieving weather data for paducah,ky
#
#
# Currently retrieving data for paducah,ky: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.379800
#
#
# export paducah,ky completed!
#
#
#
#
# Retrieving weather data for palmsprings,ca
#
#
# Currently retrieving data for palmsprings,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.374109
#
#
# export palmsprings,ca completed!
#
#
#
#
# Retrieving weather data for pasco,wa
#
#
# Currently retrieving data for pasco,wa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.347208
#
#
# export pasco,wa completed!
#
#
#
#
# Retrieving weather data for pellston,mi
#
#
# Currently retrieving data for pellston,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.411565
#
#
# export pellston,mi completed!
#
#
#
#
# Retrieving weather data for pensacola,fl
#
#
# Currently retrieving data for pensacola,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.537301
#
#
# export pensacola,fl completed!
#
#
#
#
# Retrieving weather data for peoria,il
#
#
# Currently retrieving data for peoria,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.878616
#
#
# export peoria,il completed!
#
#
#
#
# Retrieving weather data for petersburg,ak
#
#
# Currently retrieving data for petersburg,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.354545
#
#
# export petersburg,ak completed!
#
#
#
#
# Retrieving weather data for philadelphia,pa
#
#
# Currently retrieving data for philadelphia,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.635354
#
#
# export philadelphia,pa completed!
#
#
#
#
# Retrieving weather data for trenton,nj
#
#
# Currently retrieving data for trenton,nj: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.258045
#
#
# export trenton,nj completed!
#
#
#
#
# Retrieving weather data for phoenix,az
#
#
# Currently retrieving data for phoenix,az: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.419811
#
#
# export phoenix,az completed!
#
#
#
#
# Retrieving weather data for pierre,sd
#
#
# Currently retrieving data for pierre,sd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.372731
#
#
# export pierre,sd completed!
#
#
#
#
# Retrieving weather data for pittsburgh,pa
#
#
# Currently retrieving data for pittsburgh,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.368445
#
#
# export pittsburgh,pa completed!
#
#
#
#
# Retrieving weather data for pocatello,id
#
#
# Currently retrieving data for pocatello,id: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.576380
#
#
# export pocatello,id completed!
#
#
#
#
# Retrieving weather data for ponce,puertorico
#
#
# Currently retrieving data for ponce,puertorico: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.628750
#
#
# export ponce,puertorico completed!
#
#
#
#
# Retrieving weather data for portland,me
#
#
# Currently retrieving data for portland,me: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.624391
#
#
# export portland,me completed!
#
#
#
#
# Retrieving weather data for portland,or
#
#
# Currently retrieving data for portland,or: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.396759
#
#
# export portland,or completed!
#
#
#
#
# Retrieving weather data for portsmouth,nh
#
#
# Currently retrieving data for portsmouth,nh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.412701
#
#
# export portsmouth,nh completed!
#
#
#
#
# Retrieving weather data for prescott,az
#
#
# Currently retrieving data for prescott,az: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.358284
#
#
# export prescott,az completed!
#
#
#
#
# Retrieving weather data for providence,ri
#
#
# Currently retrieving data for providence,ri: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.302213
#
#
# export providence,ri completed!
#
#
#
#
# Retrieving weather data for deadhorse,ak
#
#
# Currently retrieving data for deadhorse,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.359058
#
#
# export deadhorse,ak completed!
#
#
#
#
# Retrieving weather data for pueblo,co
#
#
# Currently retrieving data for pueblo,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.456405
#
#
# export pueblo,co completed!
#
#
#
#
# Retrieving weather data for quincy,il
#
#
# Currently retrieving data for quincy,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.713059
#
#
# export quincy,il completed!
#
#
#
#
# Retrieving weather data for rapidcity,sd
#
#
# Currently retrieving data for rapidcity,sd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.399179
#
#
# export rapidcity,sd completed!
#
#
#
#
# Retrieving weather data for redding,ca
#
#
# Currently retrieving data for redding,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.374801
#
#
# export redding,ca completed!
#
#
#
#
# Retrieving weather data for redmond,or
#
#
# Currently retrieving data for redmond,or: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.255017
#
#
# export redmond,or completed!
#
#
#
#
# Retrieving weather data for reno,nv
#
#
# Currently retrieving data for reno,nv: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.315406
#
#
# export reno,nv completed!
#
#
#
#
# Retrieving weather data for rhinelander,wi,
#
#
# Currently retrieving data for rhinelander,wi,: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.362538
#
#
# export rhinelander,wi, completed!
#
#
#
#
# Retrieving weather data for richmond,va
#
#
# Currently retrieving data for richmond,va: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.584851
#
#
# export richmond,va completed!
#
#
#
#
# Retrieving weather data for riverton,wy
#
#
# Currently retrieving data for riverton,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.576977
#
#
# export riverton,wy completed!
#
#
#
#
# Retrieving weather data for roanoke,va
#
#
# Currently retrieving data for roanoke,va: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.297158
#
#
# export roanoke,va completed!
#
#
#
#
# Retrieving weather data for rochester,mn
#
#
# Currently retrieving data for rochester,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.356890
#
#
# export rochester,mn completed!
#
#
#
#
# Retrieving weather data for rochester,ny
#
#
# Currently retrieving data for rochester,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.552790
#
#
# export rochester,ny completed!
#
#
#
#
# Retrieving weather data for rocksprings,wy
#
#
# Currently retrieving data for rocksprings,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.521625
#
#
# export rocksprings,wy completed!
#
#
#
#
# Retrieving weather data for roswell,nm
#
#
# Currently retrieving data for roswell,nm: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.569977
#
#
# export roswell,nm completed!
#
#
#
#
# Retrieving weather data for sacramento,ca
#
#
# Currently retrieving data for sacramento,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.382739
#
#
# export sacramento,ca completed!
#
#
#
#
# Retrieving weather data for saintcloud,mn
#
#
# Currently retrieving data for saintcloud,mn: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.573538
#
#
# export saintcloud,mn completed!
#
#
#
#
# Retrieving weather data for saintgeorge,ut
#
#
# Currently retrieving data for saintgeorge,ut: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.542504
#
#
# export saintgeorge,ut completed!
#
#
#
#
# Retrieving weather data for saintlouis,mo
#
#
# Currently retrieving data for saintlouis,mo: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.133087
#
#
# export saintlouis,mo completed!
#
#
#
#
# Retrieving weather data for salina,ks
#
#
# Currently retrieving data for salina,ks: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383855
#
#
# export salina,ks completed!
#
#
#
#
# Retrieving weather data for saltlakecity,ut
#
#
# Currently retrieving data for saltlakecity,ut: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.369854
#
#
# export saltlakecity,ut completed!
#
#
#
#
# Retrieving weather data for sanangelo,tx
#
#
# Currently retrieving data for sanangelo,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.407194
#
#
# export sanangelo,tx completed!
#
#
#
#
# Retrieving weather data for sanantonio,tx
#
#
# Currently retrieving data for sanantonio,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.409230
#
#
# export sanantonio,tx completed!
#
#
#
#
# Retrieving weather data for sandiego,ca
#
#
# Currently retrieving data for sandiego,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.231950
#
#
# export sandiego,ca completed!
#
#
#
#
# Retrieving weather data for sanfrancisco,ca
#
#
# Currently retrieving data for sanfrancisco,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.419719
#
#
# export sanfrancisco,ca completed!
#
#
#
#
# Retrieving weather data for sanjose,ca
#
#
# Currently retrieving data for sanjose,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.394218
#
#
# export sanjose,ca completed!
#
#
#
#
# Retrieving weather data for sanjuan,puertorico
#
#
# Currently retrieving data for sanjuan,puertorico: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.920251
#
#
# export sanjuan,puertorico completed!
#
#
#
#
# Retrieving weather data for sanluisobispo,ca
#
#
# Currently retrieving data for sanluisobispo,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.198367
#
#
# export sanluisobispo,ca completed!
#
#
#
#
# Retrieving weather data for santabarbara,ca
#
#
# Currently retrieving data for santabarbara,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.325256
#
#
# export santabarbara,ca completed!
#
#
#
#
# Retrieving weather data for santafe,nm
#
#
# Currently retrieving data for santafe,nm: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.456009
#
#
# export santafe,nm completed!
#
#
#
#
# Retrieving weather data for santamaria,ca
#
#
# Currently retrieving data for santamaria,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.606549
#
#
# export santamaria,ca completed!
#
#
#
#
# Retrieving weather data for santarosa,ca
#
#
# Currently retrieving data for santarosa,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380940
#
#
# export santarosa,ca completed!
#
#
#
#
# Retrieving weather data for sarasota,fl
#
#
# Currently retrieving data for sarasota,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.516078
#
#
# export sarasota,fl completed!
#
#
#
#
# Retrieving weather data for saultstemarie,mi,
#
#
# Currently retrieving data for saultstemarie,mi,: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.696089
#
#
# export saultstemarie,mi, completed!
#
#
#
#
# Retrieving weather data for savannah,ga
#
#
# Currently retrieving data for savannah,ga: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.538823
#
#
# export savannah,ga completed!
#
#
#
#
# Retrieving weather data for scottsbluff,ne
#
#
# Currently retrieving data for scottsbluff,ne: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.407648
#
#
# export scottsbluff,ne completed!
#
#
#
#
# Retrieving weather data for scranton,pa
#
#
# Currently retrieving data for scranton,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.402038
#
#
# export scranton,pa completed!
#
#
#
#
# Retrieving weather data for seattle,wa
#
#
# Currently retrieving data for seattle,wa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.352630
#
#
# export seattle,wa completed!
#
#
#
#
# Retrieving weather data for sheridan,wy
#
#
# Currently retrieving data for sheridan,wy: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.402120
#
#
# export sheridan,wy completed!
#
#
#
#
# Retrieving weather data for shreveport,la
#
#
# Currently retrieving data for shreveport,la: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.410533
#
#
# export shreveport,la completed!
#
#
#
#
# Retrieving weather data for siouxcity,ia
#
#
# Currently retrieving data for siouxcity,ia: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.470189
#
#
# export siouxcity,ia completed!
#
#
#
#
# Retrieving weather data for siouxfalls,sd
#
#
# Currently retrieving data for siouxfalls,sd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.540732
#
#
# export siouxfalls,sd completed!
#
#
#
#
# Retrieving weather data for sitka,ak
#
#
# Currently retrieving data for sitka,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.700609
#
#
# export sitka,ak completed!
#
#
#
#
# Retrieving weather data for southbend,in
#
#
# Currently retrieving data for southbend,in: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.528277
#
#
# export southbend,in completed!
#
#
#
#
# Retrieving weather data for spokane,wa
#
#
# Currently retrieving data for spokane,wa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.161196
#
#
# export spokane,wa completed!
#
#
#
#
# Retrieving weather data for springfield,il
#
#
# Currently retrieving data for springfield,il: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.534993
#
#
# export springfield,il completed!
#
#
#
#
# Retrieving weather data for springfield,mo
#
#
# Currently retrieving data for springfield,mo: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.388856
#
#
# export springfield,mo completed!
#
#
#
#
# Retrieving weather data for universitypark,pa
#
#
# Currently retrieving data for universitypark,pa: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.315711
#
#
# export universitypark,pa completed!
#
#
#
#
# Retrieving weather data for staunton,va
#
#
# Currently retrieving data for staunton,va: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.554257
#
#
# export staunton,va completed!
#
#
#
#
# Retrieving weather data for wausau,wi
#
#
# Currently retrieving data for wausau,wi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.266027
#
#
# export wausau,wi completed!
#
#
#
#
# Retrieving weather data for stockton,ca
#
#
# Currently retrieving data for stockton,ca: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.466624
#
#
# export stockton,ca completed!
#
#
#
#
# Retrieving weather data for syracuse,ny
#
#
# Currently retrieving data for syracuse,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383346
#
#
# export syracuse,ny completed!
#
#
#
#
# Retrieving weather data for tallahassee,fl
#
#
# Currently retrieving data for tallahassee,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.300415
#
#
# export tallahassee,fl completed!
#
#
#
#
# Retrieving weather data for tampa,fl
#
#
# Currently retrieving data for tampa,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.390712
#
#
# export tampa,fl completed!
#
#
#
#
# Retrieving weather data for texarkana,ar
#
#
# Currently retrieving data for texarkana,ar: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.516186
#
#
# export texarkana,ar completed!
#
#
#
#
# Retrieving weather data for toledo,oh
#
#
# Currently retrieving data for toledo,oh: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.551434
#
#
# export toledo,oh completed!
#
#
#
#
# Retrieving weather data for traversecity,mi
#
#
# Currently retrieving data for traversecity,mi: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.377579
#
#
# export traversecity,mi completed!
#
#
#
#
# Retrieving weather data for tucson,az
#
#
# Currently retrieving data for tucson,az: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.278205
#
#
# export tucson,az completed!
#
#
#
#
# Retrieving weather data for tulsa,ok
#
#
# Currently retrieving data for tulsa,ok: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.436766
#
#
# export tulsa,ok completed!
#
#
#
#
# Retrieving weather data for twinfalls,id
#
#
# Currently retrieving data for twinfalls,id: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.467973
#
#
# export twinfalls,id completed!
#
#
#
#
# Retrieving weather data for tyler,tx
#
#
# Currently retrieving data for tyler,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.441336
#
#
# export tyler,tx completed!
#
#
#
#
# Retrieving weather data for vail,co
#
#
# Currently retrieving data for vail,co: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.568123
#
#
# export vail,co completed!
#
#
#
#
# Retrieving weather data for valdosta,ga
#
#
# Currently retrieving data for valdosta,ga: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.435184
#
#
# export valdosta,ga completed!
#
#
#
#
# Retrieving weather data for vernal,ut
#
#
# Currently retrieving data for vernal,ut: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.414737
#
#
# export vernal,ut completed!
#
#
#
#
# Retrieving weather data for waco,tx
#
#
# Currently retrieving data for waco,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.316973
#
#
# export waco,tx completed!
#
#
#
#
# Retrieving weather data for washington,dc
#
#
# Currently retrieving data for washington,dc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.024776
#
#
# export washington,dc completed!
#
#
#
#
# Retrieving weather data for waterloo,ia
#
#
# Currently retrieving data for waterloo,ia: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.560470
#
#
# export waterloo,ia completed!
#
#
#
#
# Retrieving weather data for watertown,ny
#
#
# Currently retrieving data for watertown,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.536103
#
#
# export watertown,ny completed!
#
#
#
#
# Retrieving weather data for watertown,sd
#
#
# Currently retrieving data for watertown,sd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.573381
#
#
# export watertown,sd completed!
#
#
#
#
# Retrieving weather data for westpalmbeach,fl
#
#
# Currently retrieving data for westpalmbeach,fl: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.558811
#
#
# export westpalmbeach,fl completed!
#
#
#
#
# Retrieving weather data for westchestercounty,ny
#
#
# Currently retrieving data for westchestercounty,ny: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.482966
#
#
# export westchestercounty,ny completed!
#
#
#
#
# Retrieving weather data for wichitafalls,tx
#
#
# Currently retrieving data for wichitafalls,tx: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.561129
#
#
# export wichitafalls,tx completed!
#
#
#
#
# Retrieving weather data for wichita,ks
#
#
# Currently retrieving data for wichita,ks: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.598187
#
#
# export wichita,ks completed!
#
#
#
#
# Retrieving weather data for williston,nd
#
#
# Currently retrieving data for williston,nd: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.575766
#
#
# export williston,nd completed!
#
#
#
#
# Retrieving weather data for wilmington,nc
#
#
# Currently retrieving data for wilmington,nc: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.416806
#
#
# export wilmington,nc completed!
#
#
#
#
# Retrieving weather data for worcester,ma
#
#
# Currently retrieving data for worcester,ma: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.484840
#
#
# export worcester,ma completed!
#
#
#
#
# Retrieving weather data for wrangell,ak
#
#
# Currently retrieving data for wrangell,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.414586
#
#
# export wrangell,ak completed!
#
#
#
#
# Retrieving weather data for yakutat,ak
#
#
# Currently retrieving data for yakutat,ak: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.497787
#
#
# export yakutat,ak completed!
#
#
#
#
# Retrieving weather data for yuma,az
#
#
# Currently retrieving data for yuma,az: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.418738
#
#
# export yuma,az completed!

# %%
#Create variables to hold all csv files and CSVs
all_files = glob.glob(os.path.join("*.csv"))
all_df = []

# Loop through all files, create df's and add all dataframes to the dataframes list
for x in all_files:
    df = pd.read_csv(x, sep=',')
    df['file'] = x.split('/')[-1]
    all_df.append(df)

# %%
#Merge all dataframes
merged_2019_df = pd.concat(all_df, ignore_index=True, sort=True)
merged_2019_df
# Out:
#         DewPointC  FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  \
# 0               5          -1           1          -1            50
# 1               6           3           4           3            51
# 2               7           6           7           6            52
# 3               9          10          10          10            53
# 4               9          10          10          10            55
# ...           ...         ...         ...         ...           ...
# 236587          5          10          10          10            25
# 236588          5           9          10           9            26
# 236589          5           8          10           8            26
# 236590          5           8          10           8            26
# 236591          6           7          10           7            26
#
#         cloudcover            date_time                 file  humidity  \
# 0              100  2019-01-01 00:00:00         islip,ny.csv        91
# 1              100  2019-01-01 01:00:00         islip,ny.csv        93
# 2              100  2019-01-01 02:00:00         islip,ny.csv        94
# 3              100  2019-01-01 03:00:00         islip,ny.csv        96
# 4               98  2019-01-01 04:00:00         islip,ny.csv        96
# ...            ...                  ...                  ...       ...
# 236587          26  2019-01-31 19:00:00  jacksonville,fl.csv        65
# 236588          33  2019-01-31 20:00:00  jacksonville,fl.csv        67
# 236589          40  2019-01-31 21:00:00  jacksonville,fl.csv        69
# 236590          52  2019-01-31 22:00:00  jacksonville,fl.csv        69
# 236591          64  2019-01-31 23:00:00  jacksonville,fl.csv        70
#
#                location  ...  pressure  sunHour   sunrise    sunset tempC  \
# 0              islip,ny  ...      1009      6.9  08:17 AM  05:36 PM    -1
# 1              islip,ny  ...      1007      6.9  08:17 AM  05:36 PM     2
# 2              islip,ny  ...      1005      6.9  08:17 AM  05:36 PM     6
# 3              islip,ny  ...      1003      6.9  08:17 AM  05:36 PM     9
# 4              islip,ny  ...      1003      6.9  08:17 AM  05:36 PM     9
# ...                 ...  ...       ...      ...       ...       ...   ...
# 236587  jacksonville,fl  ...      1028     10.8  08:18 AM  07:02 PM     9
# 236588  jacksonville,fl  ...      1028     10.8  08:18 AM  07:02 PM     9
# 236589  jacksonville,fl  ...      1028     10.8  08:18 AM  07:02 PM     8
# 236590  jacksonville,fl  ...      1028     10.8  08:18 AM  07:02 PM     7
# 236591  jacksonville,fl  ...      1027     10.8  08:18 AM  07:02 PM     7
#
#         totalSnow_cm  uvIndex  visibility winddirDegree windspeedKmph
# 0                0.0        2           5           163            10
# 1                0.0        2           5           179            12
# 2                0.0        2           6           194            15
# 3                0.0        2           6           209            18
# 4                0.0        2           7           218            20
# ...              ...      ...         ...           ...           ...
# 236587           0.0        3          10            59            19
# 236588           0.0        3          10            61            19
# 236589           0.0        3          10            62            19
# 236590           0.0        3          10            63            18
# 236591           0.0        3          10            65            17
#
# [236592 rows x 26 columns]

# %%
weather_2019_df = pd.DataFrame(merged_2019_df, columns = ['location','date_time','precipMM','visibility','cloudcover','windspeedKmph','humidity',])
weather_2019_df
# Out:
#                location            date_time  precipMM  visibility  \
# 0              islip,ny  2019-01-01 00:00:00       8.5           5
# 1              islip,ny  2019-01-01 01:00:00       4.3           5
# 2              islip,ny  2019-01-01 02:00:00       4.3           6
# 3              islip,ny  2019-01-01 03:00:00       5.8           6
# 4              islip,ny  2019-01-01 04:00:00       2.9           7
# ...                 ...                  ...       ...         ...
# 236587  jacksonville,fl  2019-01-31 19:00:00       0.0          10
# 236588  jacksonville,fl  2019-01-31 20:00:00       0.0          10
# 236589  jacksonville,fl  2019-01-31 21:00:00       0.0          10
# 236590  jacksonville,fl  2019-01-31 22:00:00       0.0          10
# 236591  jacksonville,fl  2019-01-31 23:00:00       0.0          10
#
#         cloudcover  windspeedKmph  humidity
# 0              100             10        91
# 1              100             12        93
# 2              100             15        94
# 3              100             18        96
# 4               98             20        96
# ...            ...            ...       ...
# 236587          26             19        65
# 236588          33             19        67
# 236589          40             19        69
# 236590          52             18        69
# 236591          64             17        70
#
# [236592 rows x 7 columns]

# %%
#Export to CSV
weather_2019_df.to_csv("../../weather_data/weather_2019_df.csv", index=False)
