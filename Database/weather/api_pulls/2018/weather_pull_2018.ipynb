# %%
#Import requests library and API key
import requests
from config import weather_api_key

# Import Dependencies
import pandas as pd

# Import Historical API Package
from wwo_hist import retrieve_hist_data

# Import glob dependncies
import os, glob

# %%
# Import CSV
city_code_api_df = pd.read_csv('../../../Flight_data_files/post_hardcode_cities.csv',index_col='Unnamed: 0')
city_code_api_df
# Out:
#     Airport Code           City
# 0            ABR    aberdeen,sd
# 1            ABI     abilene,tx
# 2            ADK  adakisland,ak
# 3            CAK       akron,oh
# 4            ALB      albany,ny
# ..           ...            ...
# 317          ILM  wilmington,nc
# 318          ORH   worcester,ma
# 319          WRG    wrangell,ak
# 320          YAK     yakutat,ak
# 321          YUM        yuma,az
#
# [322 rows x 2 columns]

# %%
cities_unique = []
for city in city_code_api_df['City']:
    if city not in cities_unique:
        cities_unique.append(city)
print(cities_unique)
# Out:
# ['aberdeen,sd', 'abilene,tx', 'adakisland,ak', 'akron,oh', 'albany,ny', 'albuquerque,nm', 'alexandria,la', 'easton,pa', 'alpena,mi', 'amarillo,tx', 'anchorage,ak', 'appleton,wi', 'arcata,ca', 'asheville,nc', 'huntington,wv', 'aspen,co', 'atlanta,ga', 'augusta,ga', 'austin,tx', 'bakersfield,ca', 'baltimore,md', 'bangor,me', 'barrow,ak', 'batonrouge,la', 'saginaw,mi', 'beaumont,tx', 'belleville,il', 'bellingham,wa', 'bemidji,mn', 'bethel,ak', 'billings,mt', 'gulfport,ms', 'binghamton,ny', 'birmingham,al', 'bismarck,nd', 'bloomington,il', 'boise,id', 'boston,ma', 'bozeman,mt', 'brainerd,mn', 'bristol,tn', 'brownsville,tx', 'brunswick,ga', 'buffalo,ny', 'burbank,ca', 'burlington,vt', 'butte,mt', 'capegirardeau,mo', 'monterey,ca', 'casper,wy', 'cedarcity,ut', 'cedarrapids,ia', 'champaign,il', 'charleston,sc', 'charleston,wv', 'charlotte,nc', 'charlottesville,va', 'chattanooga,tn', 'cheyenne,wy', 'chicago,il', 'chisholm,mn', 'cincinnati,oh', 'clarksburg,wv', 'clearwater,fl', 'cleveland,oh', 'yellowstone,wy', 'collegestation,tx', 'coloradosprings,co', 'columbia,mo', 'columbia,sc', 'columbus,ga', 'columbus,ms', 'columbus,oh', 'cordova,ak', 'corpuschristi,tx', 'fortworth,tx', 'dayton,oh', 'daytonabeach,fl', 'denver,co', 'desmoines,ia', 'detroit,mi', "devil'slake,nd", 'dothan,al', 'dubuque,ia', 'duluth,mn', 'durango,co', 'durham,nc', 'eauclaire,wi', 'elpaso,tx', 'elko,nv', 'elmira,ny', 'erie,pa', 'escanaba,mi', 'eugene,or', 'evansville,in', 'fairbanks,ak', 'fargo,nd', 'fayetteville,ar', 'fayetteville,nc', 'flagstaff,az', 'flint,mi', 'fortlauderdale,fl', 'fortmyers,fl', 'fortsmith,ar', 'fortwaltonbeach,fl', 'fortwayne,in', 'fresno,ca', 'gainesville,fl', 'gardencity,ks', 'gillette,wy', 'longview,tx', 'grandforks,nd', 'grandisland,ne', 'grandjunction,co', 'grandrapids,mi', 'greatfalls,mt', 'greenbay,wi', 'greensboro,nc', 'greenville,sc', 'gunnison,co', 'hagerstown,md', 'hailey,id', 'hampton,va', 'hancock,mi', 'harlingen,tx', 'harrisburg,pa', 'hartford,ct', 'hayden,co', 'hays,ks', 'helena,mt', 'hilo,hi', 'hiltonhead,sc', 'honolulu,hi', 'houston,tx', 'huntsville,al', 'idahofalls,id', 'indianapolis,in', 'internationalfalls,mn', 'ironmountain,mi', 'islip,ny', 'ithaca,ny', 'jacksonhole,wy', 'jackson,ms', 'jacksonville,fl', 'jacksonville,nc', 'jamestown,nd', 'joplin,mo', 'juneau,ak', 'maui,hi', 'kalamazoo,mi', 'kansascity,mo', 'kauai,hi', 'kearney,ne', 'ketchikan,ak', 'keywest,fl', 'knoxville,tn', 'kodiak,ak', 'kona,hi', 'kotzebue,ak', 'lacrosse,wi', 'lafayette,la', 'lakecharles,la', 'lansing,mi', 'laramie,wy', 'laredo,tx', 'lasvegas,nv', 'latrobe,pa', 'laurel,ms', 'lawton,ok', 'lewisburg,wv', 'lewiston,id', 'lexington,ky', 'liberal,ks', 'lincoln,ne', 'littlerock,ar', 'longbeach,ca', 'losangeles,ca', 'louisville,ky', 'lubbock,tx', 'madison,wi', 'manchester,nh', 'manhattan,ks', 'marquette,mi', 'mcallen,tx', 'medford,or', 'melbourne,fl', 'memphis,tn', 'meridian,ms', 'miami,fl', 'odessa,tx', 'milwaukee,wi', 'minneapolis,mn', 'minot,nd', 'missoula,mt', 'moab,ut', 'mobile,al', 'moline,il', 'monroe,la', 'montgomery,al', 'montrose,co', 'muskegon,mi', 'myrtlebeach,sc', 'nashville,tn', 'newhaven,ct', 'neworleans,la', 'newyork,ny', 'newark,nj', 'newburgh,ny', 'nome,ak', 'norfolk,va', 'northbend,or', 'northplatte,ne', 'oakland,ca', 'ogdensburg,ny', 'oklahomacity,ok', 'omaha,ne', 'ontario,ca', 'orangecounty,ca', 'orlando,fl', 'owensboro,ky', 'paducah,ky', 'palmsprings,ca', 'pasco,wa', 'pellston,mi', 'pensacola,fl', 'peoria,il', 'petersburg,ak', 'philadelphia,pa', 'trenton,nj', 'phoenix,az', 'pierre,sd', 'pittsburgh,pa', 'pocatello,id', 'ponce,puertorico', 'portland,me', 'portland,or', 'portsmouth,nh', 'prescott,az', 'providence,ri', 'deadhorse,ak', 'pueblo,co', 'quincy,il', 'rapidcity,sd', 'redding,ca', 'redmond,or', 'reno,nv', 'rhinelander,wi,', 'richmond,va', 'riverton,wy', 'roanoke,va', 'rochester,mn', 'rochester,ny', 'rocksprings,wy', 'roswell,nm', 'sacramento,ca', 'saintcloud,mn', 'saintgeorge,ut', 'saintlouis,mo', 'salina,ks', 'saltlakecity,ut', 'sana ...

# %%
start_date = '01-JAN-2018'
end_date = '31-JAN-2018'
location_list = cities_unique
frequency = 1

# %%
hist_weather_data_2018 = retrieve_hist_data(weather_api_key,
                                   location_list,
                                   start_date,
                                   end_date,
                                   frequency,
                                   location_label = False,
                                   export_csv = True,
                                   store_df = True)
# Out:
# Retrieving weather data for aberdeen,sd
#
#
# Currently retrieving data for aberdeen,sd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.676943
#
#
# export aberdeen,sd completed!
#
#
#
#
# Retrieving weather data for abilene,tx
#
#
# Currently retrieving data for abilene,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.448991
#
#
# export abilene,tx completed!
#
#
#
#
# Retrieving weather data for adakisland,ak
#
#
# Currently retrieving data for adakisland,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.808611
#
#
# export adakisland,ak completed!
#
#
#
#
# Retrieving weather data for akron,oh
#
#
# Currently retrieving data for akron,oh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.904005
#
#
# export akron,oh completed!
#
#
#
#
# Retrieving weather data for albany,ny
#
#
# Currently retrieving data for albany,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.485036
#
#
# export albany,ny completed!
#
#
#
#
# Retrieving weather data for albuquerque,nm
#
#
# Currently retrieving data for albuquerque,nm: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.212373
#
#
# export albuquerque,nm completed!
#
#
#
#
# Retrieving weather data for alexandria,la
#
#
# Currently retrieving data for alexandria,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.572977
#
#
# export alexandria,la completed!
#
#
#
#
# Retrieving weather data for easton,pa
#
#
# Currently retrieving data for easton,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.585608
#
#
# export easton,pa completed!
#
#
#
#
# Retrieving weather data for alpena,mi
#
#
# Currently retrieving data for alpena,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.101751
#
#
# export alpena,mi completed!
#
#
#
#
# Retrieving weather data for amarillo,tx
#
#
# Currently retrieving data for amarillo,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.617712
#
#
# export amarillo,tx completed!
#
#
#
#
# Retrieving weather data for anchorage,ak
#
#
# Currently retrieving data for anchorage,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.952145
#
#
# export anchorage,ak completed!
#
#
#
#
# Retrieving weather data for appleton,wi
#
#
# Currently retrieving data for appleton,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.435159
#
#
# export appleton,wi completed!
#
#
#
#
# Retrieving weather data for arcata,ca
#
#
# Currently retrieving data for arcata,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.464666
#
#
# export arcata,ca completed!
#
#
#
#
# Retrieving weather data for asheville,nc
#
#
# Currently retrieving data for asheville,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.396281
#
#
# export asheville,nc completed!
#
#
#
#
# Retrieving weather data for huntington,wv
#
#
# Currently retrieving data for huntington,wv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.307889
#
#
# export huntington,wv completed!
#
#
#
#
# Retrieving weather data for aspen,co
#
#
# Currently retrieving data for aspen,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.309051
#
#
# export aspen,co completed!
#
#
#
#
# Retrieving weather data for atlanta,ga
#
#
# Currently retrieving data for atlanta,ga: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.184250
#
#
# export atlanta,ga completed!
#
#
#
#
# Retrieving weather data for augusta,ga
#
#
# Currently retrieving data for augusta,ga: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.527420
#
#
# export augusta,ga completed!
#
#
#
#
# Retrieving weather data for austin,tx
#
#
# Currently retrieving data for austin,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.082441
#
#
# export austin,tx completed!
#
#
#
#
# Retrieving weather data for bakersfield,ca
#
#
# Currently retrieving data for bakersfield,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.594071
#
#
# export bakersfield,ca completed!
#
#
#
#
# Retrieving weather data for baltimore,md
#
#
# Currently retrieving data for baltimore,md: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.215900
#
#
# export baltimore,md completed!
#
#
#
#
# Retrieving weather data for bangor,me
#
#
# Currently retrieving data for bangor,me: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.097786
#
#
# export bangor,me completed!
#
#
#
#
# Retrieving weather data for barrow,ak
#
#
# Currently retrieving data for barrow,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.032054
#
#
# export barrow,ak completed!
#
#
#
#
# Retrieving weather data for batonrouge,la
#
#
# Currently retrieving data for batonrouge,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.457018
#
#
# export batonrouge,la completed!
#
#
#
#
# Retrieving weather data for saginaw,mi
#
#
# Currently retrieving data for saginaw,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.487149
#
#
# export saginaw,mi completed!
#
#
#
#
# Retrieving weather data for beaumont,tx
#
#
# Currently retrieving data for beaumont,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.873265
#
#
# export beaumont,tx completed!
#
#
#
#
# Retrieving weather data for belleville,il
#
#
# Currently retrieving data for belleville,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.355391
#
#
# export belleville,il completed!
#
#
#
#
# Retrieving weather data for bellingham,wa
#
#
# Currently retrieving data for bellingham,wa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.462823
#
#
# export bellingham,wa completed!
#
#
#
#
# Retrieving weather data for bemidji,mn
#
#
# Currently retrieving data for bemidji,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.879271
#
#
# export bemidji,mn completed!
#
#
#
#
# Retrieving weather data for bethel,ak
#
#
# Currently retrieving data for bethel,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.861773
#
#
# export bethel,ak completed!
#
#
#
#
# Retrieving weather data for billings,mt
#
#
# Currently retrieving data for billings,mt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.815456
#
#
# export billings,mt completed!
#
#
#
#
# Retrieving weather data for gulfport,ms
#
#
# Currently retrieving data for gulfport,ms: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.438892
#
#
# export gulfport,ms completed!
#
#
#
#
# Retrieving weather data for binghamton,ny
#
#
# Currently retrieving data for binghamton,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.774022
#
#
# export binghamton,ny completed!
#
#
#
#
# Retrieving weather data for birmingham,al
#
#
# Currently retrieving data for birmingham,al: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.288508
#
#
# export birmingham,al completed!
#
#
#
#
# Retrieving weather data for bismarck,nd
#
#
# Currently retrieving data for bismarck,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.339862
#
#
# export bismarck,nd completed!
#
#
#
#
# Retrieving weather data for bloomington,il
#
#
# Currently retrieving data for bloomington,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.551313
#
#
# export bloomington,il completed!
#
#
#
#
# Retrieving weather data for boise,id
#
#
# Currently retrieving data for boise,id: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.666283
#
#
# export boise,id completed!
#
#
#
#
# Retrieving weather data for boston,ma
#
#
# Currently retrieving data for boston,ma: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.481241
#
#
# export boston,ma completed!
#
#
#
#
# Retrieving weather data for bozeman,mt
#
#
# Currently retrieving data for bozeman,mt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.353702
#
#
# export bozeman,mt completed!
#
#
#
#
# Retrieving weather data for brainerd,mn
#
#
# Currently retrieving data for brainerd,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.405697
#
#
# export brainerd,mn completed!
#
#
#
#
# Retrieving weather data for bristol,tn
#
#
# Currently retrieving data for bristol,tn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.275502
#
#
# export bristol,tn completed!
#
#
#
#
# Retrieving weather data for brownsville,tx
#
#
# Currently retrieving data for brownsville,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.453092
#
#
# export brownsville,tx completed!
#
#
#
#
# Retrieving weather data for brunswick,ga
#
#
# Currently retrieving data for brunswick,ga: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.278673
#
#
# export brunswick,ga completed!
#
#
#
#
# Retrieving weather data for buffalo,ny
#
#
# Currently retrieving data for buffalo,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.778320
#
#
# export buffalo,ny completed!
#
#
#
#
# Retrieving weather data for burbank,ca
#
#
# Currently retrieving data for burbank,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.533819
#
#
# export burbank,ca completed!
#
#
#
#
# Retrieving weather data for burlington,vt
#
#
# Currently retrieving data for burlington,vt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.419258
#
#
# export burlington,vt completed!
#
#
#
#
# Retrieving weather data for butte,mt
#
#
# Currently retrieving data for butte,mt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.483609
#
#
# export butte,mt completed!
#
#
#
#
# Retrieving weather data for capegirardeau,mo
#
#
# Currently retrieving data for capegirardeau,mo: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.568247
#
#
# export capegirardeau,mo completed!
#
#
#
#
# Retrieving weather data for monterey,ca
#
#
# Currently retrieving data for monterey,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.991682
#
#
# export monterey,ca completed!
#
#
#
#
# Retrieving weather data for casper,wy
#
#
# Currently retrieving data for casper,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.352095
#
#
# export casper,wy completed!
#
#
#
#
# Retrieving weather data for cedarcity,ut
#
#
# Currently retrieving data for cedarcity,ut: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.466929
#
#
# export cedarcity,ut completed!
#
#
#
#
# Retrieving weather data for cedarrapids,ia
#
#
# Currently retrieving data for cedarrapids,ia: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.194040
#
#
# export cedarrapids,ia completed!
#
#
#
#
# Retrieving weather data for champaign,il
#
#
# Currently retrieving data for champaign,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.490963
#
#
# export champaign,il completed!
#
#
#
#
# Retrieving weather data for charleston,sc
#
#
# Currently retrieving data for charleston,sc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.424530
#
#
# export charleston,sc completed!
#
#
#
#
# Retrieving weather data for charleston,wv
#
#
# Currently retrieving data for charleston,wv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.993737
#
#
# export charleston,wv completed!
#
#
#
#
# Retrieving weather data for charlotte,nc
#
#
# Currently retrieving data for charlotte,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.419053
#
#
# export charlotte,nc completed!
#
#
#
#
# Retrieving weather data for charlottesville,va
#
#
# Currently retrieving data for charlottesville,va: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.376193
#
#
# export charlottesville,va completed!
#
#
#
#
# Retrieving weather data for chattanooga,tn
#
#
# Currently retrieving data for chattanooga,tn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.402734
#
#
# export chattanooga,tn completed!
#
#
#
#
# Retrieving weather data for cheyenne,wy
#
#
# Currently retrieving data for cheyenne,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.426359
#
#
# export cheyenne,wy completed!
#
#
#
#
# Retrieving weather data for chicago,il
#
#
# Currently retrieving data for chicago,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.015990
#
#
# export chicago,il completed!
#
#
#
#
# Retrieving weather data for chisholm,mn
#
#
# Currently retrieving data for chisholm,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.424237
#
#
# export chisholm,mn completed!
#
#
#
#
# Retrieving weather data for cincinnati,oh
#
#
# Currently retrieving data for cincinnati,oh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.219064
#
#
# export cincinnati,oh completed!
#
#
#
#
# Retrieving weather data for clarksburg,wv
#
#
# Currently retrieving data for clarksburg,wv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.323619
#
#
# export clarksburg,wv completed!
#
#
#
#
# Retrieving weather data for clearwater,fl
#
#
# Currently retrieving data for clearwater,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.406782
#
#
# export clearwater,fl completed!
#
#
#
#
# Retrieving weather data for cleveland,oh
#
#
# Currently retrieving data for cleveland,oh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.421921
#
#
# export cleveland,oh completed!
#
#
#
#
# Retrieving weather data for yellowstone,wy
#
#
# Currently retrieving data for yellowstone,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.242330
#
#
# export yellowstone,wy completed!
#
#
#
#
# Retrieving weather data for collegestation,tx
#
#
# Currently retrieving data for collegestation,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.617164
#
#
# export collegestation,tx completed!
#
#
#
#
# Retrieving weather data for coloradosprings,co
#
#
# Currently retrieving data for coloradosprings,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.073492
#
#
# export coloradosprings,co completed!
#
#
#
#
# Retrieving weather data for columbia,mo
#
#
# Currently retrieving data for columbia,mo: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.444723
#
#
# export columbia,mo completed!
#
#
#
#
# Retrieving weather data for columbia,sc
#
#
# Currently retrieving data for columbia,sc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.256596
#
#
# export columbia,sc completed!
#
#
#
#
# Retrieving weather data for columbus,ga
#
#
# Currently retrieving data for columbus,ga: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.287757
#
#
# export columbus,ga completed!
#
#
#
#
# Retrieving weather data for columbus,ms
#
#
# Currently retrieving data for columbus,ms: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.461723
#
#
# export columbus,ms completed!
#
#
#
#
# Retrieving weather data for columbus,oh
#
#
# Currently retrieving data for columbus,oh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.392164
#
#
# export columbus,oh completed!
#
#
#
#
# Retrieving weather data for cordova,ak
#
#
# Currently retrieving data for cordova,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.460257
#
#
# export cordova,ak completed!
#
#
#
#
# Retrieving weather data for corpuschristi,tx
#
#
# Currently retrieving data for corpuschristi,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.228447
#
#
# export corpuschristi,tx completed!
#
#
#
#
# Retrieving weather data for fortworth,tx
#
#
# Currently retrieving data for fortworth,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.575406
#
#
# export fortworth,tx completed!
#
#
#
#
# Retrieving weather data for dayton,oh
#
#
# Currently retrieving data for dayton,oh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.420672
#
#
# export dayton,oh completed!
#
#
#
#
# Retrieving weather data for daytonabeach,fl
#
#
# Currently retrieving data for daytonabeach,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.370083
#
#
# export daytonabeach,fl completed!
#
#
#
#
# Retrieving weather data for denver,co
#
#
# Currently retrieving data for denver,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.185152
#
#
# export denver,co completed!
#
#
#
#
# Retrieving weather data for desmoines,ia
#
#
# Currently retrieving data for desmoines,ia: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.318314
#
#
# export desmoines,ia completed!
#
#
#
#
# Retrieving weather data for detroit,mi
#
#
# Currently retrieving data for detroit,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.368549
#
#
# export detroit,mi completed!
#
#
#
#
# Retrieving weather data for devil'slake,nd
#
#
# Currently retrieving data for devil'slake,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.266424
#
#
# export devil'slake,nd completed!
#
#
#
#
# Retrieving weather data for dothan,al
#
#
# Currently retrieving data for dothan,al: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.609416
#
#
# export dothan,al completed!
#
#
#
#
# Retrieving weather data for dubuque,ia
#
#
# Currently retrieving data for dubuque,ia: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.267572
#
#
# export dubuque,ia completed!
#
#
#
#
# Retrieving weather data for duluth,mn
#
#
# Currently retrieving data for duluth,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.474777
#
#
# export duluth,mn completed!
#
#
#
#
# Retrieving weather data for durango,co
#
#
# Currently retrieving data for durango,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.397924
#
#
# export durango,co completed!
#
#
#
#
# Retrieving weather data for durham,nc
#
#
# Currently retrieving data for durham,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.321882
#
#
# export durham,nc completed!
#
#
#
#
# Retrieving weather data for eauclaire,wi
#
#
# Currently retrieving data for eauclaire,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.455811
#
#
# export eauclaire,wi completed!
#
#
#
#
# Retrieving weather data for elpaso,tx
#
#
# Currently retrieving data for elpaso,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.319893
#
#
# export elpaso,tx completed!
#
#
#
#
# Retrieving weather data for elko,nv
#
#
# Currently retrieving data for elko,nv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.394906
#
#
# export elko,nv completed!
#
#
#
#
# Retrieving weather data for elmira,ny
#
#
# Currently retrieving data for elmira,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.419192
#
#
# export elmira,ny completed!
#
#
#
#
# Retrieving weather data for erie,pa
#
#
# Currently retrieving data for erie,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.363802
#
#
# export erie,pa completed!
#
#
#
#
# Retrieving weather data for escanaba,mi
#
#
# Currently retrieving data for escanaba,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.476065
#
#
# export escanaba,mi completed!
#
#
#
#
# Retrieving weather data for eugene,or
#
#
# Currently retrieving data for eugene,or: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380002
#
#
# export eugene,or completed!
#
#
#
#
# Retrieving weather data for evansville,in
#
#
# Currently retrieving data for evansville,in: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.581687
#
#
# export evansville,in completed!
#
#
#
#
# Retrieving weather data for fairbanks,ak
#
#
# Currently retrieving data for fairbanks,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.436493
#
#
# export fairbanks,ak completed!
#
#
#
#
# Retrieving weather data for fargo,nd
#
#
# Currently retrieving data for fargo,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.437711
#
#
# export fargo,nd completed!
#
#
#
#
# Retrieving weather data for fayetteville,ar
#
#
# Currently retrieving data for fayetteville,ar: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.415198
#
#
# export fayetteville,ar completed!
#
#
#
#
# Retrieving weather data for fayetteville,nc
#
#
# Currently retrieving data for fayetteville,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.833284
#
#
# export fayetteville,nc completed!
#
#
#
#
# Retrieving weather data for flagstaff,az
#
#
# Currently retrieving data for flagstaff,az: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.490047
#
#
# export flagstaff,az completed!
#
#
#
#
# Retrieving weather data for flint,mi
#
#
# Currently retrieving data for flint,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.421055
#
#
# export flint,mi completed!
#
#
#
#
# Retrieving weather data for fortlauderdale,fl
#
#
# Currently retrieving data for fortlauderdale,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.395021
#
#
# export fortlauderdale,fl completed!
#
#
#
#
# Retrieving weather data for fortmyers,fl
#
#
# Currently retrieving data for fortmyers,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.283677
#
#
# export fortmyers,fl completed!
#
#
#
#
# Retrieving weather data for fortsmith,ar
#
#
# Currently retrieving data for fortsmith,ar: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.389464
#
#
# export fortsmith,ar completed!
#
#
#
#
# Retrieving weather data for fortwaltonbeach,fl
#
#
# Currently retrieving data for fortwaltonbeach,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.178701
#
#
# export fortwaltonbeach,fl completed!
#
#
#
#
# Retrieving weather data for fortwayne,in
#
#
# Currently retrieving data for fortwayne,in: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.383735
#
#
# export fortwayne,in completed!
#
#
#
#
# Retrieving weather data for fresno,ca
#
#
# Currently retrieving data for fresno,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.503910
#
#
# export fresno,ca completed!
#
#
#
#
# Retrieving weather data for gainesville,fl
#
#
# Currently retrieving data for gainesville,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.266737
#
#
# export gainesville,fl completed!
#
#
#
#
# Retrieving weather data for gardencity,ks
#
#
# Currently retrieving data for gardencity,ks: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.384944
#
#
# export gardencity,ks completed!
#
#
#
#
# Retrieving weather data for gillette,wy
#
#
# Currently retrieving data for gillette,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.431358
#
#
# export gillette,wy completed!
#
#
#
#
# Retrieving weather data for longview,tx
#
#
# Currently retrieving data for longview,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.318993
#
#
# export longview,tx completed!
#
#
#
#
# Retrieving weather data for grandforks,nd
#
#
# Currently retrieving data for grandforks,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.288886
#
#
# export grandforks,nd completed!
#
#
#
#
# Retrieving weather data for grandisland,ne
#
#
# Currently retrieving data for grandisland,ne: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.520511
#
#
# export grandisland,ne completed!
#
#
#
#
# Retrieving weather data for grandjunction,co
#
#
# Currently retrieving data for grandjunction,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.202752
#
#
# export grandjunction,co completed!
#
#
#
#
# Retrieving weather data for grandrapids,mi
#
#
# Currently retrieving data for grandrapids,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.995473
#
#
# export grandrapids,mi completed!
#
#
#
#
# Retrieving weather data for greatfalls,mt
#
#
# Currently retrieving data for greatfalls,mt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.516776
#
#
# export greatfalls,mt completed!
#
#
#
#
# Retrieving weather data for greenbay,wi
#
#
# Currently retrieving data for greenbay,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.320523
#
#
# export greenbay,wi completed!
#
#
#
#
# Retrieving weather data for greensboro,nc
#
#
# Currently retrieving data for greensboro,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.280943
#
#
# export greensboro,nc completed!
#
#
#
#
# Retrieving weather data for greenville,sc
#
#
# Currently retrieving data for greenville,sc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.373636
#
#
# export greenville,sc completed!
#
#
#
#
# Retrieving weather data for gunnison,co
#
#
# Currently retrieving data for gunnison,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.418739
#
#
# export gunnison,co completed!
#
#
#
#
# Retrieving weather data for hagerstown,md
#
#
# Currently retrieving data for hagerstown,md: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.452396
#
#
# export hagerstown,md completed!
#
#
#
#
# Retrieving weather data for hailey,id
#
#
# Currently retrieving data for hailey,id: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.431178
#
#
# export hailey,id completed!
#
#
#
#
# Retrieving weather data for hampton,va
#
#
# Currently retrieving data for hampton,va: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.362202
#
#
# export hampton,va completed!
#
#
#
#
# Retrieving weather data for hancock,mi
#
#
# Currently retrieving data for hancock,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.303908
#
#
# export hancock,mi completed!
#
#
#
#
# Retrieving weather data for harlingen,tx
#
#
# Currently retrieving data for harlingen,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.099128
#
#
# export harlingen,tx completed!
#
#
#
#
# Retrieving weather data for harrisburg,pa
#
#
# Currently retrieving data for harrisburg,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.373934
#
#
# export harrisburg,pa completed!
#
#
#
#
# Retrieving weather data for hartford,ct
#
#
# Currently retrieving data for hartford,ct: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.401221
#
#
# export hartford,ct completed!
#
#
#
#
# Retrieving weather data for hayden,co
#
#
# Currently retrieving data for hayden,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.278828
#
#
# export hayden,co completed!
#
#
#
#
# Retrieving weather data for hays,ks
#
#
# Currently retrieving data for hays,ks: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.418262
#
#
# export hays,ks completed!
#
#
#
#
# Retrieving weather data for helena,mt
#
#
# Currently retrieving data for helena,mt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.393857
#
#
# export helena,mt completed!
#
#
#
#
# Retrieving weather data for hilo,hi
#
#
# Currently retrieving data for hilo,hi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.478144
#
#
# export hilo,hi completed!
#
#
#
#
# Retrieving weather data for hiltonhead,sc
#
#
# Currently retrieving data for hiltonhead,sc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.864064
#
#
# export hiltonhead,sc completed!
#
#
#
#
# Retrieving weather data for honolulu,hi
#
#
# Currently retrieving data for honolulu,hi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.699120
#
#
# export honolulu,hi completed!
#
#
#
#
# Retrieving weather data for houston,tx
#
#
# Currently retrieving data for houston,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.323172
#
#
# export houston,tx completed!
#
#
#
#
# Retrieving weather data for huntsville,al
#
#
# Currently retrieving data for huntsville,al: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.385669
#
#
# export huntsville,al completed!
#
#
#
#
# Retrieving weather data for idahofalls,id
#
#
# Currently retrieving data for idahofalls,id: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.327259
#
#
# export idahofalls,id completed!
#
#
#
#
# Retrieving weather data for indianapolis,in
#
#
# Currently retrieving data for indianapolis,in: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.593286
#
#
# export indianapolis,in completed!
#
#
#
#
# Retrieving weather data for internationalfalls,mn
#
#
# Currently retrieving data for internationalfalls,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.375955
#
#
# export internationalfalls,mn completed!
#
#
#
#
# Retrieving weather data for ironmountain,mi
#
#
# Currently retrieving data for ironmountain,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.538146
#
#
# export ironmountain,mi completed!
#
#
#
#
# Retrieving weather data for islip,ny
#
#
# Currently retrieving data for islip,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.540874
#
#
# export islip,ny completed!
#
#
#
#
# Retrieving weather data for ithaca,ny
#
#
# Currently retrieving data for ithaca,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.514383
#
#
# export ithaca,ny completed!
#
#
#
#
# Retrieving weather data for jacksonhole,wy
#
#
# Currently retrieving data for jacksonhole,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.409719
#
#
# export jacksonhole,wy completed!
#
#
#
#
# Retrieving weather data for jackson,ms
#
#
# Currently retrieving data for jackson,ms: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.307406
#
#
# export jackson,ms completed!
#
#
#
#
# Retrieving weather data for jacksonville,fl
#
#
# Currently retrieving data for jacksonville,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.411199
#
#
# export jacksonville,fl completed!
#
#
#
#
# Retrieving weather data for jacksonville,nc
#
#
# Currently retrieving data for jacksonville,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.539513
#
#
# export jacksonville,nc completed!
#
#
#
#
# Retrieving weather data for jamestown,nd
#
#
# Currently retrieving data for jamestown,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.450326
#
#
# export jamestown,nd completed!
#
#
#
#
# Retrieving weather data for joplin,mo
#
#
# Currently retrieving data for joplin,mo: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.327821
#
#
# export joplin,mo completed!
#
#
#
#
# Retrieving weather data for juneau,ak
#
#
# Currently retrieving data for juneau,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.562829
#
#
# export juneau,ak completed!
#
#
#
#
# Retrieving weather data for maui,hi
#
#
# Currently retrieving data for maui,hi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.718645
#
#
# export maui,hi completed!
#
#
#
#
# Retrieving weather data for kalamazoo,mi
#
#
# Currently retrieving data for kalamazoo,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.479164
#
#
# export kalamazoo,mi completed!
#
#
#
#
# Retrieving weather data for kansascity,mo
#
#
# Currently retrieving data for kansascity,mo: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.225043
#
#
# export kansascity,mo completed!
#
#
#
#
# Retrieving weather data for kauai,hi
#
#
# Currently retrieving data for kauai,hi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.659634
#
#
# export kauai,hi completed!
#
#
#
#
# Retrieving weather data for kearney,ne
#
#
# Currently retrieving data for kearney,ne: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.311697
#
#
# export kearney,ne completed!
#
#
#
#
# Retrieving weather data for ketchikan,ak
#
#
# Currently retrieving data for ketchikan,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.807504
#
#
# export ketchikan,ak completed!
#
#
#
#
# Retrieving weather data for keywest,fl
#
#
# Currently retrieving data for keywest,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.632802
#
#
# export keywest,fl completed!
#
#
#
#
# Retrieving weather data for knoxville,tn
#
#
# Currently retrieving data for knoxville,tn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.327275
#
#
# export knoxville,tn completed!
#
#
#
#
# Retrieving weather data for kodiak,ak
#
#
# Currently retrieving data for kodiak,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.325145
#
#
# export kodiak,ak completed!
#
#
#
#
# Retrieving weather data for kona,hi
#
#
# Currently retrieving data for kona,hi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.512148
#
#
# export kona,hi completed!
#
#
#
#
# Retrieving weather data for kotzebue,ak
#
#
# Currently retrieving data for kotzebue,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.372954
#
#
# export kotzebue,ak completed!
#
#
#
#
# Retrieving weather data for lacrosse,wi
#
#
# Currently retrieving data for lacrosse,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.374355
#
#
# export lacrosse,wi completed!
#
#
#
#
# Retrieving weather data for lafayette,la
#
#
# Currently retrieving data for lafayette,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.391224
#
#
# export lafayette,la completed!
#
#
#
#
# Retrieving weather data for lakecharles,la
#
#
# Currently retrieving data for lakecharles,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.298745
#
#
# export lakecharles,la completed!
#
#
#
#
# Retrieving weather data for lansing,mi
#
#
# Currently retrieving data for lansing,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.699234
#
#
# export lansing,mi completed!
#
#
#
#
# Retrieving weather data for laramie,wy
#
#
# Currently retrieving data for laramie,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.318493
#
#
# export laramie,wy completed!
#
#
#
#
# Retrieving weather data for laredo,tx
#
#
# Currently retrieving data for laredo,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.386671
#
#
# export laredo,tx completed!
#
#
#
#
# Retrieving weather data for lasvegas,nv
#
#
# Currently retrieving data for lasvegas,nv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.354432
#
#
# export lasvegas,nv completed!
#
#
#
#
# Retrieving weather data for latrobe,pa
#
#
# Currently retrieving data for latrobe,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.341972
#
#
# export latrobe,pa completed!
#
#
#
#
# Retrieving weather data for laurel,ms
#
#
# Currently retrieving data for laurel,ms: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.446126
#
#
# export laurel,ms completed!
#
#
#
#
# Retrieving weather data for lawton,ok
#
#
# Currently retrieving data for lawton,ok: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.364947
#
#
# export lawton,ok completed!
#
#
#
#
# Retrieving weather data for lewisburg,wv
#
#
# Currently retrieving data for lewisburg,wv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.978013
#
#
# export lewisburg,wv completed!
#
#
#
#
# Retrieving weather data for lewiston,id
#
#
# Currently retrieving data for lewiston,id: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.623481
#
#
# export lewiston,id completed!
#
#
#
#
# Retrieving weather data for lexington,ky
#
#
# Currently retrieving data for lexington,ky: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.393262
#
#
# export lexington,ky completed!
#
#
#
#
# Retrieving weather data for liberal,ks
#
#
# Currently retrieving data for liberal,ks: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.347554
#
#
# export liberal,ks completed!
#
#
#
#
# Retrieving weather data for lincoln,ne
#
#
# Currently retrieving data for lincoln,ne: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.351805
#
#
# export lincoln,ne completed!
#
#
#
#
# Retrieving weather data for littlerock,ar
#
#
# Currently retrieving data for littlerock,ar: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.420814
#
#
# export littlerock,ar completed!
#
#
#
#
# Retrieving weather data for longbeach,ca
#
#
# Currently retrieving data for longbeach,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.377655
#
#
# export longbeach,ca completed!
#
#
#
#
# Retrieving weather data for losangeles,ca
#
#
# Currently retrieving data for losangeles,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.346146
#
#
# export losangeles,ca completed!
#
#
#
#
# Retrieving weather data for louisville,ky
#
#
# Currently retrieving data for louisville,ky: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.346699
#
#
# export louisville,ky completed!
#
#
#
#
# Retrieving weather data for lubbock,tx
#
#
# Currently retrieving data for lubbock,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.127790
#
#
# export lubbock,tx completed!
#
#
#
#
# Retrieving weather data for madison,wi
#
#
# Currently retrieving data for madison,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.362886
#
#
# export madison,wi completed!
#
#
#
#
# Retrieving weather data for manchester,nh
#
#
# Currently retrieving data for manchester,nh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.369648
#
#
# export manchester,nh completed!
#
#
#
#
# Retrieving weather data for manhattan,ks
#
#
# Currently retrieving data for manhattan,ks: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.292964
#
#
# export manhattan,ks completed!
#
#
#
#
# Retrieving weather data for marquette,mi
#
#
# Currently retrieving data for marquette,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.341169
#
#
# export marquette,mi completed!
#
#
#
#
# Retrieving weather data for mcallen,tx
#
#
# Currently retrieving data for mcallen,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.555865
#
#
# export mcallen,tx completed!
#
#
#
#
# Retrieving weather data for medford,or
#
#
# Currently retrieving data for medford,or: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.371670
#
#
# export medford,or completed!
#
#
#
#
# Retrieving weather data for melbourne,fl
#
#
# Currently retrieving data for melbourne,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.554836
#
#
# export melbourne,fl completed!
#
#
#
#
# Retrieving weather data for memphis,tn
#
#
# Currently retrieving data for memphis,tn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.171111
#
#
# export memphis,tn completed!
#
#
#
#
# Retrieving weather data for meridian,ms
#
#
# Currently retrieving data for meridian,ms: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.293845
#
#
# export meridian,ms completed!
#
#
#
#
# Retrieving weather data for miami,fl
#
#
# Currently retrieving data for miami,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.326567
#
#
# export miami,fl completed!
#
#
#
#
# Retrieving weather data for odessa,tx
#
#
# Currently retrieving data for odessa,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.422998
#
#
# export odessa,tx completed!
#
#
#
#
# Retrieving weather data for milwaukee,wi
#
#
# Currently retrieving data for milwaukee,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.325257
#
#
# export milwaukee,wi completed!
#
#
#
#
# Retrieving weather data for minneapolis,mn
#
#
# Currently retrieving data for minneapolis,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.326949
#
#
# export minneapolis,mn completed!
#
#
#
#
# Retrieving weather data for minot,nd
#
#
# Currently retrieving data for minot,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.370056
#
#
# export minot,nd completed!
#
#
#
#
# Retrieving weather data for missoula,mt
#
#
# Currently retrieving data for missoula,mt: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.407365
#
#
# export missoula,mt completed!
#
#
#
#
# Retrieving weather data for moab,ut
#
#
# Currently retrieving data for moab,ut: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.738976
#
#
# export moab,ut completed!
#
#
#
#
# Retrieving weather data for mobile,al
#
#
# Currently retrieving data for mobile,al: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.673920
#
#
# export mobile,al completed!
#
#
#
#
# Retrieving weather data for moline,il
#
#
# Currently retrieving data for moline,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.354319
#
#
# export moline,il completed!
#
#
#
#
# Retrieving weather data for monroe,la
#
#
# Currently retrieving data for monroe,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.263749
#
#
# export monroe,la completed!
#
#
#
#
# Retrieving weather data for montgomery,al
#
#
# Currently retrieving data for montgomery,al: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.249002
#
#
# export montgomery,al completed!
#
#
#
#
# Retrieving weather data for montrose,co
#
#
# Currently retrieving data for montrose,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.306096
#
#
# export montrose,co completed!
#
#
#
#
# Retrieving weather data for muskegon,mi
#
#
# Currently retrieving data for muskegon,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.560417
#
#
# export muskegon,mi completed!
#
#
#
#
# Retrieving weather data for myrtlebeach,sc
#
#
# Currently retrieving data for myrtlebeach,sc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.368706
#
#
# export myrtlebeach,sc completed!
#
#
#
#
# Retrieving weather data for nashville,tn
#
#
# Currently retrieving data for nashville,tn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.093461
#
#
# export nashville,tn completed!
#
#
#
#
# Retrieving weather data for newhaven,ct
#
#
# Currently retrieving data for newhaven,ct: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.458996
#
#
# export newhaven,ct completed!
#
#
#
#
# Retrieving weather data for neworleans,la
#
#
# Currently retrieving data for neworleans,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.352331
#
#
# export neworleans,la completed!
#
#
#
#
# Retrieving weather data for newyork,ny
#
#
# Currently retrieving data for newyork,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.501143
#
#
# export newyork,ny completed!
#
#
#
#
# Retrieving weather data for newark,nj
#
#
# Currently retrieving data for newark,nj: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.402835
#
#
# export newark,nj completed!
#
#
#
#
# Retrieving weather data for newburgh,ny
#
#
# Currently retrieving data for newburgh,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.425962
#
#
# export newburgh,ny completed!
#
#
#
#
# Retrieving weather data for nome,ak
#
#
# Currently retrieving data for nome,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.324955
#
#
# export nome,ak completed!
#
#
#
#
# Retrieving weather data for norfolk,va
#
#
# Currently retrieving data for norfolk,va: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.398934
#
#
# export norfolk,va completed!
#
#
#
#
# Retrieving weather data for northbend,or
#
#
# Currently retrieving data for northbend,or: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.028130
#
#
# export northbend,or completed!
#
#
#
#
# Retrieving weather data for northplatte,ne
#
#
# Currently retrieving data for northplatte,ne: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.223371
#
#
# export northplatte,ne completed!
#
#
#
#
# Retrieving weather data for oakland,ca
#
#
# Currently retrieving data for oakland,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.306947
#
#
# export oakland,ca completed!
#
#
#
#
# Retrieving weather data for ogdensburg,ny
#
#
# Currently retrieving data for ogdensburg,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.318346
#
#
# export ogdensburg,ny completed!
#
#
#
#
# Retrieving weather data for oklahomacity,ok
#
#
# Currently retrieving data for oklahomacity,ok: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.310865
#
#
# export oklahomacity,ok completed!
#
#
#
#
# Retrieving weather data for omaha,ne
#
#
# Currently retrieving data for omaha,ne: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.295117
#
#
# export omaha,ne completed!
#
#
#
#
# Retrieving weather data for ontario,ca
#
#
# Currently retrieving data for ontario,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.379902
#
#
# export ontario,ca completed!
#
#
#
#
# Retrieving weather data for orangecounty,ca
#
#
# Currently retrieving data for orangecounty,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.445699
#
#
# export orangecounty,ca completed!
#
#
#
#
# Retrieving weather data for orlando,fl
#
#
# Currently retrieving data for orlando,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.556403
#
#
# export orlando,fl completed!
#
#
#
#
# Retrieving weather data for owensboro,ky
#
#
# Currently retrieving data for owensboro,ky: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.343007
#
#
# export owensboro,ky completed!
#
#
#
#
# Retrieving weather data for paducah,ky
#
#
# Currently retrieving data for paducah,ky: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.512161
#
#
# export paducah,ky completed!
#
#
#
#
# Retrieving weather data for palmsprings,ca
#
#
# Currently retrieving data for palmsprings,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.262336
#
#
# export palmsprings,ca completed!
#
#
#
#
# Retrieving weather data for pasco,wa
#
#
# Currently retrieving data for pasco,wa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.398569
#
#
# export pasco,wa completed!
#
#
#
#
# Retrieving weather data for pellston,mi
#
#
# Currently retrieving data for pellston,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380769
#
#
# export pellston,mi completed!
#
#
#
#
# Retrieving weather data for pensacola,fl
#
#
# Currently retrieving data for pensacola,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.309269
#
#
# export pensacola,fl completed!
#
#
#
#
# Retrieving weather data for peoria,il
#
#
# Currently retrieving data for peoria,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.593130
#
#
# export peoria,il completed!
#
#
#
#
# Retrieving weather data for petersburg,ak
#
#
# Currently retrieving data for petersburg,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.401794
#
#
# export petersburg,ak completed!
#
#
#
#
# Retrieving weather data for philadelphia,pa
#
#
# Currently retrieving data for philadelphia,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.213013
#
#
# export philadelphia,pa completed!
#
#
#
#
# Retrieving weather data for trenton,nj
#
#
# Currently retrieving data for trenton,nj: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.440536
#
#
# export trenton,nj completed!
#
#
#
#
# Retrieving weather data for phoenix,az
#
#
# Currently retrieving data for phoenix,az: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.364492
#
#
# export phoenix,az completed!
#
#
#
#
# Retrieving weather data for pierre,sd
#
#
# Currently retrieving data for pierre,sd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.408456
#
#
# export pierre,sd completed!
#
#
#
#
# Retrieving weather data for pittsburgh,pa
#
#
# Currently retrieving data for pittsburgh,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.342507
#
#
# export pittsburgh,pa completed!
#
#
#
#
# Retrieving weather data for pocatello,id
#
#
# Currently retrieving data for pocatello,id: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.363761
#
#
# export pocatello,id completed!
#
#
#
#
# Retrieving weather data for ponce,puertorico
#
#
# Currently retrieving data for ponce,puertorico: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.504303
#
#
# export ponce,puertorico completed!
#
#
#
#
# Retrieving weather data for portland,me
#
#
# Currently retrieving data for portland,me: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.181052
#
#
# export portland,me completed!
#
#
#
#
# Retrieving weather data for portland,or
#
#
# Currently retrieving data for portland,or: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.572126
#
#
# export portland,or completed!
#
#
#
#
# Retrieving weather data for portsmouth,nh
#
#
# Currently retrieving data for portsmouth,nh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.366448
#
#
# export portsmouth,nh completed!
#
#
#
#
# Retrieving weather data for prescott,az
#
#
# Currently retrieving data for prescott,az: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.392983
#
#
# export prescott,az completed!
#
#
#
#
# Retrieving weather data for providence,ri
#
#
# Currently retrieving data for providence,ri: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.495359
#
#
# export providence,ri completed!
#
#
#
#
# Retrieving weather data for deadhorse,ak
#
#
# Currently retrieving data for deadhorse,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.420367
#
#
# export deadhorse,ak completed!
#
#
#
#
# Retrieving weather data for pueblo,co
#
#
# Currently retrieving data for pueblo,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.366973
#
#
# export pueblo,co completed!
#
#
#
#
# Retrieving weather data for quincy,il
#
#
# Currently retrieving data for quincy,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.655564
#
#
# export quincy,il completed!
#
#
#
#
# Retrieving weather data for rapidcity,sd
#
#
# Currently retrieving data for rapidcity,sd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.460664
#
#
# export rapidcity,sd completed!
#
#
#
#
# Retrieving weather data for redding,ca
#
#
# Currently retrieving data for redding,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404211
#
#
# export redding,ca completed!
#
#
#
#
# Retrieving weather data for redmond,or
#
#
# Currently retrieving data for redmond,or: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.290870
#
#
# export redmond,or completed!
#
#
#
#
# Retrieving weather data for reno,nv
#
#
# Currently retrieving data for reno,nv: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.278559
#
#
# export reno,nv completed!
#
#
#
#
# Retrieving weather data for rhinelander,wi,
#
#
# Currently retrieving data for rhinelander,wi,: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.382306
#
#
# export rhinelander,wi, completed!
#
#
#
#
# Retrieving weather data for richmond,va
#
#
# Currently retrieving data for richmond,va: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.226531
#
#
# export richmond,va completed!
#
#
#
#
# Retrieving weather data for riverton,wy
#
#
# Currently retrieving data for riverton,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.348505
#
#
# export riverton,wy completed!
#
#
#
#
# Retrieving weather data for roanoke,va
#
#
# Currently retrieving data for roanoke,va: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.423674
#
#
# export roanoke,va completed!
#
#
#
#
# Retrieving weather data for rochester,mn
#
#
# Currently retrieving data for rochester,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.342628
#
#
# export rochester,mn completed!
#
#
#
#
# Retrieving weather data for rochester,ny
#
#
# Currently retrieving data for rochester,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.352896
#
#
# export rochester,ny completed!
#
#
#
#
# Retrieving weather data for rocksprings,wy
#
#
# Currently retrieving data for rocksprings,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.361991
#
#
# export rocksprings,wy completed!
#
#
#
#
# Retrieving weather data for roswell,nm
#
#
# Currently retrieving data for roswell,nm: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.332148
#
#
# export roswell,nm completed!
#
#
#
#
# Retrieving weather data for sacramento,ca
#
#
# Currently retrieving data for sacramento,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.326934
#
#
# export sacramento,ca completed!
#
#
#
#
# Retrieving weather data for saintcloud,mn
#
#
# Currently retrieving data for saintcloud,mn: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.403880
#
#
# export saintcloud,mn completed!
#
#
#
#
# Retrieving weather data for saintgeorge,ut
#
#
# Currently retrieving data for saintgeorge,ut: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.404848
#
#
# export saintgeorge,ut completed!
#
#
#
#
# Retrieving weather data for saintlouis,mo
#
#
# Currently retrieving data for saintlouis,mo: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.279693
#
#
# export saintlouis,mo completed!
#
#
#
#
# Retrieving weather data for salina,ks
#
#
# Currently retrieving data for salina,ks: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.395409
#
#
# export salina,ks completed!
#
#
#
#
# Retrieving weather data for saltlakecity,ut
#
#
# Currently retrieving data for saltlakecity,ut: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.292164
#
#
# export saltlakecity,ut completed!
#
#
#
#
# Retrieving weather data for sanangelo,tx
#
#
# Currently retrieving data for sanangelo,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.207746
#
#
# export sanangelo,tx completed!
#
#
#
#
# Retrieving weather data for sanantonio,tx
#
#
# Currently retrieving data for sanantonio,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.314185
#
#
# export sanantonio,tx completed!
#
#
#
#
# Retrieving weather data for sandiego,ca
#
#
# Currently retrieving data for sandiego,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.247910
#
#
# export sandiego,ca completed!
#
#
#
#
# Retrieving weather data for sanfrancisco,ca
#
#
# Currently retrieving data for sanfrancisco,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.391206
#
#
# export sanfrancisco,ca completed!
#
#
#
#
# Retrieving weather data for sanjose,ca
#
#
# Currently retrieving data for sanjose,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.294982
#
#
# export sanjose,ca completed!
#
#
#
#
# Retrieving weather data for sanjuan,puertorico
#
#
# Currently retrieving data for sanjuan,puertorico: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.411968
#
#
# export sanjuan,puertorico completed!
#
#
#
#
# Retrieving weather data for sanluisobispo,ca
#
#
# Currently retrieving data for sanluisobispo,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.741416
#
#
# export sanluisobispo,ca completed!
#
#
#
#
# Retrieving weather data for santabarbara,ca
#
#
# Currently retrieving data for santabarbara,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.294988
#
#
# export santabarbara,ca completed!
#
#
#
#
# Retrieving weather data for santafe,nm
#
#
# Currently retrieving data for santafe,nm: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.327743
#
#
# export santafe,nm completed!
#
#
#
#
# Retrieving weather data for santamaria,ca
#
#
# Currently retrieving data for santamaria,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.727335
#
#
# export santamaria,ca completed!
#
#
#
#
# Retrieving weather data for santarosa,ca
#
#
# Currently retrieving data for santarosa,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.200367
#
#
# export santarosa,ca completed!
#
#
#
#
# Retrieving weather data for sarasota,fl
#
#
# Currently retrieving data for sarasota,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.243377
#
#
# export sarasota,fl completed!
#
#
#
#
# Retrieving weather data for saultstemarie,mi,
#
#
# Currently retrieving data for saultstemarie,mi,: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.364837
#
#
# export saultstemarie,mi, completed!
#
#
#
#
# Retrieving weather data for savannah,ga
#
#
# Currently retrieving data for savannah,ga: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.709419
#
#
# export savannah,ga completed!
#
#
#
#
# Retrieving weather data for scottsbluff,ne
#
#
# Currently retrieving data for scottsbluff,ne: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.361938
#
#
# export scottsbluff,ne completed!
#
#
#
#
# Retrieving weather data for scranton,pa
#
#
# Currently retrieving data for scranton,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.333396
#
#
# export scranton,pa completed!
#
#
#
#
# Retrieving weather data for seattle,wa
#
#
# Currently retrieving data for seattle,wa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.317956
#
#
# export seattle,wa completed!
#
#
#
#
# Retrieving weather data for sheridan,wy
#
#
# Currently retrieving data for sheridan,wy: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.288694
#
#
# export sheridan,wy completed!
#
#
#
#
# Retrieving weather data for shreveport,la
#
#
# Currently retrieving data for shreveport,la: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.245845
#
#
# export shreveport,la completed!
#
#
#
#
# Retrieving weather data for siouxcity,ia
#
#
# Currently retrieving data for siouxcity,ia: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.305163
#
#
# export siouxcity,ia completed!
#
#
#
#
# Retrieving weather data for siouxfalls,sd
#
#
# Currently retrieving data for siouxfalls,sd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.335774
#
#
# export siouxfalls,sd completed!
#
#
#
#
# Retrieving weather data for sitka,ak
#
#
# Currently retrieving data for sitka,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.381873
#
#
# export sitka,ak completed!
#
#
#
#
# Retrieving weather data for southbend,in
#
#
# Currently retrieving data for southbend,in: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.332695
#
#
# export southbend,in completed!
#
#
#
#
# Retrieving weather data for spokane,wa
#
#
# Currently retrieving data for spokane,wa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.348400
#
#
# export spokane,wa completed!
#
#
#
#
# Retrieving weather data for springfield,il
#
#
# Currently retrieving data for springfield,il: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.368317
#
#
# export springfield,il completed!
#
#
#
#
# Retrieving weather data for springfield,mo
#
#
# Currently retrieving data for springfield,mo: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.408563
#
#
# export springfield,mo completed!
#
#
#
#
# Retrieving weather data for universitypark,pa
#
#
# Currently retrieving data for universitypark,pa: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.415727
#
#
# export universitypark,pa completed!
#
#
#
#
# Retrieving weather data for staunton,va
#
#
# Currently retrieving data for staunton,va: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.286563
#
#
# export staunton,va completed!
#
#
#
#
# Retrieving weather data for wausau,wi
#
#
# Currently retrieving data for wausau,wi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.226450
#
#
# export wausau,wi completed!
#
#
#
#
# Retrieving weather data for stockton,ca
#
#
# Currently retrieving data for stockton,ca: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.521300
#
#
# export stockton,ca completed!
#
#
#
#
# Retrieving weather data for syracuse,ny
#
#
# Currently retrieving data for syracuse,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.803545
#
#
# export syracuse,ny completed!
#
#
#
#
# Retrieving weather data for tallahassee,fl
#
#
# Currently retrieving data for tallahassee,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.283835
#
#
# export tallahassee,fl completed!
#
#
#
#
# Retrieving weather data for tampa,fl
#
#
# Currently retrieving data for tampa,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.254040
#
#
# export tampa,fl completed!
#
#
#
#
# Retrieving weather data for texarkana,ar
#
#
# Currently retrieving data for texarkana,ar: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.313824
#
#
# export texarkana,ar completed!
#
#
#
#
# Retrieving weather data for toledo,oh
#
#
# Currently retrieving data for toledo,oh: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.338738
#
#
# export toledo,oh completed!
#
#
#
#
# Retrieving weather data for traversecity,mi
#
#
# Currently retrieving data for traversecity,mi: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.333458
#
#
# export traversecity,mi completed!
#
#
#
#
# Retrieving weather data for tucson,az
#
#
# Currently retrieving data for tucson,az: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.265490
#
#
# export tucson,az completed!
#
#
#
#
# Retrieving weather data for tulsa,ok
#
#
# Currently retrieving data for tulsa,ok: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.512012
#
#
# export tulsa,ok completed!
#
#
#
#
# Retrieving weather data for twinfalls,id
#
#
# Currently retrieving data for twinfalls,id: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.182765
#
#
# export twinfalls,id completed!
#
#
#
#
# Retrieving weather data for tyler,tx
#
#
# Currently retrieving data for tyler,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.373867
#
#
# export tyler,tx completed!
#
#
#
#
# Retrieving weather data for vail,co
#
#
# Currently retrieving data for vail,co: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.279431
#
#
# export vail,co completed!
#
#
#
#
# Retrieving weather data for valdosta,ga
#
#
# Currently retrieving data for valdosta,ga: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.369428
#
#
# export valdosta,ga completed!
#
#
#
#
# Retrieving weather data for vernal,ut
#
#
# Currently retrieving data for vernal,ut: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.382622
#
#
# export vernal,ut completed!
#
#
#
#
# Retrieving weather data for waco,tx
#
#
# Currently retrieving data for waco,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.412818
#
#
# export waco,tx completed!
#
#
#
#
# Retrieving weather data for washington,dc
#
#
# Currently retrieving data for washington,dc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.283343
#
#
# export washington,dc completed!
#
#
#
#
# Retrieving weather data for waterloo,ia
#
#
# Currently retrieving data for waterloo,ia: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.781248
#
#
# export waterloo,ia completed!
#
#
#
#
# Retrieving weather data for watertown,ny
#
#
# Currently retrieving data for watertown,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.503580
#
#
# export watertown,ny completed!
#
#
#
#
# Retrieving weather data for watertown,sd
#
#
# Currently retrieving data for watertown,sd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.298132
#
#
# export watertown,sd completed!
#
#
#
#
# Retrieving weather data for westpalmbeach,fl
#
#
# Currently retrieving data for westpalmbeach,fl: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.361979
#
#
# export westpalmbeach,fl completed!
#
#
#
#
# Retrieving weather data for westchestercounty,ny
#
#
# Currently retrieving data for westchestercounty,ny: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.349987
#
#
# export westchestercounty,ny completed!
#
#
#
#
# Retrieving weather data for wichitafalls,tx
#
#
# Currently retrieving data for wichitafalls,tx: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.156477
#
#
# export wichitafalls,tx completed!
#
#
#
#
# Retrieving weather data for wichita,ks
#
#
# Currently retrieving data for wichita,ks: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.236534
#
#
# export wichita,ks completed!
#
#
#
#
# Retrieving weather data for williston,nd
#
#
# Currently retrieving data for williston,nd: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.363308
#
#
# export williston,nd completed!
#
#
#
#
# Retrieving weather data for wilmington,nc
#
#
# Currently retrieving data for wilmington,nc: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.370658
#
#
# export wilmington,nc completed!
#
#
#
#
# Retrieving weather data for worcester,ma
#
#
# Currently retrieving data for worcester,ma: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.453353
#
#
# export worcester,ma completed!
#
#
#
#
# Retrieving weather data for wrangell,ak
#
#
# Currently retrieving data for wrangell,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.192326
#
#
# export wrangell,ak completed!
#
#
#
#
# Retrieving weather data for yakutat,ak
#
#
# Currently retrieving data for yakutat,ak: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.378073
#
#
# export yakutat,ak completed!
#
#
#
#
# Retrieving weather data for yuma,az
#
#
# Currently retrieving data for yuma,az: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.380517
#
#
# export yuma,az completed!

# %%
#Create variables to hold all csv files and CSVs
all_files = glob.glob(os.path.join("*.csv"))
all_df = []

# Loop through all files, create df's and add all dataframes to the dataframes list
for x in all_files:
    df = pd.read_csv(x, sep=',')
    df['file'] = x.split('/')[-1]
    all_df.append(df)

# %%
#Merge all dataframes
merged_2018_df = pd.concat(all_df, ignore_index=True, sort=True)
merged_2018_df
# Out:
#         DewPointC  FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  \
# 0             -14         -20         -11         -20            31
# 1             -14         -20         -11         -20            32
# 2             -14         -21         -11         -21            33
# 3             -15         -21         -11         -21            34
# 4             -15         -21         -11         -21            33
# ...           ...         ...         ...         ...           ...
# 236587          8          11          12          11            14
# 236588          8          11          11          11            13
# 236589          9          11          11          11            12
# 236590          9          11          11          11            11
# 236591          9          11          11          11            10
#
#         cloudcover            date_time                 file  humidity  \
# 0               61  2018-01-01 00:00:00         islip,ny.csv        77
# 1               50  2018-01-01 01:00:00         islip,ny.csv        76
# 2               40  2018-01-01 02:00:00         islip,ny.csv        76
# 3               29  2018-01-01 03:00:00         islip,ny.csv        75
# 4               20  2018-01-01 04:00:00         islip,ny.csv        74
# ...            ...                  ...                  ...       ...
# 236587          12  2018-01-31 19:00:00  jacksonville,fl.csv        80
# 236588           6  2018-01-31 20:00:00  jacksonville,fl.csv        82
# 236589           0  2018-01-31 21:00:00  jacksonville,fl.csv        84
# 236590           2  2018-01-31 22:00:00  jacksonville,fl.csv        84
# 236591           3  2018-01-31 23:00:00  jacksonville,fl.csv        85
#
#                location  ...  pressure  sunHour   sunrise    sunset tempC  \
# 0              islip,ny  ...      1026      8.7  08:17 AM  05:36 PM   -11
# 1              islip,ny  ...      1026      8.7  08:17 AM  05:36 PM   -11
# 2              islip,ny  ...      1027      8.7  08:17 AM  05:36 PM   -11
# 3              islip,ny  ...      1027      8.7  08:17 AM  05:36 PM   -11
# 4              islip,ny  ...      1027      8.7  08:17 AM  05:36 PM   -11
# ...                 ...  ...       ...      ...       ...       ...   ...
# 236587  jacksonville,fl  ...      1025     10.9  08:18 AM  07:03 PM    12
# 236588  jacksonville,fl  ...      1024     10.9  08:18 AM  07:03 PM    11
# 236589  jacksonville,fl  ...      1024     10.9  08:18 AM  07:03 PM    11
# 236590  jacksonville,fl  ...      1024     10.9  08:18 AM  07:03 PM    11
# 236591  jacksonville,fl  ...      1024     10.9  08:18 AM  07:03 PM    11
#
#         totalSnow_cm  uvIndex  visibility winddirDegree windspeedKmph
# 0                0.0        2          10           328            27
# 1                0.0        2          10           328            28
# 2                0.0        2          10           327            29
# 3                0.0        2          10           326            30
# 4                0.0        2          10           325            29
# ...              ...      ...         ...           ...           ...
# 236587           0.0        4          10            97             8
# 236588           0.0        4          10           101             7
# 236589           0.0        4          10           105             6
# 236590           0.0        4          10           111             6
# 236591           0.0        4          10           116             5
#
# [236592 rows x 26 columns]

# %%
weather_2018_df = pd.DataFrame(merged_2018_df, columns = ['location','date_time','precipMM','visibility','cloudcover','windspeedKmph','humidity',])
weather_2018_df
# Out:
#                location            date_time  precipMM  visibility  \
# 0              islip,ny  2018-01-01 00:00:00       0.0          10
# 1              islip,ny  2018-01-01 01:00:00       0.0          10
# 2              islip,ny  2018-01-01 02:00:00       0.0          10
# 3              islip,ny  2018-01-01 03:00:00       0.0          10
# 4              islip,ny  2018-01-01 04:00:00       0.0          10
# ...                 ...                  ...       ...         ...
# 236587  jacksonville,fl  2018-01-31 19:00:00       0.0          10
# 236588  jacksonville,fl  2018-01-31 20:00:00       0.0          10
# 236589  jacksonville,fl  2018-01-31 21:00:00       0.0          10
# 236590  jacksonville,fl  2018-01-31 22:00:00       0.0          10
# 236591  jacksonville,fl  2018-01-31 23:00:00       0.0          10
#
#         cloudcover  windspeedKmph  humidity
# 0               61             27        77
# 1               50             28        76
# 2               40             29        76
# 3               29             30        75
# 4               20             29        74
# ...            ...            ...       ...
# 236587          12              8        80
# 236588           6              7        82
# 236589           0              6        84
# 236590           2              6        84
# 236591           3              5        85
#
# [236592 rows x 7 columns]

# %%
#Export to CSV
weather_2018_df.to_csv("../../weather_data/weather_2018_df.csv", index=False)
