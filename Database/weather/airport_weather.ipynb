# %%
#Import requests library and API key
import requests
from config import weather_api_key

# Import Dependencies
import pandas as pd

# %% [markdown]
# ### Import & edit necessary DataFrames for API call

# %%
# Import DataFrame from Segment One
initial_2019 = pd.read_csv('../../Database/Data/jan_19_clean.csv')
initial_2020 = pd.read_csv('../../Database/Data/jan_20_clean.csv')
initial_2019
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0                  1            2                  20363         9E   N8688C
# 1                  1            2                  20363         9E   N348PQ
# 2                  1            2                  20363         9E   N8896A
# 3                  1            2                  20363         9E   N8886A
# 4                  1            2                  20363         9E   N8974C
# ...              ...          ...                    ...        ...      ...
# 565958            31            4                  19977         UA   N776UA
# 565959            31            4                  19977         UA   N36280
# 565960            31            4                  19977         UA   N36280
# 565961            31            4                  19977         UA   N39726
# 565962            31            4                  19977         UA   N39726
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0                    3280              11953                1195302    GNV
# 1                    3281              13487                1348702    MSP
# 2                    3282              11433                1143302    DTW
# 3                    3283              15249                1524906    TLH
# 4                    3284              10397                1039707    ATL
# ...                   ...                ...                    ...    ...
# 565958                200              12016                1201602    GUM
# 565959                174              12016                1201602    GUM
# 565960                117              14955                1495503    SPN
# 565961                105              14955                1495503    SPN
# 565962                104              12016                1201602    GUM
#
#         DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 0                 10397              1039707  ATL     601.0        0.0
# 1                 11193              1119302  CVG    1359.0        0.0
# 2                 11193              1119302  CVG    1215.0        0.0
# 3                 10397              1039707  ATL    1521.0        0.0
# 4                 11778              1177801  FSM    1847.0        0.0
# ...                 ...                  ...  ...       ...        ...
# 565958            12173              1217305  HNL     749.0        0.0
# 565959            14955              1495503  SPN     717.0        0.0
# 565960            12016              1201602  GUM     857.0        0.0
# 565961            12016              1201602  GUM    1820.0        0.0
# 565962            14955              1495503  SPN    1636.0        0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  DISTANCE
# 0         0600-0659     722.0        0.0          0         0       300
# 1         1400-1459    1633.0        0.0          0         0       596
# 2         1200-1259    1329.0        0.0          0         0       229
# 3         1500-1559    1625.0        0.0          0         0       223
# 4         1900-1959    1940.0        0.0          0         0       579
# ...             ...       ...        ...        ...       ...       ...
# 565958    0700-0759    1832.0        0.0          0         0      3801
# 565959    0700-0759     759.0        0.0          0         0       129
# 565960    0900-0959     933.0        0.0          0         0       129
# 565961    1800-1859    1854.0        0.0          0         0       129
# 565962    1600-1659    1719.0        0.0          0         0       129
#
# [565963 rows x 20 columns]

# %%
# Import City Codes to Cities DataFrame
city_code_df = pd.read_csv('../Data/airport_codes_final.csv')
city_code_df
# Out:
#     Airport Code             City
# 0            ABR     Aberdeen, SD
# 1            ABI      Abilene, TX
# 2            ADK  Adak Island, AK
# 3            CAK        Akron, OH
# 4            ALB       Albany, NY
# ..           ...              ...
# 342          OGD        Ogden, UT
# 343          LYH    Lynchburg, VA
# 344          XWA    Williston, ND
# 345          PAE      Everett, WA
# 346          BFM       Mobile, AL
#
# [347 rows x 2 columns]

# %%
# Make all cities in lowercase
city_code_lower = city_code_df['City'].str.lower()
city_code_lower
# Out:
# 0         aberdeen, sd
# 1          abilene, tx
# 2      adak island, ak
# 3            akron, oh
# 4           albany, ny
#             ...
# 342          ogden, ut
# 343      lynchburg, va
# 344      williston, nd
# 345        everett, wa
# 346         mobile, al
# Name: City, Length: 347, dtype: object

# %%
# Delete all spaces
city_code_clean = city_code_lower.str.replace(" ", "")
city_code_clean
# Out:
# 0        aberdeen,sd
# 1         abilene,tx
# 2      adakisland,ak
# 3           akron,oh
# 4          albany,ny
#            ...
# 342         ogden,ut
# 343     lynchburg,va
# 344     williston,nd
# 345       everett,wa
# 346        mobile,al
# Name: City, Length: 347, dtype: object

# %%
# Convert the lowercase/no space city series to a dataframe
lower_city_df = city_code_clean.to_frame()
lower_city_df
# Out:
#               City
# 0      aberdeen,sd
# 1       abilene,tx
# 2    adakisland,ak
# 3         akron,oh
# 4        albany,ny
# ..             ...
# 342       ogden,ut
# 343   lynchburg,va
# 344   williston,nd
# 345     everett,wa
# 346      mobile,al
#
# [347 rows x 1 columns]

# %%
# Create a city abreviation dataframe
city_code_abr_df = city_code_df.drop(columns="City")
city_code_abr_df
# Out:
#     Airport Code
# 0            ABR
# 1            ABI
# 2            ADK
# 3            CAK
# 4            ALB
# ..           ...
# 342          OGD
# 343          LYH
# 344          XWA
# 345          PAE
# 346          BFM
#
# [347 rows x 1 columns]

# %%
# Inner join the two dataframes to create a clean city code df that can be used by the API
city_code_clean_df = pd.concat([city_code_abr_df, lower_city_df], axis=1, join='inner')
city_code_clean_df
# Out:
#     Airport Code           City
# 0            ABR    aberdeen,sd
# 1            ABI     abilene,tx
# 2            ADK  adakisland,ak
# 3            CAK       akron,oh
# 4            ALB      albany,ny
# ..           ...            ...
# 342          OGD       ogden,ut
# 343          LYH   lynchburg,va
# 344          XWA   williston,nd
# 345          PAE     everett,wa
# 346          BFM      mobile,al
#
# [347 rows x 2 columns]

# %%
# Return columns that have / 
for city in city_code_clean_df['City']:
    if city.find('/') > -1:
        print(city)

# %%
## export the cleaned city list to a csv
city_code_clean_df.to_csv('../../Flight_data_files/city_code_api.csv')

# %%
# Create a dataframe for the origin cities
origin_code_df = city_code_clean_df.rename(columns={"Airport Code": "ORIGIN"})

# %%
# Create a dataframe for the destination cities
dest_code_df = city_code_clean_df.rename(columns={"Airport Code": "DEST"})
dest_code_df
# Out:
#     DEST           City
# 0    ABR    aberdeen,sd
# 1    ABI     abilene,tx
# 2    ADK  adakisland,ak
# 3    CAK       akron,oh
# 4    ALB      albany,ny
# ..   ...            ...
# 342  OGD       ogden,ut
# 343  LYH   lynchburg,va
# 344  XWA   williston,nd
# 345  PAE     everett,wa
# 346  BFM      mobile,al
#
# [347 rows x 2 columns]

# %%
flights_2019 = initial_2019[["DAY_OF_MONTH","DAY_OF_WEEK","OP_CARRIER_AIRLINE_ID","OP_CARRIER","TAIL_NUM","OP_CARRIER_FL_NUM","ORIGIN_AIRPORT_ID","ORIGIN_AIRPORT_SEQ_ID","ORIGIN","DEST_AIRPORT_ID","DEST_AIRPORT_SEQ_ID","DEST","DEP_TIME","DEP_DEL15","DEP_TIME_BLK","ARR_TIME","ARR_DEL15","CANCELLED","DIVERTED","DISTANCE"]]
flights_2019
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0                  1            2                  20363         9E   N8688C
# 1                  1            2                  20363         9E   N348PQ
# 2                  1            2                  20363         9E   N8896A
# 3                  1            2                  20363         9E   N8886A
# 4                  1            2                  20363         9E   N8974C
# ...              ...          ...                    ...        ...      ...
# 565958            31            4                  19977         UA   N776UA
# 565959            31            4                  19977         UA   N36280
# 565960            31            4                  19977         UA   N36280
# 565961            31            4                  19977         UA   N39726
# 565962            31            4                  19977         UA   N39726
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0                    3280              11953                1195302    GNV
# 1                    3281              13487                1348702    MSP
# 2                    3282              11433                1143302    DTW
# 3                    3283              15249                1524906    TLH
# 4                    3284              10397                1039707    ATL
# ...                   ...                ...                    ...    ...
# 565958                200              12016                1201602    GUM
# 565959                174              12016                1201602    GUM
# 565960                117              14955                1495503    SPN
# 565961                105              14955                1495503    SPN
# 565962                104              12016                1201602    GUM
#
#         DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 0                 10397              1039707  ATL     601.0        0.0
# 1                 11193              1119302  CVG    1359.0        0.0
# 2                 11193              1119302  CVG    1215.0        0.0
# 3                 10397              1039707  ATL    1521.0        0.0
# 4                 11778              1177801  FSM    1847.0        0.0
# ...                 ...                  ...  ...       ...        ...
# 565958            12173              1217305  HNL     749.0        0.0
# 565959            14955              1495503  SPN     717.0        0.0
# 565960            12016              1201602  GUM     857.0        0.0
# 565961            12016              1201602  GUM    1820.0        0.0
# 565962            14955              1495503  SPN    1636.0        0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  DISTANCE
# 0         0600-0659     722.0        0.0          0         0       300
# 1         1400-1459    1633.0        0.0          0         0       596
# 2         1200-1259    1329.0        0.0          0         0       229
# 3         1500-1559    1625.0        0.0          0         0       223
# 4         1900-1959    1940.0        0.0          0         0       579
# ...             ...       ...        ...        ...       ...       ...
# 565958    0700-0759    1832.0        0.0          0         0      3801
# 565959    0700-0759     759.0        0.0          0         0       129
# 565960    0900-0959     933.0        0.0          0         0       129
# 565961    1800-1859    1854.0        0.0          0         0       129
# 565962    1600-1659    1719.0        0.0          0         0       129
#
# [565963 rows x 20 columns]

# %%
# Merge Origin code and the flights dataframes
origin_join_2019_df = pd.merge(origin_code_df,flights_2019, on='ORIGIN', how ='inner')
origin_join_2019_df
# Out:
#        ORIGIN          City  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR   aberdeen,sd             1            2                  20304
# 1         ABR   aberdeen,sd             1            2                  20304
# 2         ABR   aberdeen,sd             2            3                  20304
# 3         ABR   aberdeen,sd             2            3                  20304
# 4         ABR   aberdeen,sd             3            4                  20304
# ...       ...           ...           ...          ...                    ...
# 564543    LYH  lynchburg,va            29            2                  20397
# 564544    LYH  lynchburg,va            30            3                  20397
# 564545    LYH  lynchburg,va            30            3                  20397
# 564546    LYH  lynchburg,va            31            4                  20397
# 564547    LYH  lynchburg,va            31            4                  20397
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              10141
# 1              OO   N432SW               7365              10141
# 2              OO   N498CA               7363              10141
# 3              OO   N439SW               7365              10141
# 4              OO   N8965E               7363              10141
# ...           ...      ...                ...                ...
# 564543         OH   N519AE               5174              13139
# 564544         OH   N563NN               5116              13139
# 564545         OH   N712PS               5174              13139
# 564546         OH   N709PS               5116              13139
# 564547         OH   N723PS               5174              13139
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1014106  ...              1348702   MSP   1411.0
# 1                     1014106  ...              1348702   MSP    642.0
# 2                     1014106  ...              1348702   MSP   1310.0
# 3                     1014106  ...              1348702   MSP    502.0
# 4                     1014106  ...              1348702   MSP   1307.0
# ...                       ...  ...                  ...   ...      ...
# 564543                1313902  ...              1105703   CLT   1108.0
# 564544                1313902  ...              1105703   CLT    642.0
# 564545                1313902  ...              1105703   CLT   1102.0
# 564546                1313902  ...              1105703   CLT    648.0
# 564547                1313902  ...              1105703   CLT   1107.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             1.0     1300-1359   1521.0        1.0          0         0
# 1             0.0     0600-0659    800.0        0.0          0         0
# 2             0.0     1300-1359   1424.0        0.0          0         0
# 3             0.0     0001-0559    622.0        0.0          0         0
# 4             0.0     1300-1359   1411.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 564543        0.0     1100-1159   1223.0        0.0          0         0
# 564544        0.0     0600-0659    744.0        0.0          0         0
# 564545        0.0     1100-1159   1220.0        0.0          0         0
# 564546        0.0     0600-0659    746.0        0.0          0         0
# 564547        0.0     1100-1159   1232.0        0.0          0         0
#
#         DISTANCE
# 0            257
# 1            257
# 2            257
# 3            257
# 4            257
# ...          ...
# 564543       175
# 564544       175
# 564545       175
# 564546       175
# 564547       175
#
# [564548 rows x 21 columns]

# %%
# Change city column to Origin City
origin_join_2019_df = origin_join_2019_df.rename(columns={'City':'ORIGIN_CITY'})
origin_join_2019_df
# Out:
#        ORIGIN   ORIGIN_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR   aberdeen,sd             1            2                  20304
# 1         ABR   aberdeen,sd             1            2                  20304
# 2         ABR   aberdeen,sd             2            3                  20304
# 3         ABR   aberdeen,sd             2            3                  20304
# 4         ABR   aberdeen,sd             3            4                  20304
# ...       ...           ...           ...          ...                    ...
# 564543    LYH  lynchburg,va            29            2                  20397
# 564544    LYH  lynchburg,va            30            3                  20397
# 564545    LYH  lynchburg,va            30            3                  20397
# 564546    LYH  lynchburg,va            31            4                  20397
# 564547    LYH  lynchburg,va            31            4                  20397
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              10141
# 1              OO   N432SW               7365              10141
# 2              OO   N498CA               7363              10141
# 3              OO   N439SW               7365              10141
# 4              OO   N8965E               7363              10141
# ...           ...      ...                ...                ...
# 564543         OH   N519AE               5174              13139
# 564544         OH   N563NN               5116              13139
# 564545         OH   N712PS               5174              13139
# 564546         OH   N709PS               5116              13139
# 564547         OH   N723PS               5174              13139
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1014106  ...              1348702   MSP   1411.0
# 1                     1014106  ...              1348702   MSP    642.0
# 2                     1014106  ...              1348702   MSP   1310.0
# 3                     1014106  ...              1348702   MSP    502.0
# 4                     1014106  ...              1348702   MSP   1307.0
# ...                       ...  ...                  ...   ...      ...
# 564543                1313902  ...              1105703   CLT   1108.0
# 564544                1313902  ...              1105703   CLT    642.0
# 564545                1313902  ...              1105703   CLT   1102.0
# 564546                1313902  ...              1105703   CLT    648.0
# 564547                1313902  ...              1105703   CLT   1107.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             1.0     1300-1359   1521.0        1.0          0         0
# 1             0.0     0600-0659    800.0        0.0          0         0
# 2             0.0     1300-1359   1424.0        0.0          0         0
# 3             0.0     0001-0559    622.0        0.0          0         0
# 4             0.0     1300-1359   1411.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 564543        0.0     1100-1159   1223.0        0.0          0         0
# 564544        0.0     0600-0659    744.0        0.0          0         0
# 564545        0.0     1100-1159   1220.0        0.0          0         0
# 564546        0.0     0600-0659    746.0        0.0          0         0
# 564547        0.0     1100-1159   1232.0        0.0          0         0
#
#         DISTANCE
# 0            257
# 1            257
# 2            257
# 3            257
# 4            257
# ...          ...
# 564543       175
# 564544       175
# 564545       175
# 564546       175
# 564547       175
#
# [564548 rows x 21 columns]

# %%
# Create a destination dataframe by merging the flights with destination codes
dest_join_2019_df = pd.merge(dest_code_df,flights_2019, on='DEST', how ='inner')
dest_join_2019_df
# Out:
#        DEST          City  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0       ABR   aberdeen,sd             1            2                  20304
# 1       ABR   aberdeen,sd             1            2                  20304
# 2       ABR   aberdeen,sd             2            3                  20304
# 3       ABR   aberdeen,sd             2            3                  20304
# 4       ABR   aberdeen,sd             3            4                  20304
# ...     ...           ...           ...          ...                    ...
# 564536  LYH  lynchburg,va            29            2                  20397
# 564537  LYH  lynchburg,va            30            3                  20397
# 564538  LYH  lynchburg,va            30            3                  20397
# 564539  LYH  lynchburg,va            31            4                  20397
# 564540  LYH  lynchburg,va            31            4                  20397
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              13487
# 1              OO   N439SW               7419              13487
# 2              OO   N498CA               7363              13487
# 3              OO   N935SW               7419              13487
# 4              OO   N8965E               7363              13487
# ...           ...      ...                ...                ...
# 564536         OH   N519AE               5174              11057
# 564537         OH   N709PS               5123              11057
# 564538         OH   N712PS               5174              11057
# 564539         OH   N510AE               5123              11057
# 564540         OH   N723PS               5174              11057
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  \
# 0                     1348702  ...           10141              1014106
# 1                     1348702  ...           10141              1014106
# 2                     1348702  ...           10141              1014106
# 3                     1348702  ...           10141              1014106
# 4                     1348702  ...           10141              1014106
# ...                       ...  ...             ...                  ...
# 564536                1105703  ...           13139              1313902
# 564537                1105703  ...           13139              1313902
# 564538                1105703  ...           13139              1313902
# 564539                1105703  ...           13139              1313902
# 564540                1105703  ...           13139              1313902
#
#         DEP_TIME  DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  \
# 0         1220.0        1.0     1100-1159   1343.0        1.0          0
# 1         2010.0        0.0     2000-2059   2139.0        0.0          0
# 2         1123.0        0.0     1100-1159   1230.0        0.0          0
# 3         2226.0        0.0     2200-2259   2342.0        0.0          0
# 4         1120.0        0.0     1100-1159   1224.0        0.0          0
# ...          ...        ...           ...      ...        ...        ...
# 564536     925.0        0.0     0900-0959   1030.0        0.0          0
# 564537    2014.0        0.0     2000-2059   2101.0        0.0          0
# 564538     928.0        0.0     0900-0959   1034.0        0.0          0
# 564539    2019.0        0.0     2000-2059   2131.0        0.0          0
# 564540     947.0        0.0     0900-0959   1044.0        0.0          0
#
#         DIVERTED  DISTANCE
# 0              0       257
# 1              0       257
# 2              0       257
# 3              0       257
# 4              0       257
# ...          ...       ...
# 564536         0       175
# 564537         0       175
# 564538         0       175
# 564539         0       175
# 564540         0       175
#
# [564541 rows x 21 columns]

# %%
# Change city column to Destination City
dest_join_2019_df = dest_join_2019_df.rename(columns={'City':'DEST_CITY'})
dest_join_2019_df
# Out:
#        DEST     DEST_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0       ABR   aberdeen,sd             1            2                  20304
# 1       ABR   aberdeen,sd             1            2                  20304
# 2       ABR   aberdeen,sd             2            3                  20304
# 3       ABR   aberdeen,sd             2            3                  20304
# 4       ABR   aberdeen,sd             3            4                  20304
# ...     ...           ...           ...          ...                    ...
# 564536  LYH  lynchburg,va            29            2                  20397
# 564537  LYH  lynchburg,va            30            3                  20397
# 564538  LYH  lynchburg,va            30            3                  20397
# 564539  LYH  lynchburg,va            31            4                  20397
# 564540  LYH  lynchburg,va            31            4                  20397
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              13487
# 1              OO   N439SW               7419              13487
# 2              OO   N498CA               7363              13487
# 3              OO   N935SW               7419              13487
# 4              OO   N8965E               7363              13487
# ...           ...      ...                ...                ...
# 564536         OH   N519AE               5174              11057
# 564537         OH   N709PS               5123              11057
# 564538         OH   N712PS               5174              11057
# 564539         OH   N510AE               5123              11057
# 564540         OH   N723PS               5174              11057
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  \
# 0                     1348702  ...           10141              1014106
# 1                     1348702  ...           10141              1014106
# 2                     1348702  ...           10141              1014106
# 3                     1348702  ...           10141              1014106
# 4                     1348702  ...           10141              1014106
# ...                       ...  ...             ...                  ...
# 564536                1105703  ...           13139              1313902
# 564537                1105703  ...           13139              1313902
# 564538                1105703  ...           13139              1313902
# 564539                1105703  ...           13139              1313902
# 564540                1105703  ...           13139              1313902
#
#         DEP_TIME  DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  \
# 0         1220.0        1.0     1100-1159   1343.0        1.0          0
# 1         2010.0        0.0     2000-2059   2139.0        0.0          0
# 2         1123.0        0.0     1100-1159   1230.0        0.0          0
# 3         2226.0        0.0     2200-2259   2342.0        0.0          0
# 4         1120.0        0.0     1100-1159   1224.0        0.0          0
# ...          ...        ...           ...      ...        ...        ...
# 564536     925.0        0.0     0900-0959   1030.0        0.0          0
# 564537    2014.0        0.0     2000-2059   2101.0        0.0          0
# 564538     928.0        0.0     0900-0959   1034.0        0.0          0
# 564539    2019.0        0.0     2000-2059   2131.0        0.0          0
# 564540     947.0        0.0     0900-0959   1044.0        0.0          0
#
#         DIVERTED  DISTANCE
# 0              0       257
# 1              0       257
# 2              0       257
# 3              0       257
# 4              0       257
# ...          ...       ...
# 564536         0       175
# 564537         0       175
# 564538         0       175
# 564539         0       175
# 564540         0       175
#
# [564541 rows x 21 columns]

# %%
# Merge the origin and destination dataframes to prepare for the API requests
complete_flight_2019_df = pd.merge(origin_join_2019_df, dest_join_2019_df)
complete_flight_2019_df
# Out:
#        ORIGIN   ORIGIN_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR   aberdeen,sd             1            2                  20304
# 1         ABR   aberdeen,sd             1            2                  20304
# 2         ABR   aberdeen,sd             2            3                  20304
# 3         ABR   aberdeen,sd             2            3                  20304
# 4         ABR   aberdeen,sd             3            4                  20304
# ...       ...           ...           ...          ...                    ...
# 563121    LYH  lynchburg,va            29            2                  20397
# 563122    LYH  lynchburg,va            30            3                  20397
# 563123    LYH  lynchburg,va            30            3                  20397
# 563124    LYH  lynchburg,va            31            4                  20397
# 563125    LYH  lynchburg,va            31            4                  20397
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              10141
# 1              OO   N432SW               7365              10141
# 2              OO   N498CA               7363              10141
# 3              OO   N439SW               7365              10141
# 4              OO   N8965E               7363              10141
# ...           ...      ...                ...                ...
# 563121         OH   N519AE               5174              13139
# 563122         OH   N563NN               5116              13139
# 563123         OH   N712PS               5174              13139
# 563124         OH   N709PS               5116              13139
# 563125         OH   N723PS               5174              13139
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                     1014106  ...   MSP    1411.0       1.0     1300-1359
# 1                     1014106  ...   MSP     642.0       0.0     0600-0659
# 2                     1014106  ...   MSP    1310.0       0.0     1300-1359
# 3                     1014106  ...   MSP     502.0       0.0     0001-0559
# 4                     1014106  ...   MSP    1307.0       0.0     1300-1359
# ...                       ...  ...   ...       ...       ...           ...
# 563121                1313902  ...   CLT    1108.0       0.0     1100-1159
# 563122                1313902  ...   CLT     642.0       0.0     0600-0659
# 563123                1313902  ...   CLT    1102.0       0.0     1100-1159
# 563124                1313902  ...   CLT     648.0       0.0     0600-0659
# 563125                1313902  ...   CLT    1107.0       0.0     1100-1159
#
#         ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE       DEST_CITY
# 0         1521.0       1.0          0         0       257  minneapolis,mn
# 1          800.0       0.0          0         0       257  minneapolis,mn
# 2         1424.0       0.0          0         0       257  minneapolis,mn
# 3          622.0       0.0          0         0       257  minneapolis,mn
# 4         1411.0       0.0          0         0       257  minneapolis,mn
# ...          ...       ...        ...       ...       ...             ...
# 563121    1223.0       0.0          0         0       175    charlotte,nc
# 563122     744.0       0.0          0         0       175    charlotte,nc
# 563123    1220.0       0.0          0         0       175    charlotte,nc
# 563124     746.0       0.0          0         0       175    charlotte,nc
# 563125    1232.0       0.0          0         0       175    charlotte,nc
#
# [563126 rows x 22 columns]

# %%
#Add date format
complete_flight_2019_df['DAY_OF_MONTH'] = '2019-01-' + complete_flight_2019_df['DAY_OF_MONTH'].astype(str)
clean_complete_flight_2019_df = complete_flight_2019_df.rename(columns={"'DAY_OF_MONTH'": "Date"})
clean_complete_flight_2019_df
# Out:
#        ORIGIN   ORIGIN_CITY DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR   aberdeen,sd    2019-01-1            2                  20304
# 1         ABR   aberdeen,sd    2019-01-1            2                  20304
# 2         ABR   aberdeen,sd    2019-01-2            3                  20304
# 3         ABR   aberdeen,sd    2019-01-2            3                  20304
# 4         ABR   aberdeen,sd    2019-01-3            4                  20304
# ...       ...           ...          ...          ...                    ...
# 563121    LYH  lynchburg,va   2019-01-29            2                  20397
# 563122    LYH  lynchburg,va   2019-01-30            3                  20397
# 563123    LYH  lynchburg,va   2019-01-30            3                  20397
# 563124    LYH  lynchburg,va   2019-01-31            4                  20397
# 563125    LYH  lynchburg,va   2019-01-31            4                  20397
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              10141
# 1              OO   N432SW               7365              10141
# 2              OO   N498CA               7363              10141
# 3              OO   N439SW               7365              10141
# 4              OO   N8965E               7363              10141
# ...           ...      ...                ...                ...
# 563121         OH   N519AE               5174              13139
# 563122         OH   N563NN               5116              13139
# 563123         OH   N712PS               5174              13139
# 563124         OH   N709PS               5116              13139
# 563125         OH   N723PS               5174              13139
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                     1014106  ...   MSP    1411.0       1.0     1300-1359
# 1                     1014106  ...   MSP     642.0       0.0     0600-0659
# 2                     1014106  ...   MSP    1310.0       0.0     1300-1359
# 3                     1014106  ...   MSP     502.0       0.0     0001-0559
# 4                     1014106  ...   MSP    1307.0       0.0     1300-1359
# ...                       ...  ...   ...       ...       ...           ...
# 563121                1313902  ...   CLT    1108.0       0.0     1100-1159
# 563122                1313902  ...   CLT     642.0       0.0     0600-0659
# 563123                1313902  ...   CLT    1102.0       0.0     1100-1159
# 563124                1313902  ...   CLT     648.0       0.0     0600-0659
# 563125                1313902  ...   CLT    1107.0       0.0     1100-1159
#
#         ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE       DEST_CITY
# 0         1521.0       1.0          0         0       257  minneapolis,mn
# 1          800.0       0.0          0         0       257  minneapolis,mn
# 2         1424.0       0.0          0         0       257  minneapolis,mn
# 3          622.0       0.0          0         0       257  minneapolis,mn
# 4         1411.0       0.0          0         0       257  minneapolis,mn
# ...          ...       ...        ...       ...       ...             ...
# 563121    1223.0       0.0          0         0       175    charlotte,nc
# 563122     744.0       0.0          0         0       175    charlotte,nc
# 563123    1220.0       0.0          0         0       175    charlotte,nc
# 563124     746.0       0.0          0         0       175    charlotte,nc
# 563125    1232.0       0.0          0         0       175    charlotte,nc
#
# [563126 rows x 22 columns]

# %%
clean_complete_flight_2019_df.to_csv("../../Database/clean_2019_flight_data.csv", index=False)

# %% [markdown]
# ### 2020 Flights

# %%
flights_2020 = initial_2020[["DAY_OF_MONTH","DAY_OF_WEEK","OP_CARRIER_AIRLINE_ID","OP_CARRIER","TAIL_NUM","OP_CARRIER_FL_NUM","ORIGIN_AIRPORT_ID","ORIGIN_AIRPORT_SEQ_ID","ORIGIN","DEST_AIRPORT_ID","DEST_AIRPORT_SEQ_ID","DEST","DEP_TIME","DEP_DEL15","DEP_TIME_BLK","ARR_TIME","ARR_DEL15","CANCELLED","DIVERTED","DISTANCE"]]
flights_2020
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0                  1            3                  20366         EV   N48901
# 1                  1            3                  20366         EV   N16976
# 2                  1            3                  20366         EV   N12167
# 3                  1            3                  20366         EV   N14902
# 4                  1            3                  20366         EV   N606UX
# ...              ...          ...                    ...        ...      ...
# 599263            31            5                  20363         9E   N331CA
# 599264            31            5                  20363         9E   N295PQ
# 599265            31            5                  20363         9E   N294PQ
# 599266            31            5                  20363         9E   N228PQ
# 599267            31            5                  20363         9E   N228PQ
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0                    4397              13930                1393007    ORD
# 1                    4401              15370                1537002    TUL
# 2                    4404              11618                1161802    EWR
# 3                    4405              10781                1078105    BTR
# 4                    4407              14524                1452401    RIC
# ...                   ...                ...                    ...    ...
# 599263               4812              15412                1541205    TYS
# 599264               4813              11433                1143302    DTW
# 599265               4814              11996                1199603    GSP
# 599266               4815              10397                1039707    ATL
# 599267               4815              15919                1591904    XNA
#
#         DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 0                 11977              1197705  GRB    1003.0        0.0
# 1                 13930              1393007  ORD    1027.0        0.0
# 2                 15412              1541205  TYS    1848.0        0.0
# 3                 12266              1226603  IAH    1846.0        0.0
# 4                 12266              1226603  IAH    1038.0        0.0
# ...                 ...                  ...  ...       ...        ...
# 599263            11433              1143302  DTW    1002.0        1.0
# 599264            12478              1247805  JFK    1747.0        0.0
# 599265            12953              1295304  LGA     554.0        0.0
# 599266            15919              1591904  XNA    1714.0        0.0
# 599267            10397              1039707  ATL    1841.0        0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  DISTANCE
# 0         1000-1059    1117.0        0.0          0         0       174
# 1         1000-1059    1216.0        0.0          0         0       585
# 2         1800-1859    2120.0        0.0          0         0       631
# 3         1800-1859    2004.0        0.0          0         0       253
# 4         1000-1059    1330.0        0.0          0         0      1157
# ...             ...       ...        ...        ...       ...       ...
# 599263    0700-0759    1128.0        1.0          0         0       443
# 599264    1700-1759    1933.0        0.0          0         0       509
# 599265    0600-0659     752.0        0.0          0         0       610
# 599266    1700-1759    1811.0        0.0          0         0       589
# 599267    1800-1859    2128.0        0.0          0         0       589
#
# [599268 rows x 20 columns]

# %%
# Merge Origin code and the flights dataframes
origin_join_2020_df = pd.merge(origin_code_df,flights_2020, on='ORIGIN', how ='inner')
origin_join_2020_df
# Out:
#        ORIGIN         City  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR  aberdeen,sd             1            3                  20304
# 1         ABR  aberdeen,sd             1            3                  20304
# 2         ABR  aberdeen,sd             2            4                  20304
# 3         ABR  aberdeen,sd             2            4                  20304
# 4         ABR  aberdeen,sd             3            5                  20304
# ...       ...          ...           ...          ...                    ...
# 597708    BFM    mobile,al            22            3                  20436
# 597709    BFM    mobile,al            24            5                  20436
# 597710    BFM    mobile,al            27            1                  20436
# 597711    BFM    mobile,al            29            3                  20436
# 597712    BFM    mobile,al            31            5                  20436
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N878AS               4244              10141
# 1              OO   N8942A               4255              10141
# 2              OO   N8965E               4244              10141
# 3              OO   N8933B               4255              10141
# 4              OO   N477CA               4244              10141
# ...           ...      ...                ...                ...
# 597708         F9   N939FR                235              10562
# 597709         F9   N202FR                235              10562
# 597710         F9   N941FR                235              10562
# 597711         F9   N941FR                235              10562
# 597712         F9   N943FR                235              10562
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1014106  ...              1348702   MSP   1316.0
# 1                     1014106  ...              1348702   MSP    459.0
# 2                     1014106  ...              1348702   MSP   1417.0
# 3                     1014106  ...              1348702   MSP    455.0
# 4                     1014106  ...              1348702   MSP   1316.0
# ...                       ...  ...                  ...   ...      ...
# 597708                1056202  ...              1129202   DEN   1218.0
# 597709                1056202  ...              1129202   DEN   1225.0
# 597710                1056202  ...              1129202   DEN   1229.0
# 597711                1056202  ...              1129202   DEN   1234.0
# 597712                1056202  ...              1129202   DEN   1436.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             0.0     1300-1359   1438.0        0.0          0         0
# 1             0.0     0001-0559    605.0        0.0          0         0
# 2             1.0     1300-1359   1518.0        1.0          0         0
# 3             0.0     0001-0559    616.0        0.0          0         0
# 4             0.0     1300-1359   1438.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 597708        0.0     1200-1259   1418.0        0.0          0         0
# 597709        0.0     1200-1259   1417.0        0.0          0         0
# 597710        0.0     1200-1259   1430.0        0.0          0         0
# 597711        0.0     1200-1259   1445.0        0.0          0         0
# 597712        1.0     1200-1259   1633.0        1.0          0         0
#
#         DISTANCE
# 0            257
# 1            257
# 2            257
# 3            257
# 4            257
# ...          ...
# 597708      1132
# 597709      1132
# 597710      1132
# 597711      1132
# 597712      1132
#
# [597713 rows x 21 columns]

# %%
# Change city column to Origin City
origin_join_2020_df = origin_join_2020_df.rename(columns={'City':'ORIGIN_CITY'})
origin_join_2020_df
# Out:
#        ORIGIN  ORIGIN_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR  aberdeen,sd             1            3                  20304
# 1         ABR  aberdeen,sd             1            3                  20304
# 2         ABR  aberdeen,sd             2            4                  20304
# 3         ABR  aberdeen,sd             2            4                  20304
# 4         ABR  aberdeen,sd             3            5                  20304
# ...       ...          ...           ...          ...                    ...
# 597708    BFM    mobile,al            22            3                  20436
# 597709    BFM    mobile,al            24            5                  20436
# 597710    BFM    mobile,al            27            1                  20436
# 597711    BFM    mobile,al            29            3                  20436
# 597712    BFM    mobile,al            31            5                  20436
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N878AS               4244              10141
# 1              OO   N8942A               4255              10141
# 2              OO   N8965E               4244              10141
# 3              OO   N8933B               4255              10141
# 4              OO   N477CA               4244              10141
# ...           ...      ...                ...                ...
# 597708         F9   N939FR                235              10562
# 597709         F9   N202FR                235              10562
# 597710         F9   N941FR                235              10562
# 597711         F9   N941FR                235              10562
# 597712         F9   N943FR                235              10562
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1014106  ...              1348702   MSP   1316.0
# 1                     1014106  ...              1348702   MSP    459.0
# 2                     1014106  ...              1348702   MSP   1417.0
# 3                     1014106  ...              1348702   MSP    455.0
# 4                     1014106  ...              1348702   MSP   1316.0
# ...                       ...  ...                  ...   ...      ...
# 597708                1056202  ...              1129202   DEN   1218.0
# 597709                1056202  ...              1129202   DEN   1225.0
# 597710                1056202  ...              1129202   DEN   1229.0
# 597711                1056202  ...              1129202   DEN   1234.0
# 597712                1056202  ...              1129202   DEN   1436.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             0.0     1300-1359   1438.0        0.0          0         0
# 1             0.0     0001-0559    605.0        0.0          0         0
# 2             1.0     1300-1359   1518.0        1.0          0         0
# 3             0.0     0001-0559    616.0        0.0          0         0
# 4             0.0     1300-1359   1438.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 597708        0.0     1200-1259   1418.0        0.0          0         0
# 597709        0.0     1200-1259   1417.0        0.0          0         0
# 597710        0.0     1200-1259   1430.0        0.0          0         0
# 597711        0.0     1200-1259   1445.0        0.0          0         0
# 597712        1.0     1200-1259   1633.0        1.0          0         0
#
#         DISTANCE
# 0            257
# 1            257
# 2            257
# 3            257
# 4            257
# ...          ...
# 597708      1132
# 597709      1132
# 597710      1132
# 597711      1132
# 597712      1132
#
# [597713 rows x 21 columns]

# %%
# Create a destination dataframe by merging the flights with destination codes
dest_join_2020_df = pd.merge(dest_code_df,flights_2020, on='DEST', how ='inner')
dest_join_2020_df
# Out:
#        DEST         City  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0       ABR  aberdeen,sd             1            3                  20304
# 1       ABR  aberdeen,sd             1            3                  20304
# 2       ABR  aberdeen,sd             2            4                  20304
# 3       ABR  aberdeen,sd             2            4                  20304
# 4       ABR  aberdeen,sd             3            5                  20304
# ...     ...          ...           ...          ...                    ...
# 597707  BFM    mobile,al            22            3                  20436
# 597708  BFM    mobile,al            24            5                  20436
# 597709  BFM    mobile,al            27            1                  20436
# 597710  BFM    mobile,al            29            3                  20436
# 597711  BFM    mobile,al            31            5                  20436
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N878AS               4244              13487
# 1              OO   N8933B               4264              13487
# 2              OO   N8965E               4244              13487
# 3              OO   N8965E               4264              13487
# 4              OO   N477CA               4244              13487
# ...           ...      ...                ...                ...
# 597707         F9   N939FR                234              11292
# 597708         F9   N202FR                234              11292
# 597709         F9   N941FR                234              11292
# 597710         F9   N941FR                234              11292
# 597711         F9   N943FR                234              11292
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  \
# 0                     1348702  ...           10141              1014106
# 1                     1348702  ...           10141              1014106
# 2                     1348702  ...           10141              1014106
# 3                     1348702  ...           10141              1014106
# 4                     1348702  ...           10141              1014106
# ...                       ...  ...             ...                  ...
# 597707                1129202  ...           10562              1056202
# 597708                1129202  ...           10562              1056202
# 597709                1129202  ...           10562              1056202
# 597710                1129202  ...           10562              1056202
# 597711                1129202  ...           10562              1056202
#
#         DEP_TIME  DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  \
# 0         1129.0        0.0     1100-1159   1241.0        0.0          0
# 1         2013.0        0.0     2000-2059   2125.0        0.0          0
# 2         1226.0        1.0     1100-1159   1343.0        1.0          0
# 3         2224.0        0.0     2200-2259   2344.0        0.0          0
# 4         1136.0        0.0     1100-1159   1247.0        0.0          0
# ...          ...        ...           ...      ...        ...        ...
# 597707     754.0        0.0     0800-0859   1132.0        0.0          0
# 597708     750.0        0.0     0800-0859   1135.0        0.0          0
# 597709     755.0        0.0     0800-0859   1135.0        0.0          0
# 597710     750.0        0.0     0800-0859   1207.0        1.0          0
# 597711    1002.0        1.0     0800-0859   1346.0        1.0          0
#
#         DIVERTED  DISTANCE
# 0              0       257
# 1              0       257
# 2              0       257
# 3              0       257
# 4              0       257
# ...          ...       ...
# 597707         0      1132
# 597708         0      1132
# 597709         0      1132
# 597710         0      1132
# 597711         0      1132
#
# [597712 rows x 21 columns]

# %%
# Change city column to Destination City
dest_join_2020_df = dest_join_2020_df.rename(columns={'City':'DEST_CITY'})
dest_join_2020_df
# Out:
#        DEST    DEST_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0       ABR  aberdeen,sd             1            3                  20304
# 1       ABR  aberdeen,sd             1            3                  20304
# 2       ABR  aberdeen,sd             2            4                  20304
# 3       ABR  aberdeen,sd             2            4                  20304
# 4       ABR  aberdeen,sd             3            5                  20304
# ...     ...          ...           ...          ...                    ...
# 597707  BFM    mobile,al            22            3                  20436
# 597708  BFM    mobile,al            24            5                  20436
# 597709  BFM    mobile,al            27            1                  20436
# 597710  BFM    mobile,al            29            3                  20436
# 597711  BFM    mobile,al            31            5                  20436
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N878AS               4244              13487
# 1              OO   N8933B               4264              13487
# 2              OO   N8965E               4244              13487
# 3              OO   N8965E               4264              13487
# 4              OO   N477CA               4244              13487
# ...           ...      ...                ...                ...
# 597707         F9   N939FR                234              11292
# 597708         F9   N202FR                234              11292
# 597709         F9   N941FR                234              11292
# 597710         F9   N941FR                234              11292
# 597711         F9   N943FR                234              11292
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  \
# 0                     1348702  ...           10141              1014106
# 1                     1348702  ...           10141              1014106
# 2                     1348702  ...           10141              1014106
# 3                     1348702  ...           10141              1014106
# 4                     1348702  ...           10141              1014106
# ...                       ...  ...             ...                  ...
# 597707                1129202  ...           10562              1056202
# 597708                1129202  ...           10562              1056202
# 597709                1129202  ...           10562              1056202
# 597710                1129202  ...           10562              1056202
# 597711                1129202  ...           10562              1056202
#
#         DEP_TIME  DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  \
# 0         1129.0        0.0     1100-1159   1241.0        0.0          0
# 1         2013.0        0.0     2000-2059   2125.0        0.0          0
# 2         1226.0        1.0     1100-1159   1343.0        1.0          0
# 3         2224.0        0.0     2200-2259   2344.0        0.0          0
# 4         1136.0        0.0     1100-1159   1247.0        0.0          0
# ...          ...        ...           ...      ...        ...        ...
# 597707     754.0        0.0     0800-0859   1132.0        0.0          0
# 597708     750.0        0.0     0800-0859   1135.0        0.0          0
# 597709     755.0        0.0     0800-0859   1135.0        0.0          0
# 597710     750.0        0.0     0800-0859   1207.0        1.0          0
# 597711    1002.0        1.0     0800-0859   1346.0        1.0          0
#
#         DIVERTED  DISTANCE
# 0              0       257
# 1              0       257
# 2              0       257
# 3              0       257
# 4              0       257
# ...          ...       ...
# 597707         0      1132
# 597708         0      1132
# 597709         0      1132
# 597710         0      1132
# 597711         0      1132
#
# [597712 rows x 21 columns]

# %%
# Merge the origin and destination dataframes to prepare for the API requests
complete_flight_2020_df = pd.merge(origin_join_2020_df, dest_join_2020_df)
complete_flight_2020_df
# Out:
#        ORIGIN  ORIGIN_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR  aberdeen,sd             1            3                  20304
# 1         ABR  aberdeen,sd             1            3                  20304
# 2         ABR  aberdeen,sd             2            4                  20304
# 3         ABR  aberdeen,sd             2            4                  20304
# 4         ABR  aberdeen,sd             3            5                  20304
# ...       ...          ...           ...          ...                    ...
# 596152    BFM    mobile,al            22            3                  20436
# 596153    BFM    mobile,al            24            5                  20436
# 596154    BFM    mobile,al            27            1                  20436
# 596155    BFM    mobile,al            29            3                  20436
# 596156    BFM    mobile,al            31            5                  20436
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N878AS               4244              10141
# 1              OO   N8942A               4255              10141
# 2              OO   N8965E               4244              10141
# 3              OO   N8933B               4255              10141
# 4              OO   N477CA               4244              10141
# ...           ...      ...                ...                ...
# 596152         F9   N939FR                235              10562
# 596153         F9   N202FR                235              10562
# 596154         F9   N941FR                235              10562
# 596155         F9   N941FR                235              10562
# 596156         F9   N943FR                235              10562
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                     1014106  ...   MSP    1316.0       0.0     1300-1359
# 1                     1014106  ...   MSP     459.0       0.0     0001-0559
# 2                     1014106  ...   MSP    1417.0       1.0     1300-1359
# 3                     1014106  ...   MSP     455.0       0.0     0001-0559
# 4                     1014106  ...   MSP    1316.0       0.0     1300-1359
# ...                       ...  ...   ...       ...       ...           ...
# 596152                1056202  ...   DEN    1218.0       0.0     1200-1259
# 596153                1056202  ...   DEN    1225.0       0.0     1200-1259
# 596154                1056202  ...   DEN    1229.0       0.0     1200-1259
# 596155                1056202  ...   DEN    1234.0       0.0     1200-1259
# 596156                1056202  ...   DEN    1436.0       1.0     1200-1259
#
#         ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE       DEST_CITY
# 0         1438.0       0.0          0         0       257  minneapolis,mn
# 1          605.0       0.0          0         0       257  minneapolis,mn
# 2         1518.0       1.0          0         0       257  minneapolis,mn
# 3          616.0       0.0          0         0       257  minneapolis,mn
# 4         1438.0       0.0          0         0       257  minneapolis,mn
# ...          ...       ...        ...       ...       ...             ...
# 596152    1418.0       0.0          0         0      1132       denver,co
# 596153    1417.0       0.0          0         0      1132       denver,co
# 596154    1430.0       0.0          0         0      1132       denver,co
# 596155    1445.0       0.0          0         0      1132       denver,co
# 596156    1633.0       1.0          0         0      1132       denver,co
#
# [596157 rows x 22 columns]

# %%
#Add date format
complete_flight_2020_df['DAY_OF_MONTH'] = '2020-01-' + complete_flight_2020_df['DAY_OF_MONTH'].astype(str)

# %%
# Rename the day of the month column
clean_complete_flight_2020_df = complete_flight_2020_df.rename(columns={"'DAY_OF_MONTH'": "Date"})
clean_complete_flight_2020_df
# Out:
#        ORIGIN  ORIGIN_CITY DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR  aberdeen,sd    2020-01-1            3                  20304
# 1         ABR  aberdeen,sd    2020-01-1            3                  20304
# 2         ABR  aberdeen,sd    2020-01-2            4                  20304
# 3         ABR  aberdeen,sd    2020-01-2            4                  20304
# 4         ABR  aberdeen,sd    2020-01-3            5                  20304
# ...       ...          ...          ...          ...                    ...
# 596152    BFM    mobile,al   2020-01-22            3                  20436
# 596153    BFM    mobile,al   2020-01-24            5                  20436
# 596154    BFM    mobile,al   2020-01-27            1                  20436
# 596155    BFM    mobile,al   2020-01-29            3                  20436
# 596156    BFM    mobile,al   2020-01-31            5                  20436
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N878AS               4244              10141
# 1              OO   N8942A               4255              10141
# 2              OO   N8965E               4244              10141
# 3              OO   N8933B               4255              10141
# 4              OO   N477CA               4244              10141
# ...           ...      ...                ...                ...
# 596152         F9   N939FR                235              10562
# 596153         F9   N202FR                235              10562
# 596154         F9   N941FR                235              10562
# 596155         F9   N941FR                235              10562
# 596156         F9   N943FR                235              10562
#
#         ORIGIN_AIRPORT_SEQ_ID  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                     1014106  ...   MSP    1316.0       0.0     1300-1359
# 1                     1014106  ...   MSP     459.0       0.0     0001-0559
# 2                     1014106  ...   MSP    1417.0       1.0     1300-1359
# 3                     1014106  ...   MSP     455.0       0.0     0001-0559
# 4                     1014106  ...   MSP    1316.0       0.0     1300-1359
# ...                       ...  ...   ...       ...       ...           ...
# 596152                1056202  ...   DEN    1218.0       0.0     1200-1259
# 596153                1056202  ...   DEN    1225.0       0.0     1200-1259
# 596154                1056202  ...   DEN    1229.0       0.0     1200-1259
# 596155                1056202  ...   DEN    1234.0       0.0     1200-1259
# 596156                1056202  ...   DEN    1436.0       1.0     1200-1259
#
#         ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE       DEST_CITY
# 0         1438.0       0.0          0         0       257  minneapolis,mn
# 1          605.0       0.0          0         0       257  minneapolis,mn
# 2         1518.0       1.0          0         0       257  minneapolis,mn
# 3          616.0       0.0          0         0       257  minneapolis,mn
# 4         1438.0       0.0          0         0       257  minneapolis,mn
# ...          ...       ...        ...       ...       ...             ...
# 596152    1418.0       0.0          0         0      1132       denver,co
# 596153    1417.0       0.0          0         0      1132       denver,co
# 596154    1430.0       0.0          0         0      1132       denver,co
# 596155    1445.0       0.0          0         0      1132       denver,co
# 596156    1633.0       1.0          0         0      1132       denver,co
#
# [596157 rows x 22 columns]

# %%
clean_complete_flight_2020_df.to_csv("../../Database/clean_2020_flight_data.csv", index=False)

# %%
clean_complete_flight_2020_df.dtypes
# Out:
# ORIGIN                    object
# ORIGIN_CITY               object
# DAY_OF_MONTH              object
# DAY_OF_WEEK                int64
# OP_CARRIER_AIRLINE_ID      int64
# OP_CARRIER                object
# TAIL_NUM                  object
# OP_CARRIER_FL_NUM          int64
# ORIGIN_AIRPORT_ID          int64
# ORIGIN_AIRPORT_SEQ_ID      int64
# DEST_AIRPORT_ID            int64
# DEST_AIRPORT_SEQ_ID        int64
# DEST                      object
# DEP_TIME                 float64
# DEP_DEL15                float64
# DEP_TIME_BLK              object
# ARR_TIME                 float64
# ARR_DEL15                float64
# CANCELLED                  int64
# DIVERTED                   int64
# DISTANCE                   int64
# DEST_CITY                 object
# dtype: object
