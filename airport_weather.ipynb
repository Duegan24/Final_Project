# %%
#Import requests library and API key
import requests
from config import weather_api_key

# Import Dependencies
import pandas as pd

# %% [markdown]
# ### Import & edit necessary DataFrames for API call

# %%
# Import DataFrame from Segment One
initial_2019 = pd.read_csv('Database/Data/jan_19_clean_data.csv')
initial_2020 = pd.read_csv('Database/Data/jan_20_clean_data.csv')
initial_2019
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0                  1            2                  20363         9E   N8688C
# 1                  1            2                  20363         9E   N348PQ
# 2                  1            2                  20363         9E   N8896A
# 3                  1            2                  20363         9E   N8886A
# 4                  1            2                  20363         9E   N8974C
# ...              ...          ...                    ...        ...      ...
# 565958            31            4                  19977         UA   N776UA
# 565959            31            4                  19977         UA   N36280
# 565960            31            4                  19977         UA   N36280
# 565961            31            4                  19977         UA   N39726
# 565962            31            4                  19977         UA   N39726
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0                    3280              11953                1195302    GNV
# 1                    3281              13487                1348702    MSP
# 2                    3282              11433                1143302    DTW
# 3                    3283              15249                1524906    TLH
# 4                    3284              10397                1039707    ATL
# ...                   ...                ...                    ...    ...
# 565958                200              12016                1201602    GUM
# 565959                174              12016                1201602    GUM
# 565960                117              14955                1495503    SPN
# 565961                105              14955                1495503    SPN
# 565962                104              12016                1201602    GUM
#
#         DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  DEP_TIME  DEP_DEL15  \
# 0                 10397              1039707  ATL     601.0        0.0
# 1                 11193              1119302  CVG    1359.0        0.0
# 2                 11193              1119302  CVG    1215.0        0.0
# 3                 10397              1039707  ATL    1521.0        0.0
# 4                 11778              1177801  FSM    1847.0        0.0
# ...                 ...                  ...  ...       ...        ...
# 565958            12173              1217305  HNL     749.0        0.0
# 565959            14955              1495503  SPN     717.0        0.0
# 565960            12016              1201602  GUM     857.0        0.0
# 565961            12016              1201602  GUM    1820.0        0.0
# 565962            14955              1495503  SPN    1636.0        0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  DISTANCE
# 0         0600-0659     722.0        0.0          0         0       300
# 1         1400-1459    1633.0        0.0          0         0       596
# 2         1200-1259    1329.0        0.0          0         0       229
# 3         1500-1559    1625.0        0.0          0         0       223
# 4         1900-1959    1940.0        0.0          0         0       579
# ...             ...       ...        ...        ...       ...       ...
# 565958    0700-0759    1832.0        0.0          0         0      3801
# 565959    0700-0759     759.0        0.0          0         0       129
# 565960    0900-0959     933.0        0.0          0         0       129
# 565961    1800-1859    1854.0        0.0          0         0       129
# 565962    1600-1659    1719.0        0.0          0         0       129
#
# [565963 rows x 20 columns]

# %%
# Import City Codes to Cities DataFrame
city_code_df = pd.read_csv('Flight_data_files/airport_codes_city.csv')
city_code_df
# Out:
#     Airport Code              City
# 0            ABR      Aberdeen, SD
# 1            ABI       Abilene, TX
# 2            ADK   Adak Island, AK
# 3            CAK  Akron/Canton, OH
# 4            ALB        Albany, NY
# ..           ...               ...
# 317          ILM    Wilmington, NC
# 318          ORH     Worcester, MA
# 319          WRG      Wrangell, AK
# 320          YAK       Yakutat, AK
# 321          YUM          Yuma, AZ
#
# [322 rows x 2 columns]

# %%
# Make all cities in lowercase
city_code_lower = city_code_df['City'].str.lower()
city_code_lower
# Out:
# 0          aberdeen, sd
# 1           abilene, tx
# 2       adak island, ak
# 3      akron/canton, oh
# 4            albany, ny
#              ...
# 317      wilmington, nc
# 318       worcester, ma
# 319        wrangell, ak
# 320         yakutat, ak
# 321            yuma, az
# Name: City, Length: 322, dtype: object

# %%
# Delete all spaces
city_code_clean = city_code_lower.str.replace(" ", "")
city_code_clean
# Out:
# 0          aberdeen,sd
# 1           abilene,tx
# 2        adakisland,ak
# 3      akron/canton,oh
# 4            albany,ny
#             ...
# 317      wilmington,nc
# 318       worcester,ma
# 319        wrangell,ak
# 320         yakutat,ak
# 321            yuma,az
# Name: City, Length: 322, dtype: object

# %%
# Convert the lowercase/no space city series to a dataframe
lower_city_df = city_code_clean.to_frame()
lower_city_df
# Out:
#                 City
# 0        aberdeen,sd
# 1         abilene,tx
# 2      adakisland,ak
# 3    akron/canton,oh
# 4          albany,ny
# ..               ...
# 317    wilmington,nc
# 318     worcester,ma
# 319      wrangell,ak
# 320       yakutat,ak
# 321          yuma,az
#
# [322 rows x 1 columns]

# %%
# Create a city abreviation dataframe
city_code_abr_df = city_code_df.drop(columns="City")
city_code_abr_df
# Out:
#     Airport Code
# 0            ABR
# 1            ABI
# 2            ADK
# 3            CAK
# 4            ALB
# ..           ...
# 317          ILM
# 318          ORH
# 319          WRG
# 320          YAK
# 321          YUM
#
# [322 rows x 1 columns]

# %%
# Inner join the two dataframes to create a clean city code df that can be used by the API
city_code_clean_df = pd.concat([city_code_abr_df, lower_city_df], axis=1, join='inner')
city_code_clean_df
# Out:
#     Airport Code             City
# 0            ABR      aberdeen,sd
# 1            ABI       abilene,tx
# 2            ADK    adakisland,ak
# 3            CAK  akron/canton,oh
# 4            ALB        albany,ny
# ..           ...              ...
# 317          ILM    wilmington,nc
# 318          ORH     worcester,ma
# 319          WRG      wrangell,ak
# 320          YAK       yakutat,ak
# 321          YUM          yuma,az
#
# [322 rows x 2 columns]

# %%
# Create a dataframe for the origin cities
origin_code_df = city_code_clean_df.rename(columns={"Airport Code": "ORIGIN"})
origin_code_df
# Out:
#     ORIGIN             City
# 0      ABR      aberdeen,sd
# 1      ABI       abilene,tx
# 2      ADK    adakisland,ak
# 3      CAK  akron/canton,oh
# 4      ALB        albany,ny
# ..     ...              ...
# 317    ILM    wilmington,nc
# 318    ORH     worcester,ma
# 319    WRG      wrangell,ak
# 320    YAK       yakutat,ak
# 321    YUM          yuma,az
#
# [322 rows x 2 columns]

# %%
# Create a dataframe for the destination cities
dest_code_df = city_code_clean_df.rename(columns={"Airport Code": "DEST"})
dest_code_df
# Out:
#     DEST             City
# 0    ABR      aberdeen,sd
# 1    ABI       abilene,tx
# 2    ADK    adakisland,ak
# 3    CAK  akron/canton,oh
# 4    ALB        albany,ny
# ..   ...              ...
# 317  ILM    wilmington,nc
# 318  ORH     worcester,ma
# 319  WRG      wrangell,ak
# 320  YAK       yakutat,ak
# 321  YUM          yuma,az
#
# [322 rows x 2 columns]

# %%
initial_2019["dest_city"] = ""
initial_2019["origin_city"] = ""
flights_2019 = initial_2019[["DAY_OF_MONTH","DAY_OF_WEEK","OP_CARRIER_AIRLINE_ID","OP_CARRIER","TAIL_NUM","OP_CARRIER_FL_NUM","ORIGIN_AIRPORT_ID","ORIGIN_AIRPORT_SEQ_ID","ORIGIN","origin_city","DEST_AIRPORT_ID","DEST_AIRPORT_SEQ_ID","DEST","dest_city","DEP_TIME","DEP_DEL15","DEP_TIME_BLK","ARR_TIME","ARR_DEL15","CANCELLED","DIVERTED","DISTANCE"]]
flights_2019
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# 0                  1            2                  20363         9E   N8688C
# 1                  1            2                  20363         9E   N348PQ
# 2                  1            2                  20363         9E   N8896A
# 3                  1            2                  20363         9E   N8886A
# 4                  1            2                  20363         9E   N8974C
# ...              ...          ...                    ...        ...      ...
# 565958            31            4                  19977         UA   N776UA
# 565959            31            4                  19977         UA   N36280
# 565960            31            4                  19977         UA   N36280
# 565961            31            4                  19977         UA   N39726
# 565962            31            4                  19977         UA   N39726
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID ORIGIN  \
# 0                    3280              11953                1195302    GNV
# 1                    3281              13487                1348702    MSP
# 2                    3282              11433                1143302    DTW
# 3                    3283              15249                1524906    TLH
# 4                    3284              10397                1039707    ATL
# ...                   ...                ...                    ...    ...
# 565958                200              12016                1201602    GUM
# 565959                174              12016                1201602    GUM
# 565960                117              14955                1495503    SPN
# 565961                105              14955                1495503    SPN
# 565962                104              12016                1201602    GUM
#
#        origin_city  ...  DEST  dest_city DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                   ...   ATL               601.0       0.0     0600-0659
# 1                   ...   CVG              1359.0       0.0     1400-1459
# 2                   ...   CVG              1215.0       0.0     1200-1259
# 3                   ...   ATL              1521.0       0.0     1500-1559
# 4                   ...   FSM              1847.0       0.0     1900-1959
# ...            ...  ...   ...        ...      ...       ...           ...
# 565958              ...   HNL               749.0       0.0     0700-0759
# 565959              ...   SPN               717.0       0.0     0700-0759
# 565960              ...   GUM               857.0       0.0     0900-0959
# 565961              ...   GUM              1820.0       0.0     1800-1859
# 565962              ...   SPN              1636.0       0.0     1600-1659
#
#         ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE
# 0          722.0       0.0          0         0       300
# 1         1633.0       0.0          0         0       596
# 2         1329.0       0.0          0         0       229
# 3         1625.0       0.0          0         0       223
# 4         1940.0       0.0          0         0       579
# ...          ...       ...        ...       ...       ...
# 565958    1832.0       0.0          0         0      3801
# 565959     759.0       0.0          0         0       129
# 565960     933.0       0.0          0         0       129
# 565961    1854.0       0.0          0         0       129
# 565962    1719.0       0.0          0         0       129
#
# [565963 rows x 22 columns]

# %%
# Merge Origin code and the flights dataframes
origin_join_df = pd.merge(origin_code_df,flights_2019, on='ORIGIN', how ='inner')
origin_join_df
# Out:
#        ORIGIN         City  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR  aberdeen,sd             1            2                  20304
# 1         ABR  aberdeen,sd             1            2                  20304
# 2         ABR  aberdeen,sd             2            3                  20304
# 3         ABR  aberdeen,sd             2            3                  20304
# 4         ABR  aberdeen,sd             3            4                  20304
# ...       ...          ...           ...          ...                    ...
# 555444    YUM      yuma,az            30            3                  20304
# 555445    YUM      yuma,az            31            4                  20304
# 555446    YUM      yuma,az            31            4                  20304
# 555447    YUM      yuma,az            31            4                  20304
# 555448    YUM      yuma,az            31            4                  20304
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              10141
# 1              OO   N432SW               7365              10141
# 2              OO   N498CA               7363              10141
# 3              OO   N439SW               7365              10141
# 4              OO   N8965E               7363              10141
# ...           ...      ...                ...                ...
# 555444         OO   N746SK               2988              16218
# 555445         OO   N713SK               2978              16218
# 555446         OO   N713SK               2988              16218
# 555447         OO   N710SK               3060              16218
# 555448         OO   N746SK               2967              16218
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST  dest_city  DEP_TIME DEP_DEL15  \
# 0                     1014106  ...  MSP               1411.0       1.0
# 1                     1014106  ...  MSP                642.0       0.0
# 2                     1014106  ...  MSP               1310.0       0.0
# 3                     1014106  ...  MSP                502.0       0.0
# 4                     1014106  ...  MSP               1307.0       0.0
# ...                       ...  ...  ...        ...       ...       ...
# 555444                1621802  ...  PHX               1739.0       0.0
# 555445                1621802  ...  PHX               1120.0       0.0
# 555446                1621802  ...  PHX               1739.0       0.0
# 555447                1621802  ...  PHX               2120.0       0.0
# 555448                1621802  ...  PHX                645.0       0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15 CANCELLED  DIVERTED  DISTANCE
# 0         1300-1359    1521.0        1.0         0         0       257
# 1         0600-0659     800.0        0.0         0         0       257
# 2         1300-1359    1424.0        0.0         0         0       257
# 3         0001-0559     622.0        0.0         0         0       257
# 4         1300-1359    1411.0        0.0         0         0       257
# ...             ...       ...        ...       ...       ...       ...
# 555444    1700-1759    1832.0        0.0         0         0       160
# 555445    1100-1159    1212.0        0.0         0         0       160
# 555446    1700-1759    1828.0        0.0         0         0       160
# 555447    2100-2159    2203.0        0.0         0         0       160
# 555448    0600-0659     728.0        0.0         0         0       160
#
# [555449 rows x 23 columns]

# %%
# Change city column to Origin City
origin_join_df = origin_join_df.rename(columns={'City':'ORIGIN_CITY'})
origin_join_df
# Out:
#        ORIGIN  ORIGIN_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0         ABR  aberdeen,sd             1            2                  20304
# 1         ABR  aberdeen,sd             1            2                  20304
# 2         ABR  aberdeen,sd             2            3                  20304
# 3         ABR  aberdeen,sd             2            3                  20304
# 4         ABR  aberdeen,sd             3            4                  20304
# ...       ...          ...           ...          ...                    ...
# 555444    YUM      yuma,az            30            3                  20304
# 555445    YUM      yuma,az            31            4                  20304
# 555446    YUM      yuma,az            31            4                  20304
# 555447    YUM      yuma,az            31            4                  20304
# 555448    YUM      yuma,az            31            4                  20304
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              10141
# 1              OO   N432SW               7365              10141
# 2              OO   N498CA               7363              10141
# 3              OO   N439SW               7365              10141
# 4              OO   N8965E               7363              10141
# ...           ...      ...                ...                ...
# 555444         OO   N746SK               2988              16218
# 555445         OO   N713SK               2978              16218
# 555446         OO   N713SK               2988              16218
# 555447         OO   N710SK               3060              16218
# 555448         OO   N746SK               2967              16218
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST  dest_city  DEP_TIME DEP_DEL15  \
# 0                     1014106  ...  MSP               1411.0       1.0
# 1                     1014106  ...  MSP                642.0       0.0
# 2                     1014106  ...  MSP               1310.0       0.0
# 3                     1014106  ...  MSP                502.0       0.0
# 4                     1014106  ...  MSP               1307.0       0.0
# ...                       ...  ...  ...        ...       ...       ...
# 555444                1621802  ...  PHX               1739.0       0.0
# 555445                1621802  ...  PHX               1120.0       0.0
# 555446                1621802  ...  PHX               1739.0       0.0
# 555447                1621802  ...  PHX               2120.0       0.0
# 555448                1621802  ...  PHX                645.0       0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15 CANCELLED  DIVERTED  DISTANCE
# 0         1300-1359    1521.0        1.0         0         0       257
# 1         0600-0659     800.0        0.0         0         0       257
# 2         1300-1359    1424.0        0.0         0         0       257
# 3         0001-0559     622.0        0.0         0         0       257
# 4         1300-1359    1411.0        0.0         0         0       257
# ...             ...       ...        ...       ...       ...       ...
# 555444    1700-1759    1832.0        0.0         0         0       160
# 555445    1100-1159    1212.0        0.0         0         0       160
# 555446    1700-1759    1828.0        0.0         0         0       160
# 555447    2100-2159    2203.0        0.0         0         0       160
# 555448    0600-0659     728.0        0.0         0         0       160
#
# [555449 rows x 23 columns]

# %%
# Create a destination dataframe by merging the flights with destination codes
dest_join_df = pd.merge(dest_code_df,flights_2019, on='DEST', how ='inner')
dest_join_df
# Out:
#        DEST         City  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0       ABR  aberdeen,sd             1            2                  20304
# 1       ABR  aberdeen,sd             1            2                  20304
# 2       ABR  aberdeen,sd             2            3                  20304
# 3       ABR  aberdeen,sd             2            3                  20304
# 4       ABR  aberdeen,sd             3            4                  20304
# ...     ...          ...           ...          ...                    ...
# 555445  YUM      yuma,az            30            3                  20304
# 555446  YUM      yuma,az            31            4                  20304
# 555447  YUM      yuma,az            31            4                  20304
# 555448  YUM      yuma,az            31            4                  20304
# 555449  YUM      yuma,az            31            4                  20304
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              13487
# 1              OO   N439SW               7419              13487
# 2              OO   N498CA               7363              13487
# 3              OO   N935SW               7419              13487
# 4              OO   N8965E               7363              13487
# ...           ...      ...                ...                ...
# 555445         OO   N746SK               2988              14107
# 555446         OO   N713SK               2978              14107
# 555447         OO   N710SK               2985              14107
# 555448         OO   N713SK               2988              14107
# 555449         OO   N710SK               3060              14107
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST_AIRPORT_SEQ_ID dest_city  DEP_TIME  \
# 0                     1348702  ...             1014106              1220.0
# 1                     1348702  ...             1014106              2010.0
# 2                     1348702  ...             1014106              1123.0
# 3                     1348702  ...             1014106              2226.0
# 4                     1348702  ...             1014106              1120.0
# ...                       ...  ...                 ...       ...       ...
# 555445                1410702  ...             1621802              1610.0
# 555446                1410702  ...             1621802               936.0
# 555447                1410702  ...             1621802              2254.0
# 555448                1410702  ...             1621802              1612.0
# 555449                1410702  ...             1621802              1954.0
#
#         DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15 CANCELLED  DIVERTED  \
# 0             1.0    1100-1159    1343.0        1.0         0         0
# 1             0.0    2000-2059    2139.0        0.0         0         0
# 2             0.0    1100-1159    1230.0        0.0         0         0
# 3             0.0    2200-2259    2342.0        0.0         0         0
# 4             0.0    1100-1159    1224.0        0.0         0         0
# ...           ...          ...       ...        ...       ...       ...
# 555445        0.0    1600-1659    1702.0        0.0         0         0
# 555446        0.0    0900-0959    1048.0        0.0         0         0
# 555447        0.0    2200-2259    2347.0        0.0         0         0
# 555448        0.0    1600-1659    1655.0        0.0         0         0
# 555449        0.0    1900-1959    2107.0        1.0         0         0
#
#         DISTANCE
# 0            257
# 1            257
# 2            257
# 3            257
# 4            257
# ...          ...
# 555445       160
# 555446       160
# 555447       160
# 555448       160
# 555449       160
#
# [555450 rows x 23 columns]

# %%
# Change city column to Destination City
dest_join_df = dest_join_df.rename(columns={'City':'DEST_CITY'})
dest_join_df
# Out:
#        DEST    DEST_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0       ABR  aberdeen,sd             1            2                  20304
# 1       ABR  aberdeen,sd             1            2                  20304
# 2       ABR  aberdeen,sd             2            3                  20304
# 3       ABR  aberdeen,sd             2            3                  20304
# 4       ABR  aberdeen,sd             3            4                  20304
# ...     ...          ...           ...          ...                    ...
# 555445  YUM      yuma,az            30            3                  20304
# 555446  YUM      yuma,az            31            4                  20304
# 555447  YUM      yuma,az            31            4                  20304
# 555448  YUM      yuma,az            31            4                  20304
# 555449  YUM      yuma,az            31            4                  20304
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              OO   N910EV               7363              13487
# 1              OO   N439SW               7419              13487
# 2              OO   N498CA               7363              13487
# 3              OO   N935SW               7419              13487
# 4              OO   N8965E               7363              13487
# ...           ...      ...                ...                ...
# 555445         OO   N746SK               2988              14107
# 555446         OO   N713SK               2978              14107
# 555447         OO   N710SK               2985              14107
# 555448         OO   N713SK               2988              14107
# 555449         OO   N710SK               3060              14107
#
#         ORIGIN_AIRPORT_SEQ_ID  ... DEST_AIRPORT_SEQ_ID dest_city  DEP_TIME  \
# 0                     1348702  ...             1014106              1220.0
# 1                     1348702  ...             1014106              2010.0
# 2                     1348702  ...             1014106              1123.0
# 3                     1348702  ...             1014106              2226.0
# 4                     1348702  ...             1014106              1120.0
# ...                       ...  ...                 ...       ...       ...
# 555445                1410702  ...             1621802              1610.0
# 555446                1410702  ...             1621802               936.0
# 555447                1410702  ...             1621802              2254.0
# 555448                1410702  ...             1621802              1612.0
# 555449                1410702  ...             1621802              1954.0
#
#         DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15 CANCELLED  DIVERTED  \
# 0             1.0    1100-1159    1343.0        1.0         0         0
# 1             0.0    2000-2059    2139.0        0.0         0         0
# 2             0.0    1100-1159    1230.0        0.0         0         0
# 3             0.0    2200-2259    2342.0        0.0         0         0
# 4             0.0    1100-1159    1224.0        0.0         0         0
# ...           ...          ...       ...        ...       ...       ...
# 555445        0.0    1600-1659    1702.0        0.0         0         0
# 555446        0.0    0900-0959    1048.0        0.0         0         0
# 555447        0.0    2200-2259    2347.0        0.0         0         0
# 555448        0.0    1600-1659    1655.0        0.0         0         0
# 555449        0.0    1900-1959    2107.0        1.0         0         0
#
#         DISTANCE
# 0            257
# 1            257
# 2            257
# 3            257
# 4            257
# ...          ...
# 555445       160
# 555446       160
# 555447       160
# 555448       160
# 555449       160
#
# [555450 rows x 23 columns]

# %%
# Merge the origin and destination dataframes to prepare for the API requests
complete_flight_df = pd.merge(origin_join_df, dest_join_df)
complete_flight_df.head(50)
# Out:
#    ORIGIN  ORIGIN_CITY  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0     ABR  aberdeen,sd             1            2                  20304
# 1     ABR  aberdeen,sd             1            2                  20304
# 2     ABR  aberdeen,sd             2            3                  20304
# 3     ABR  aberdeen,sd             2            3                  20304
# 4     ABR  aberdeen,sd             3            4                  20304
# 5     ABR  aberdeen,sd             3            4                  20304
# 6     ABR  aberdeen,sd             4            5                  20304
# 7     ABR  aberdeen,sd             4            5                  20304
# 8     ABR  aberdeen,sd             5            6                  20304
# 9     ABR  aberdeen,sd             5            6                  20304
# 10    ABR  aberdeen,sd             6            7                  20304
# 11    ABR  aberdeen,sd             6            7                  20304
# 12    ABR  aberdeen,sd             7            1                  20304
# 13    ABR  aberdeen,sd             7            1                  20304
# 14    ABR  aberdeen,sd             8            2                  20304
# 15    ABR  aberdeen,sd             8            2                  20304
# 16    ABR  aberdeen,sd             9            3                  20304
# 17    ABR  aberdeen,sd             9            3                  20304
# 18    ABR  aberdeen,sd            10            4                  20304
# 19    ABR  aberdeen,sd            10            4                  20304
# 20    ABR  aberdeen,sd            11            5                  20304
# 21    ABR  aberdeen,sd            11            5                  20304
# 22    ABR  aberdeen,sd            12            6                  20304
# 23    ABR  aberdeen,sd            12            6                  20304
# 24    ABR  aberdeen,sd            13            7                  20304
# 25    ABR  aberdeen,sd            13            7                  20304
# 26    ABR  aberdeen,sd            14            1                  20304
# 27    ABR  aberdeen,sd            14            1                  20304
# 28    ABR  aberdeen,sd            15            2                  20304
# 29    ABR  aberdeen,sd            15            2                  20304
# 30    ABR  aberdeen,sd            16            3                  20304
# 31    ABR  aberdeen,sd            16            3                  20304
# 32    ABR  aberdeen,sd            17            4                  20304
# 33    ABR  aberdeen,sd            17            4                  20304
# 34    ABR  aberdeen,sd            18            5                  20304
# 35    ABR  aberdeen,sd            18            5                  20304
# 36    ABR  aberdeen,sd            19            6                  20304
# 37    ABR  aberdeen,sd            19            6                  20304
# 38    ABR  aberdeen,sd            20            7                  20304
# 39    ABR  aberdeen,sd            20            7                  20304
# 40    ABR  aberdeen,sd            21            1                  20304
# 41    ABR  aberdeen,sd            21            1                  20304
# 42    ABR  aberdeen,sd            22            2                  20304
# 43    ABR  aberdeen,sd            22            2                  20304
# 44    ABR  aberdeen,sd            23            3                  20304
# 45    ABR  aberdeen,sd            23            3                  20304
# 46    ABR  aberdeen,sd            24            4                  20304
# 47    ABR  aberdeen,sd            24            4                  20304
# 48    ABR  aberdeen,sd            25            5                  20304
# 49    ABR  aberdeen,sd            25            5                  20304
#
#    OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0          OO   N910EV               7363              10141
# 1          OO   N432SW               7365              10141
# 2          OO   N498CA               7363              10141
# 3          OO   N439SW               7365              10141
# 4          OO   N8965E               7363              10141
# 5          OO   N935SW               7365              10141
# 6          OO   N461SW               7363              10141
# 7          OO   N461SW               7365              10141
# 8          OO   N702BR               7363              10141
# 9          OO   N430SW               7365              10141
# 10         OO   N437SW               7363              10141
# 11         OO   N437SW               7365              10141
# 12         OO   N460SW               7363              10141
# 13         OO   N8923A               7365              10141
# 14         OO   N438SW               7363              10141
# 15         OO   N457SW               7365              10141
# 16         OO   N868CA               7363              10141
# 17         OO   N886AS               7365              10141
# 18         OO   N926EV               7363              10141
# 19         OO   N675BR               7365              10141
# 20         OO   N455CA               7363              10141
# 21         OO   N868CA               7365              10141
# 22         OO   N921EV               7363              10141
# 23         OO   N8884E               7365              10141
# 24         OO   N915EV               7363              10141
# 25         OO   N498CA               7365              10141
# 26         OO   N921EV               7363              10141
# 27         OO   N873AS               7365              10141
# 28         OO   N439SW               7363              10141
# 29         OO   N8932C               7365              10141
# 30         OO   N448SW               7363              10141
# 31         OO   N8982A               7365              10141
# 32         OO   N442SW               7363              10141
# 33         OO   N498CA               7365              10141
# 34         OO   N431SW               7363              10141
# 35         OO   N427SW               7365              10141
# 36         OO   N460SW               7363              10141
# 37         OO   N868CA               7365              10141
# 38         OO   N868CA               7363              10141
# 39         OO   N8965E               7365              10141
# 40         OO   N936SW               7363              10141
# 41         OO   N926EV               7365              10141
# 42         OO   N8965E               7363              10141
# 43         OO   N440SW               7365              10141
# 44         OO   N506CA               7363              10141
# 45         OO   N8965E               7365              10141
# 46         OO   N440SW               7363              10141
# 47         OO   N477CA               7365              10141
# 48         OO   N477CA               7363              10141
# 49         OO   N433SW               7365              10141
#
#     ORIGIN_AIRPORT_SEQ_ID  ... dest_city  DEP_TIME  DEP_DEL15 DEP_TIME_BLK  \
# 0                 1014106  ...              1411.0        1.0    1300-1359
# 1                 1014106  ...               642.0        0.0    0600-0659
# 2                 1014106  ...              1310.0        0.0    1300-1359
# 3                 1014106  ...               502.0        0.0    0001-0559
# 4                 1014106  ...              1307.0        0.0    1300-1359
# 5                 1014106  ...               506.0        0.0    0001-0559
# 6                 1014106  ...              1308.0        0.0    1300-1359
# 7                 1014106  ...               447.0        0.0    0001-0559
# 8                 1014106  ...              1312.0        0.0    1300-1359
# 9                 1014106  ...               447.0        0.0    0001-0559
# 10                1014106  ...              1318.0        0.0    1300-1359
# 11                1014106  ...               453.0        0.0    0001-0559
# 12                1014106  ...              1307.0        0.0    1300-1359
# 13                1014106  ...               447.0        0.0    0001-0559
# 14                1014106  ...              1307.0        0.0    1300-1359
# 15                1014106  ...               500.0        0.0    0001-0559
# 16                1014106  ...              1310.0        0.0    1300-1359
# 17                1014106  ...               448.0        0.0    0001-0559
# 18                1014106  ...              1317.0        0.0    1300-1359
# 19                1014106  ...               456.0        0.0    0001-0559
# 20                1014106  ...              1310.0        0.0    1300-1359
# 21                1014106  ...               455.0        0.0    0001-0559
# 22                1014106  ...              1306.0        0.0    1300-1359
# 23                1014106  ...               500.0        0.0    0001-0559
# 24                1014106  ...              1316.0        0.0    1300-1359
# 25                1014106  ...               450.0        0.0    0001-0559
# 26                1014106  ...              1351.0        1.0    1300-1359
# 27                1014106  ...               459.0        0.0    0001-0559
# 28                1014106  ...              1316.0        0.0    1300-1359
# 29                1014106  ...               452.0        0.0    0001-0559
# 30                1014106  ...              1312.0        0.0    1300-1359
# 31                1014106  ...               456.0        0.0    0001-0559
# 32                1014106  ...              1311.0        0.0    1300-1359
# 33                1014106  ...               457.0        0.0    0001-0559
# 34                1014106  ...              1359.0        1.0    1300-1359
# 35                1014106  ...               457.0        0.0    0001-0559
# 36                1014106  ...              1306.0        0.0    1300-1359
# 37                1014106  ...               512.0        0.0    0001-0559
# 38                1014106  ...              1319.0        0.0    1300-1359
# 39                1014106  ...               456.0        0.0    0001-0559
# 40                1014106  ...              1315.0        0.0    1300-1359
# 41                1014106  ...               625.0        0.0    0600-0659
# 42                1014106  ...              1319.0        0.0    1300-1359
# 43                1014106  ...               454.0        0.0    0001-0559
# 44                1014106  ...              1318.0        0.0    1300-1359
# 45                1014106  ...               451.0        0.0    0001-0559
# 46                1014106  ...              1314.0        0.0    1300-1359
# 47                1014106  ...               456.0        0.0    0001-0559
# 48                1014106  ...              1310.0        0.0    1300-1359
# 49                1014106  ...               548.0        1.0    0001-0559
#
#    ARR_TIME  ARR_DEL15  CANCELLED DIVERTED  DISTANCE       DEST_CITY
# 0    1521.0        1.0          0        0       257  minneapolis,mn
# 1     800.0        0.0          0        0       257  minneapolis,mn
# 2    1424.0        0.0          0        0       257  minneapolis,mn
# 3     622.0        0.0          0        0       257  minneapolis,mn
# 4    1411.0        0.0          0        0       257  minneapolis,mn
# 5     621.0        0.0          0        0       257  minneapolis,mn
# 6    1414.0        0.0          0        0       257  minneapolis,mn
# 7     603.0        0.0          0        0       257  minneapolis,mn
# 8    1415.0        0.0          0        0       257  minneapolis,mn
# 9     547.0        0.0          0        0       257  minneapolis,mn
# 10   1417.0        0.0          0        0       257  minneapolis,mn
# 11    614.0        0.0          0        0       257  minneapolis,mn
# 12   1417.0        0.0          0        0       257  minneapolis,mn
# 13    548.0        0.0          0        0       257  minneapolis,mn
# 14   1417.0        0.0          0        0       257  minneapolis,mn
# 15    614.0        0.0          0        0       257  minneapolis,mn
# 16   1409.0        0.0          0        0       257  minneapolis,mn
# 17    548.0        0.0          0        0       257  minneapolis,mn
# 18   1419.0        0.0          0        0       257  minneapolis,mn
# 19    621.0        0.0          0        0       257  minneapolis,mn
# 20   1422.0        0.0          0        0       257  minneapolis,mn
# 21    640.0        0.0          0        0       257  minneapolis,mn
# 22   1433.0        0.0          0        0       257  minneapolis,mn
# 23    626.0        0.0          0        0       257  minneapolis,mn
# 24   1433.0        0.0          0        0       257  minneapolis,mn
# 25    613.0        0.0          0        0       257  minneapolis,mn
# 26   1516.0        1.0          0        0       257  minneapolis,mn
# 27    633.0        0.0          0        0       257  minneapolis,mn
# 28   1439.0        0.0          0        0       257  minneapolis,mn
# 29    612.0        0.0          0        0       257  minneapolis,mn
# 30   1410.0        0.0          0        0       257  minneapolis,mn
# 31    617.0        0.0          0        0       257  minneapolis,mn
# 32   1422.0        0.0          0        0       257  minneapolis,mn
# 33    628.0        0.0          0        0       257  minneapolis,mn
# 34   1522.0        1.0          0        0       257  minneapolis,mn
# 35    616.0        0.0          0        0       257  minneapolis,mn
# 36   1417.0        0.0          0        0       257  minneapolis,mn
# 37    636.0        0.0          0        0       257  minneapolis,mn
# 38   1421.0        0.0          0        0       257  minneapolis,mn
# 39    629.0        0.0          0        0       257  minneapolis,mn
# 40   1437.0        0.0          0        0       257  minneapolis,mn
# 41    746.0        0.0          0        0       257  minneapolis,mn
# 42   1444.0        0.0          0        0       257  minneapolis,mn
# 43    635.0        0.0          0        0       257  minneapolis,mn
# 44   1425.0        0.0          0        0       257  minneapolis,mn
# 45    610.0        0.0          0        0       257  minneapolis,mn
# 46   1427.0        0.0          0        0       257  minneapolis,mn
# 47    628.0        0.0          0        0       257  minneapolis,mn
# 48   1415.0        0.0          0        0       257  minneapolis,mn
# 49    654.0        1.0          0        0       257  minneapolis,mn
#
# [50 rows x 24 columns]

# %%
# Create an empty list for dept airport codes and date
dest_name = []
origin_name = []
date = []

#Create for loop for dates
for i in complete_flight_df['DAY_OF_MONTH']:
    date.append(i)

#Create for loop for departure airport code
for i in complete_flight_df['ORIGIN_CITY']:
    origin_name.append(i)

#Create for loop for arival airport code
for i in complete_flight_df['DEST_CITY']:
    dest_name.append(i)


#len(dest_name)
#len(origin_name)
#len(date)
# Out:
# 545340

# %% [markdown]
# ### Create API calls using Open Weather

# %%
# Starting URL for API call to World Weather
url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx" + "?key=" + weather_api_key
print(url)

# %%
# Create an endpoint URL for a city destination
airport_url = url + "&q=" + dest_code + "&format=json" + "&date=2019-01-" + date
print(airport_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-51f8016b1242> in <module>
#       1 # Create an endpoint URL for a city destination
# ----> 2 airport_url = url + "&q=" + dest_code + "&format=json" + "&date=2019-01-" + date
#       3 print(airport_url)
#
# NameError: name 'url' is not defined

# %%
# Create an endpoint for airport weather
airport_weather = requests.get(airport_url)
airport_weather.json()
